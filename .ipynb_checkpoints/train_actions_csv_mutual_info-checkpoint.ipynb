# %%
import os
import pandas as pd
import numpy as np
import sklearn
import csv

# %%
df = pd.read_csv('Charades_vu17_train.csv')

# %%
df.head()
# Out:
#       id subject         scene  quality  relevance verified  \
# 0  46GP8    HR43       Kitchen      6.0        7.0      Yes
# 1  N11GT    0KZ7        Stairs      6.0        7.0      Yes
# 2  0IH69    6RE8       Bedroom      6.0        5.0      Yes
# 3  KRF68    YA10  Laundry room      6.0        7.0      Yes
# 4  MJO7C    6RE8       Kitchen      6.0        6.0      Yes
#
#                                               script                 objects  \
# 0  A person cooking on a stove while watching som...       food;stove;window
# 1  One person opens up a folded blanket, then sne...     blanket;broom;floor
# 2  A person is seen leaving a cabinet. They then ...  book;box;cabinet;shelf
# 3  A person runs into their laundry room. They gr...      clothes;door;phone
# 4  A person runs into their pantry holding a bott...               cup;phone
#
#                                         descriptions  \
# 0  A person cooks food on a stove before looking ...
# 1  Person at the bottom of the staircase shakes a...
# 2  A person is standing in a bedroom. They walk o...
# 3  A person runs in and shuts door. The person gr...
# 4  A person runs in place while holding a bottle ...
#
#                                              actions  length
# 0                   c092 11.90 21.20;c147 0.00 12.60   24.83
# 1  c098 8.60 14.20;c075 0.00 11.70;c127 0.00 15.2...   18.33
# 2                                                NaN   30.25
# 3  c018 22.60 27.80;c141 4.10 9.60;c148 10.30 25....   30.33
# 4                    c015 0.00 32.00;c107 0.00 32.00   31.38

# %%
df = df[pd.notnull(df['actions'])] # drop NA in column['actions']
# df = df[df.quality >=6 ]
# df = df[df.relevance == 7] #  和 script 的相關性，但我們不需要管 script ，所以用不到
df['origin_index'] = df.index.values
df.head()
# Out:
#       id subject                                              scene  quality  \
# 0  46GP8    HR43                                            Kitchen      6.0
# 1  N11GT    0KZ7                                             Stairs      6.0
# 3  KRF68    YA10                                       Laundry room      6.0
# 4  MJO7C    6RE8                                            Kitchen      6.0
# 5  S6MPZ    EA2K  Home Office / Study (A room in a house used fo...      6.0
#
#    relevance verified                                             script  \
# 0        7.0      Yes  A person cooking on a stove while watching som...
# 1        7.0      Yes  One person opens up a folded blanket, then sne...
# 3        7.0      Yes  A person runs into their laundry room. They gr...
# 4        6.0      Yes  A person runs into their pantry holding a bott...
# 5        6.0      Yes  A person is eating at the desk and lying the p...
#
#                                     objects  \
# 0                         food;stove;window
# 1                       blanket;broom;floor
# 3                        clothes;door;phone
# 4                                 cup;phone
# 5  chair;desk;food;phone;plate;snacks;table
#
#                                         descriptions  \
# 0  A person cooks food on a stove before looking ...
# 1  Person at the bottom of the staircase shakes a...
# 3  A person runs in and shuts door. The person gr...
# 4  A person runs in place while holding a bottle ...
# 5  A person in a blue shirt is eating snacks off ...
#
#                                              actions  length  origin_index
# 0                   c092 11.90 21.20;c147 0.00 12.60   24.83             0
# 1  c098 8.60 14.20;c075 0.00 11.70;c127 0.00 15.2...   18.33             1
# 3  c018 22.60 27.80;c141 4.10 9.60;c148 10.30 25....   30.33             3
# 4                    c015 0.00 32.00;c107 0.00 32.00   31.38             4
# 5  c009 0.00 4.30;c011 0.00 39.00;c015 0.00 39.00...   38.46             5

# %%
df = df.reset_index(drop=True)
df.head()
# Out:
#       id subject                                              scene  quality  \
# 0  46GP8    HR43                                            Kitchen      6.0
# 1  N11GT    0KZ7                                             Stairs      6.0
# 2  KRF68    YA10                                       Laundry room      6.0
# 3  MJO7C    6RE8                                            Kitchen      6.0
# 4  S6MPZ    EA2K  Home Office / Study (A room in a house used fo...      6.0
#
#    relevance verified                                             script  \
# 0        7.0      Yes  A person cooking on a stove while watching som...
# 1        7.0      Yes  One person opens up a folded blanket, then sne...
# 2        7.0      Yes  A person runs into their laundry room. They gr...
# 3        6.0      Yes  A person runs into their pantry holding a bott...
# 4        6.0      Yes  A person is eating at the desk and lying the p...
#
#                                     objects  \
# 0                         food;stove;window
# 1                       blanket;broom;floor
# 2                        clothes;door;phone
# 3                                 cup;phone
# 4  chair;desk;food;phone;plate;snacks;table
#
#                                         descriptions  \
# 0  A person cooks food on a stove before looking ...
# 1  Person at the bottom of the staircase shakes a...
# 2  A person runs in and shuts door. The person gr...
# 3  A person runs in place while holding a bottle ...
# 4  A person in a blue shirt is eating snacks off ...
#
#                                              actions  length  origin_index
# 0                   c092 11.90 21.20;c147 0.00 12.60   24.83             0
# 1  c098 8.60 14.20;c075 0.00 11.70;c127 0.00 15.2...   18.33             1
# 2  c018 22.60 27.80;c141 4.10 9.60;c148 10.30 25....   30.33             3
# 3                    c015 0.00 32.00;c107 0.00 32.00   31.38             4
# 4  c009 0.00 4.30;c011 0.00 39.00;c015 0.00 39.00...   38.46             5

# %%
dat_id = df['id']
dat_actions = df['actions']
dat_origin_index = df['origin_index']
dat = pd.concat([dat_id, dat_origin_index, dat_actions], axis=1)
split_arr = dat['actions'].str.split(';')

# %%
large_arr = []
for element in enumerate(split_arr):
    arr = []
    for i in element[1]:
        k = i.split(" ")
        d = k[0]
        arr.append(d)
    large_arr.append(arr)
dat['split'] = large_arr

# %%
dat = dat.drop('actions', 1)

# %%
str_actions = dat['split']
int_actions = []
for action in str_actions:
    arr = []
    for act in action:
        a = int(act[1:])
        arr.append(a)
    int_actions.append(arr)

# %%
dat
# str_actions
# Out:
#          id  origin_index                                              split
# 0     46GP8             0                                       [c092, c147]
# 1     N11GT             1                           [c098, c075, c127, c153]
# 2     KRF68             3         [c018, c141, c148, c006, c002, c150, c000]
# 3     MJO7C             4                                       [c015, c107]
# 4     S6MPZ             5  [c009, c011, c015, c019, c156, c059, c061, c06...
# 5     7HVU8             6         [c020, c004, c001, c144, c127, c127, c127]
# 6     MCQO5             7               [c148, c106, c000, c107, c002, c110]
# 7     VPIYF             8                                             [c015]
# 8     JSUF4             9                     [c123, c106, c102, c151, c127]
# 9     8WJIR            10  [c009, c106, c006, c154, c107, c131, c107, c15...
# 10    INQNU            11   [c107, c135, c151, c106, c152, c004, c075, c118]
# 11    LI6LV            12  [c034, c129, c106, c155, c148, c129, c001, c09...
# 12    MGCM8            13                                 [c011, c014, c059]
# 13    I8QJN            14                     [c124, c106, c154, c107, c146]
# 14    XC9EY            15               [c088, c109, c009, c118, c119, c107]
# 15    DOQ9Y            16  [c001, c006, c061, c097, c155, c081, c141, c02...
# 16    RK9II            17                                       [c012, c154]
# 17    QGQGZ            18         [c008, c104, c130, c118, c063, c061, c097]
# 18    5S1WQ            19                     [c101, c127, c102, c100, c098]
# 19    CUCBN            20                           [c154, c123, c009, c097]
# 20    SX0HE            21                           [c107, c015, c019, c106]
# 21    72JYK            22         [c048, c061, c151, c047, c052, c156, c125]
# 22    BDFDE            23                     [c059, c151, c129, c106, c107]
# 23    H6N4Z            24               [c113, c081, c015, c001, c114, c016]
# 24    OBTP8            25               [c008, c040, c096, c097, c155, c141]
# 25    4021N            26         [c040, c042, c076, c039, c041, c043, c000]
# 26    ZSHWE            27   [c034, c026, c155, c035, c033, c001, c000, c002]
# 27    SFDTP            28                     [c044, c000, c154, c033, c035]
# 28    Q5EPP            29                                       [c129, c128]
# 29    SK6FW            30                           [c098, c155, c100, c003]
# ...     ...           ...                                                ...
# 7781  9KYMU          7954                           [c040, c150, c041, c044]
# 7782  UJT87          7955                                 [c076, c015, c152]
# 7783  6U082          7956                           [c098, c150, c127, c002]
# 7784  MR3ON          7957                                 [c124, c136, c125]
# 7785  OZSB3          7958         [c076, c079, c020, c021, c059, c132, c011]
# 7786  OUH2U          7959                           [c006, c040, c020, c097]
# 7787  82R7V          7960  [c020, c152, c106, c123, c110, c063, c056, c10...
# 7788  MOQIU          7961  [c018, c019, c131, c132, c149, c123, c051, c15...
# 7789  JJZ1X          7962                           [c107, c156, c061, c011]
# 7790  XAW3U          7963                           [c090, c092, c156, c061]
# 7791  38QA4          7964         [c155, c120, c118, c107, c097, c002, c000]
# 7792  WJL39          7965                                 [c008, c096, c148]
# 7793  FPWD0          7966         [c143, c059, c011, c142, c142, c097, c130]
# 7794  L1O0N          7967         [c076, c106, c107, c155, c110, c077, c079]
# 7795  OTLX9          7968  [c052, c145, c014, c148, c011, c032, c110, c10...
# 7796  B4F0T          7969   [c128, c151, c128, c129, c154, c125, c106, c107]
# 7797  0L0KS          7970                     [c015, c018, c019, c154, c059]
# 7798  F7AIA          7971   [c065, c156, c152, c125, c059, c029, c061, c149]
# 7799  B6LRC          7972                           [c053, c056, c153, c082]
# 7800  LD011          7974                                 [c110, c030, c148]
# 7801  WPFKR          7975                           [c057, c152, c008, c113]
# 7802  WO0OM          7976               [c149, c156, c015, c017, c016, c067]
# 7803  1AA6Z          7977  [c118, c063, c155, c156, c002, c120, c061, c00...
# 7804  LV24Z          7978                                 [c047, c050, c153]
# 7805  8U3SS          7979                           [c137, c152, c149, c020]
# 7806  7K2CS          7980         [c065, c067, c153, c155, c097, c141, c156]
# 7807  S2A89          7981                           [c006, c141, c151, c097]
# 7808  01O27          7982                           [c006, c008, c124, c096]
# 7809  2MJ72          7983                           [c006, c037, c092, c033]
# 7810  PG1ID          7984               [c047, c051, c052, c100, c151, c098]
#
# [7811 rows x 3 columns]

# %%
import nltk
from nltk.corpus import brown
from nltk import WordNetLemmatizer
from math import log 

# brown = nltk.download('brown')
# wd = nltk.download('wordnet')

wnl=WordNetLemmatizer()

_Fdist = nltk.FreqDist([wnl.lemmatize(w.lower()) for w in brown.words(categories='news')])

_Sents = [[wnl.lemmatize(j.lower()) for j in i] for i in brown.sents(categories='news')]


# int_actions
def p(x):
    return _Fdist[x]/float(len(_Fdist))

def pxy(x,y):
    return (len(list(filter(lambda s :  x in s and y in s ,_Sents)))+1) / float(len(_Sents) )

def pmi(x,y):
    return  log(pxy(x,y)/(p(x)*p(y)),2)

# %%
_Fdist
# _Sents
# len(_Fdist) # 11892
# Out:
# FreqDist({'the': 6386,
#           'fulton': 14,
#           'county': 75,
#           'grand': 19,
#           'jury': 47,
#           'said': 406,
#           'friday': 41,
#           'an': 311,
#           'investigation': 12,
#           'of': 2861,
#           "atlanta's": 4,
#           'recent': 20,
#           'primary': 17,
#           'election': 44,
#           'produced': 6,
#           '``': 732,
#           'no': 121,
#           'evidence': 17,
#           "''": 702,
#           'that': 829,
#           'any': 94,
#           'irregularity': 3,
#           'took': 47,
#           'place': 38,
#           '.': 4030,
#           'further': 18,
#           'in': 2020,
#           'term-end': 1,
#           'presentment': 1,
#           'city': 99,
#           'executive': 20,
#           'committee': 81,
#           ',': 5188,
#           'which': 245,
#           'had': 281,
#           'over-all': 2,
#           'charge': 29,
#           'deserves': 3,
#           'praise': 2,
#           'and': 2186,
#           'thanks': 6,
#           'atlanta': 14,
#           'for': 969,
#           'manner': 7,
#           'wa': 717,
#           'conducted': 8,
#           'september-october': 1,
#           'term': 20,
#           'been': 212,
#           'charged': 12,
#           'by': 504,
#           'superior': 7,
#           'court': 61,
#           'judge': 44,
#           'durwood': 1,
#           'pye': 1,
#           'to': 2144,
#           'investigate': 3,
#           'report': 40,
#           'possible': 29,
#           'hard-fought': 1,
#           'won': 24,
#           'mayor-nominate': 1,
#           'ivan': 2,
#           'allen': 7,
#           'jr.': 46,
#           'only': 111,
#           'a': 2647,
#           'relative': 5,
#           'handful': 1,
#           'such': 74,
#           'received': 33,
#           'considering': 3,
#           'widespread': 4,
#           'interest': 34,
#           'number': 35,
#           'voter': 15,
#           'size': 8,
#           'this': 320,
#           'it': 656,
#           'did': 64,
#           'find': 17,
#           'many': 72,
#           "georgia's": 7,
#           'registration': 3,
#           'law': 70,
#           'are': 330,
#           'outmoded': 1,
#           'or': 174,
#           'inadequate': 4,
#           'often': 14,
#           'ambiguous': 1,
#           'recommended': 9,
#           'legislator': 13,
#           'act': 34,
#           'have': 265,
#           'these': 70,
#           'studied': 7,
#           'revised': 2,
#           'end': 34,
#           'modernizing': 1,
#           'improving': 4,
#           'them': 96,
#           'commented': 7,
#           'on': 691,
#           'other': 164,
#           'topic': 2,
#           'among': 39,
#           'purchasing': 4,
#           'department': 34,
#           'well': 45,
#           'operated': 4,
#           'follow': 13,
#           'generally': 15,
#           'accepted': 5,
#           'practice': 16,
#           'inure': 1,
#           'best': 31,
#           'both': 73,
#           'government': 79,
#           'merger': 6,
#           'proposed': 18,
#           'however': 49,
#           'belief': 17,
#           'two': 174,
#           'office': 32,
#           'should': 61,
#           'be': 527,
#           'combined': 9,
#           'achieve': 6,
#           'greater': 12,
#           'efficiency': 2,
#           'reduce': 8,
#           'cost': 35,
#           'administration': 62,
#           'is': 733,
#           'lacking': 4,
#           'experienced': 4,
#           'clerical': 4,
#           'personnel': 11,
#           'result': 35,
#           'policy': 32,
#           'urged': 12,
#           'take': 57,
#           'step': 18,
#           'remedy': 1,
#           'problem': 58,
#           'implementation': 2,
#           'automobile': 4,
#           'title': 6,
#           'also': 129,
#           'outgoing': 3,
#           'next': 41,
#           'legislature': 23,
#           'provide': 24,
#           'enabling': 5,
#           'fund': 48,
#           're-set': 1,
#           'effective': 15,
#           'date': 19,
#           'so': 81,
#           'orderly': 3,
#           'may': 103,
#           'effected': 1,
#           'swipe': 1,
#           'at': 636,
#           'state': 213,
#           'welfare': 16,
#           "department's": 2,
#           'handling': 3,
#           'federal': 52,
#           'granted': 5,
#           'child': 56,
#           'service': 79,
#           'foster': 2,
#           'home': 141,
#           'one': 221,
#           'major': 33,
#           'item': 5,
#           'general': 43,
#           'assistance': 8,
#           'program': 78,
#           'but': 283,
#           'ha': 303,
#           'seen': 7,
#           'fit': 4,
#           'distribute': 2,
#           'through': 56,
#           'all': 181,
#           'with': 567,
#           'exception': 6,
#           'receives': 1,
#           'none': 8,
#           'money': 30,
#           'juror': 8,
#           'they': 267,
#           'realize': 4,
#           'proportionate': 1,
#           'distribution': 8,
#           'might': 38,
#           'disable': 1,
#           'our': 60,
#           'le': 12,
#           'populous': 3,
#           'nevertheless': 5,
#           'we': 107,
#           'feel': 25,
#           'future': 26,
#           'receive': 15,
#           'some': 113,
#           'portion': 3,
#           'available': 10,
#           'failure': 7,
#           'do': 64,
#           'will': 389,
#           'continue': 11,
#           'disproportionate': 1,
#           'burden': 2,
#           'taxpayer': 8,
#           "ordinary's": 1,
#           'under': 91,
#           'fire': 29,
#           'appointment': 11,
#           'appraiser': 1,
#           'guardian': 2,
#           'administrator': 7,
#           'awarding': 1,
#           'fee': 20,
#           'compensation': 5,
#           'ward': 11,
#           'protected': 1,
#           'found': 30,
#           'incorporated': 1,
#           'into': 115,
#           'operating': 6,
#           'procedure': 7,
#           'recommendation': 7,
#           'previous': 11,
#           'bar': 4,
#           'association': 35,
#           'interim': 2,
#           'citizen': 12,
#           'action': 28,
#           'serve': 8,
#           'protect': 2,
#           'fact': 26,
#           'effect': 19,
#           "court's": 1,
#           'from': 353,
#           'undue': 2,
#           'appointed': 6,
#           'elected': 12,
#           'servant': 5,
#           'unmeritorious': 1,
#           'criticism': 2,
#           'regarding': 1,
#           'new': 241,
#           'multi-million-dollar': 1,
#           'airport': 7,
#           'when': 169,
#           'management': 8,
#           'jan.': 15,
#           '1': 47,
#           'eliminate': 5,
#           'political': 28,
#           'influence': 4,
#           'not': 257,
#           'elaborate': 3,
#           'added': 33,
#           'there': 189,
#           'periodic': 1,
#           'surveillance': 1,
#           'pricing': 3,
#           'concessionaire': 1,
#           'purpose': 12,
#           'keeping': 4,
#           'price': 35,
#           'reasonable': 2,
#           'ask': 8,
#           'jail': 9,
#           'deputy': 6,
#           'matter': 25,
#           ':': 149,
#           '(': 168,
#           ')': 171,
#           'four': 82,
#           'additional': 14,
#           'employed': 5,
#           'doctor': 7,
#           'medical': 19,
#           'intern': 1,
#           'extern': 1,
#           'night': 66,
#           'weekend': 12,
#           'duty': 4,
#           '2': 33,
#           'work': 76,
#           'official': 31,
#           'pas': 15,
#           'legislation': 14,
#           'permit': 10,
#           'establishment': 7,
#           'fair': 13,
#           'equitable': 1,
#           'pension': 7,
#           'plan': 68,
#           'employes': 11,
#           'praised': 3,
#           'operation': 26,
#           'police': 40,
#           'tax': 68,
#           "commissioner's": 1,
#           'bellwood': 1,
#           'alpharetta': 1,
#           'prison': 7,
#           'farm': 25,
#           'grady': 5,
#           'hospital': 43,
#           'health': 19,
#           'mayor': 19,
#           'william': 36,
#           'b.': 31,
#           'hartsfield': 5,
#           'filed': 7,
#           'suit': 10,
#           'divorce': 3,
#           'his': 428,
#           'wife': 35,
#           'pearl': 3,
#           'williams': 14,
#           'petition': 13,
#           'mental': 1,
#           'cruelty': 1,
#           'couple': 15,
#           'married': 8,
#           'aug.': 8,
#           '1913': 2,
#           'son': 29,
#           'berry': 5,
#           'daughter': 31,
#           'mrs.': 253,
#           'j.': 42,
#           'm.': 22,
#           'cheshire': 1,
#           'griffin': 2,
#           'attorney': 32,
#           'amicable': 1,
#           'property': 18,
#           'settlement': 3,
#           'agreed': 15,
#           'upon': 23,
#           'listed': 11,
#           "mayor's": 6,
#           'occupation': 4,
#           'age': 13,
#           '71': 4,
#           "wife's": 1,
#           '74': 3,
#           'birth': 5,
#           'opelika': 1,
#           'ala.': 7,
#           'lived': 3,
#           'together': 27,
#           'man': 74,
#           'more': 183,
#           'than': 138,
#           'year': 244,
#           '637': 1,
#           'e.': 34,
#           'pelham': 5,
#           'rd.': 3,
#           'aj': 14,
#           'henry': 18,
#           'l.': 25,
#           'bowden': 2,
#           'brief': 3,
#           'interlude': 1,
#           'since': 67,
#           '1937': 2,
#           'career': 13,
#           'go': 47,
#           'back': 75,
#           'council': 37,
#           '1923': 2,
#           'present': 31,
#           'expires': 1,
#           'he': 642,
#           'succeeded': 3,
#           'who': 268,
#           'became': 20,
#           'candidate': 27,
#           'sept.': 6,
#           '13': 16,
#           'after': 151,
#           'announced': 37,
#           'would': 246,
#           'run': 65,
#           'reelection': 1,
#           'georgia': 18,
#           'republican': 41,
#           'getting': 18,
#           'strong': 14,
#           'encouragement': 5,
#           'enter': 5,
#           '1962': 5,
#           "governor's": 5,
#           'race': 23,
#           'top': 35,
#           'wednesday': 22,
#           'robert': 31,
#           'snodgrass': 1,
#           'gop': 5,
#           'chairman': 46,
#           'meeting': 67,
#           'held': 43,
#           'tuesday': 43,
#           'blue': 23,
#           'ridge': 3,
#           'brought': 21,
#           'enthusiastic': 3,
#           'response': 7,
#           'audience': 12,
#           'party': 57,
#           'james': 37,
#           'w.': 39,
#           'dorsey': 1,
#           'enthusiasm': 3,
#           'picking': 1,
#           'up': 168,
#           'rally': 4,
#           '8': 22,
#           'savannah': 1,
#           'newly': 6,
#           'texas': 48,
#           'sen.': 18,
#           'john': 66,
#           'tower': 4,
#           'featured': 3,
#           'speaker': 10,
#           'warned': 2,
#           'entering': 5,
#           'governor': 19,
#           'force': 36,
#           'out': 162,
#           'voting': 7,
#           'precinct': 9,
#           'obtain': 8,
#           'signature': 6,
#           'registered': 2,
#           'despite': 16,
#           'warning': 5,
#           'unanimous': 2,
#           'vote': 35,
#           'according': 23,
#           'attended': 10,
#           'crowd': 11,
#           'asked': 39,
#           'whether': 18,
#           'wanted': 20,
#           'wait': 4,
#           'make': 55,
#           'voted': 9,
#           '--': 300,
#           'were': 252,
#           'dissent': 2,
#           'largest': 10,
#           'hurdle': 1,
#           'face': 23,
#           'say': 51,
#           'before': 93,
#           'making': 25,
#           'first': 158,
#           'alternative': 5,
#           'course': 30,
#           'must': 53,
#           'taken': 30,
#           'five': 45,
#           'per': 61,
#           'cent': 55,
#           'each': 74,
#           'sign': 12,
#           'requesting': 1,
#           'allowed': 8,
#           'name': 21,
#           'ballot': 9,
#           'hold': 15,
#           'unit': 19,
#           'system': 57,
#           'opposes': 2,
#           'platform': 2,
#           'sam': 13,
#           'caldwell': 2,
#           'highway': 16,
#           'public': 58,
#           'relation': 21,
#           'director': 39,
#           'resigned': 5,
#           'lt.': 1,
#           'gov.': 10,
#           'garland': 3,
#           "byrd's": 1,
#           'campaign': 17,
#           "caldwell's": 1,
#           'resignation': 4,
#           'expected': 40,
#           'time': 123,
#           'rob': 1,
#           'ledford': 1,
#           'gainesville': 1,
#           'assistant': 13,
#           'three': 101,
#           'gubernatorial': 6,
#           'start': 39,
#           'become': 23,
#           'coordinator': 5,
#           'byrd': 1,
#           'wind': 7,
#           '1961': 42,
#           'session': 43,
#           'monday': 54,
#           'head': 27,
#           'where': 59,
#           'bond': 41,
#           'approved': 8,
#           'shortly': 7,
#           'adjournment': 2,
#           'afternoon': 20,
#           'senate': 34,
#           'approve': 2,
#           'study': 16,
#           'allotted': 2,
#           'rural': 11,
#           'urban': 4,
#           'area': 52,
#           'determine': 3,
#           'what': 95,
#           'adjustment': 3,
#           'made': 107,
#           'vandiver': 4,
#           'traditional': 8,
#           'visit': 8,
#           'chamber': 6,
#           'toward': 23,
#           'likely': 7,
#           'mention': 7,
#           '$100': 7,
#           'million': 54,
#           'issue': 40,
#           'earlier': 25,
#           'priority': 4,
#           'construction': 16,
#           'meanwhile': 7,
#           'learned': 7,
#           'very': 35,
#           'near': 16,
#           'being': 57,
#           'ready': 12,
#           '$30': 1,
#           'worth': 18,
#           'reconstruction': 2,
#           'friendly': 3,
#           'test': 19,
#           'validity': 1,
#           'then': 73,
#           'sale': 60,
#           'begin': 13,
#           'contract': 16,
#           'let': 11,
#           'repair': 3,
#           'most': 81,
#           'heavily': 5,
#           'traveled': 2,
#           'source': 8,
#           '$3': 1,
#           '$4': 1,
#           'road': 29,
#           'authority': 19,
#           'revolving': 3,
#           'apparently': 15,
#           'intends': 1,
#           'issued': 8,
#           'every': 28,
#           'old': 34,
#           'paid': 25,
#           'off': 73,
#           'opened': 9,
#           '1958': 19,
#           'battle': 18,
#           'against': 78,
#           'issuance': 2,
#           '$50': 2,
#           'marvin': 2,
#           'told': 53,
#           'constitution': 5,
#           'consulted': 4,
#           'yet': 17,
#           'about': 147,
#           'schley': 1,
#           'rep.': 10,
#           'd.': 24,
#           'offer': 14,
#           'resolution': 21,
#           'house': 104,
#           'rescind': 2,
#           "body's": 1,
#           'itself': 10,
#           '$10': 3,
#           'day': 116,
#           'increase': 29,
#           'expense': 14,
#           'allowance': 5,
#           'sunday': 51,
#           'research': 19,
#           'done': 24,
#           'quickie': 1,
#           'can': 94,
#           'repealed': 1,
#           'outright': 3,
#           'notice': 6,
#           'given': 38,
#           'reconsideration': 2,
#           'sought': 6,
#           'while': 55,
#           'emphasizing': 1,
#           'technical': 7,
#           'detail': 6,
#           'fully': 6,
#           'worked': 12,
#           'seek': 15,
#           'set': 52,
#           'aside': 5,
#           'privilege': 6,
#           '87-31': 1,
#           'similar': 18,
#           'passed': 18,
#           '29-5': 1,
#           'word': 24,
#           'offered': 11,
#           'pointed': 9,
#           'last': 177,
#           'november': 10,
#           'rejected': 8,
#           'constitutional': 8,
#           'amendment': 6,
#           'allow': 5,
#           'pay': 37,
#           'raise': 11,
#           'veteran': 11,
#           'jackson': 5,
#           'aid': 31,
#           'education': 46,
#           'something': 16,
#           'consistently': 1,
#           'opposed': 9,
#           'past': 35,
#           'mac': 1,
#           'barber': 6,
#           'commerce': 10,
#           'asking': 5,
#           'endorse': 3,
#           'increased': 10,
#           'support': 25,
#           'provided': 8,
#           'expended': 1,
#           '13th': 5,
#           'member': 109,
#           'congressional': 9,
#           'delegation': 4,
#           'washington': 48,
#           'like': 50,
#           'see': 42,
#           'congressman': 7,
#           'specifically': 1,
#           'him': 93,
#           'tossed': 1,
#           'hopper': 1,
#           'formally': 7,
#           'read': 16,
#           'event': 19,
#           'congress': 22,
#           'doe': 26,
#           'board': 67,
#           'directed': 8,
#           'give': 37,
#           'teacher': 17,
#           'colquitt': 2,
#           'long': 46,
#           'hot': 9,
#           'controversy': 5,
#           'miller': 3,
#           'school': 125,
#           'superintendent': 9,
#           'policeman': 8,
#           'put': 29,
#           'coolest': 2,
#           'i': 179,
#           'ever': 32,
#           'saw': 19,
#           'harry': 10,
#           'davis': 13,
#           'agriculture': 5,
#           'defeated': 5,
#           'felix': 2,
#           'bush': 5,
#           'principal': 12,
#           'democratic': 38,
#           '1,119': 1,
#           "saturday's": 2,
#           'got': 45,
#           '402': 1,
#           'ordinary': 9,
#           'carey': 5,
#           'armed': 11,
#           'pistol': 3,
#           'stood': 4,
#           'poll': 9,
#           'insure': 2,
#           'order': 29,
#           'calmest': 1,
#           'tom': 6,
#           'just': 49,
#           'church': 46,
#           "didn't": 15,
#           'smell': 2,
#           'drop': 7,
#           'liquor': 5,
#           'bit': 7,
#           'trouble': 14,
#           'leading': 12,
#           'quiet': 5,
#           'marked': 4,
#           'anonymous': 4,
#           'midnight': 4,
#           'phone': 6,
#           'call': 29,
#           'veiled': 3,
#           'threat': 9,
#           'violence': 3,
#           'former': 28,
#           'george': 23,
#           'p.': 18,
#           'callan': 1,
#           'shot': 18,
#           'himself': 21,
#           'death': 10,
#           'march': 40,
#           '18': 20,
#           'post': 19,
#           'dispute': 4,
#           'during': 60,
#           'reportedly': 4,
#           'telephone': 8,
#           'too': 37,
#           'subjected': 2,
#           'soon': 17,
#           'scheduled': 14,
#           'local': 45,
#           'feared': 1,
#           'carry': 16,
#           'gun': 4,
#           'promised': 4,
#           'sheriff': 5,
#           'tabb': 1,
#           'good': 56,
#           'promise': 6,
#           'everything': 5,
#           'went': 37,
#           'real': 24,
#           'smooth': 1,
#           "wasn't": 3,
#           'austin': 15,
#           'approval': 8,
#           "daniel's": 1,
#           'abandoned': 3,
#           'seemed': 12,
#           'certain': 19,
#           'thursday': 20,
#           'adamant': 2,
#           'protest': 2,
#           'banker': 12,
#           'daniel': 5,
#           'personally': 3,
#           'led': 18,
#           'fight': 14,
#           'measure': 16,
#           'watered': 1,
#           'down': 51,
#           'considerably': 5,
#           'rejection': 3,
#           'hearing': 17,
#           'revenue': 21,
#           'taxation': 2,
#           'rule': 40,
#           'automatically': 3,
#           'subcommittee': 1,
#           'week': 120,
#           'question': 31,
#           'taunted': 1,
#           'appearing': 1,
#           'witness': 11,
#           'left': 39,
#           'little': 38,
#           'doubt': 6,
#           'recommend': 4,
#           'passage': 5,
#           'termed': 4,
#           'extremely': 2,
#           'conservative': 7,
#           'estimate': 7,
#           'produce': 8,
#           '17': 14,
#           'dollar': 21,
#           'help': 33,
#           'erase': 1,
#           'anticipated': 5,
#           'deficit': 1,
#           '63': 1,
#           'current': 13,
#           'fiscal': 5,
#           '31': 6,
#           'merely': 15,
#           'mean': 26,
#           'enforcing': 1,
#           'escheat': 2,
#           'book': 30,
#           'republic': 4,
#           'over': 119,
#           'bank': 21,
#           'account': 12,
#           'stock': 37,
#           'personal': 12,
#           'person': 36,
#           'missing': 3,
#           'seven': 17,
#           'bill': 87,
#           'drafted': 1,
#           'insurance': 5,
#           'firm': 47,
#           'pipeline': 2,
#           'company': 70,
#           'corporation': 12,
#           'treasurer': 6,
#           'cannot': 15,
#           'enforced': 3,
#           'now': 87,
#           'because': 55,
#           'almost': 25,
#           'impossible': 4,
#           'locate': 1,
#           'declared': 15,
#           'dewey': 1,
#           'lawrence': 12,
#           'tyler': 2,
#           'lawyer': 12,
#           'representing': 8,
#           'sounded': 1,
#           'opposition': 9,
#           'keynote': 3,
#           'violate': 2,
#           'their': 231,
#           'contractual': 1,
#           'obligation': 5,
#           'depositor': 1,
#           'undermine': 1,
#           'confidence': 6,
#           'customer': 7,
#           'if': 103,
#           'you': 66,
#           'destroy': 5,
#           'economy': 9,
#           'circulation': 2,
#           'charles': 22,
#           'hughes': 22,
#           'sherman': 9,
#           'sponsor': 5,
#           'enact': 1,
#           'amount': 21,
#           'gift': 9,
#           "taxpayers'": 2,
#           'pocket': 3,
#           'contention': 2,
#           'denied': 5,
#           'several': 39,
#           'including': 25,
#           'scott': 3,
#           'hudson': 2,
#           'gaynor': 1,
#           'jones': 22,
#           'houston': 15,
#           'brady': 1,
#           'harlingen': 1,
#           'howard': 13,
#           'cox': 4,
#           'argued': 7,
#           'probably': 20,
#           'unconstitutional': 1,
#           'impair': 1,
#           'complained': 4,
#           'enough': 27,
#           'introduced': 10,
#           'senator': 22,
#           'unanimously': 2,
#           'parkhouse': 5,
#           'dallas': 49,
#           'authorizing': 2,
#           'deaf': 6,
#           'designed': 16,
#           'special': 42,
#           'schooling': 2,
#           'student': 45,
#           'scholastic': 3,
#           'reduced': 6,
#           'debate': 10,
#           'authorize': 2,
#           'agency': 21,
#           'establish': 8,
#           'county-wide': 2,
#           '300,000': 1,
#           'population': 13,
#           'require': 5,
#           'between': 48,
#           '6': 16,
#           'attend': 17,
#           'permitting': 2,
#           'older': 3,
#           'residential': 8,
#           'here': 72,
#           'budget': 12,
#           'harris': 8,
#           'bexar': 1,
#           'tarrant': 1,
#           'el': 12,
#           'paso': 9,
#           '$451,500': 1,
#           'saving': 11,
#           '$157,460': 1,
#           'yearly': 2,
#           "year's": 14,
#           'capital': 6,
#           'outlay': 3,
#           '$88,000': 1,
#           'absorbed': 4,
#           'tea': 5,
#           'estimated': 14,
#           '182': 1,
#           'coming': 19,
#           'live': 15,
#           'get': 77,
#           'hear': 12,
#           'horse': 3,
#           'parimutuel': 1,
#           'reps.': 2,
#           'v.': 6,
#           'red': 11,
#           'joe': 10,
#           'ratcliff': 3,
#           'still': 38,
#           'expects': 6,
#           'tell': 18,
#           'folk': 3,
#           'why': 14,
#           'think': 30,
#           "berry's": 1,
#           "we're": 7,
#           "'": 46,
#           'pro': 8,
#           'letter': 20,
#           'con': 1,
#           'betting': 2,
#           'believe': 12,
#           'people': 57,
#           'better': 29,
#           'informed': 9,
#           'oppose': 5,
#           "i'm": 18,
#           'willing': 7,
#           'stake': 2,
#           'my': 43,
#           'ex-gambler': 1,
#           'san': 22,
#           'antonio': 4,
#           'advocacy': 1,
#           'pony': 1,
#           'heard': 15,
#           'option': 2,
#           'proposal': 23,
#           'favorable': 6,
#           'although': 22,
#           'hard': 11,
#           'sledding': 1,
#           'later': 37,
#           'finally': 5,
#           'sent': 17,
#           'extending': 6,
#           'planning': 11,
#           'quickly': 6,
#           'whipped': 2,
#           'meager': 1,
#           'fare': 2,
#           'passing': 12,
#           ...})

# %%
p('new')
# Out:
# 0.020265724857046755

# %%
p('york')
# Out:
# 0.004372687521022536

# %%
pmi('new','the')
# Out:
# 1.8863664858873235

# %%
join_str = []
for it in str_actions:
    for s in it:
        join_str.append(s)
        
# join_str

# %%
import nltk
from nltk.corpus import brown
from nltk import WordNetLemmatizer
from math import log 

# brown = nltk.download('brown')
# wd = nltk.download('wordnet')

wnl=WordNetLemmatizer()
# lemmatize 詞型還原

_Fdist = nltk.FreqDist([wnl.lemmatize(w.lower()) for w in join_str])

_Sents = [[wnl.lemmatize(j.lower()) for j in i] for i in str_actions]

# int_actions
def p(x):
    return _Fdist[x]/ float(sum(_Fdist.values())) #float(len(_Fdist))

def pxy(x,y):
    return (len(list(filter(lambda s :  x in s and y in s ,_Sents)))+1) / float(len(_Sents) )

def pmi(x,y):
    return  log(pxy(x,y)/(p(x)*p(y)),2)

# %%
# _Fdist
# _Sents

# %%
# c000 Holding some clothes
# c001 Putting clothes somewhere
print(p('c000'))
print(p('c001'))
print(pxy('c000', 'c001'))
print(pmi('c000', 'c001'))
# Out:
# 0.012748700034130377
# 0.01284908349896605
# 0.04058379208808091
# 7.952744260921994

# %%
# c059 Sitting in a chair
# c011 Sitting at a table
print(p('c059'))
print(p('c011'))
print(pxy('c059', 'c011'))
print(pmi('c059', 'c011'))
# Out:
# 0.025296633138589413
# 0.014615832480073882
# 0.06734092945845602
# 7.508862438035805

# %%
# c057 Taking off some shoes
# c065 Eating a sandwich
print(p('c057'))
print(p('c065'))
print(pxy('c057', 'c065'))
print(pmi('c057', 'c065'))
# Out:
# 0.003935031821558353
# 0.009215202071914714
# 0.00038407374215849446
# 3.404848420521618
