# %%
import os
import pandas as pd
import numpy as np
import sklearn
import csv

# %%
df = pd.read_csv('Charades_v1_train.csv')
# df.head()

# %%
print(df.shape)
df = df[pd.notnull(df['actions'])] # drop NA in column['actions']
print(df.shape)

# df = df[df.quality >=6 ]
# df = df[df.relevance == 7] #  和 script 的相關性，但我們不需要管 script ，所以用不到
df['origin_index'] = df.index.values
# df.head()
# Out:
# (7985, 11)
# (7811, 11)

# %%
df = df.reset_index(drop=True)
# df.head()

# %%
dat_id = df['id']
dat_actions = df['actions']
dat_origin_index = df['origin_index']
dat = pd.concat([dat_id, dat_origin_index, dat_actions], axis=1)
split_arr = dat['actions'].str.split(';')

# %%
large_arr = []
for element in enumerate(split_arr):
    arr = []
    time = []
    for i in element[1]:
        k = i.split(" ")
        d = k[0]
        t = k[1]
        arr.append(d)
        time.append(t)
#     print(arr)
#     print(time)
    arr = [x for _,x in sorted(zip(time,arr))]
#     print(arr)
    large_arr.append(arr)
dat['split'] = large_arr

# %%
dat = dat.drop('actions', 1)

# %%
str_actions = dat['split']
int_actions = []
for action in str_actions:
    arr = []
    for act in action:
        a = int(act[1:])
        arr.append(a)
    int_actions.append(arr)

# %%
# dat

# %%
join_str = []
for it in str_actions:
    for s in it:
        join_str.append(s)
        
# join_str

# %%
import nltk
from nltk.corpus import brown
from nltk import WordNetLemmatizer
from math import log 

# brown = nltk.download('brown')
# wd = nltk.download('wordnet')

wnl=WordNetLemmatizer()
# lemmatize 詞型還原

_Fdist = nltk.FreqDist([wnl.lemmatize(w.lower()) for w in join_str])

_Sents = [[wnl.lemmatize(j.lower()) for j in i] for i in str_actions]

MAX_DISTANCE = 100000 # 只有這兩個動作距離 = 1，這筆 video 才算數。

def inSents(x, y):
    c = 0
    l = []
    for s in _Sents:
        
#         first method:
        index1 = 0
        index2 = 0
        bool1 = False
        bool2 = False
        k = 0
        for index, st in enumerate(s):    
            if x == st and not bool1:
                k += 1
                index1 = index
                bool1 = True
            if y == st and not bool2:
                k += 1
                index2 = index  
                bool2 = True
        if k == 2: # x in s and y in s
            if abs(index1 - index2) < MAX_DISTANCE: # i.e 必定為 1 
                l.append(s)
                
#         second method:
#         if x in s and y in s:
#             l.append(s)
        
    return l

# int_actions
def p(x):
    return _Fdist[x]/ float(sum(_Fdist.values())) #float(len(_Fdist))
    

def pxy(x,y):
    return (len(inSents(x,y)) + 1) / float(len(_Sents) )

def pmi(x,y):
    return  log(pxy(x,y)/(p(x)*p(y)),2)

# %%
_Fdist
# _Sents
# Out:
# FreqDist({'c000': 635,
#           'c001': 640,
#           'c002': 479,
#           'c003': 303,
#           'c004': 266,
#           'c005': 81,
#           'c006': 618,
#           'c007': 27,
#           'c008': 784,
#           'c009': 879,
#           'c010': 46,
#           'c011': 728,
#           'c012': 202,
#           'c013': 42,
#           'c014': 241,
#           'c015': 1055,
#           'c016': 673,
#           'c017': 219,
#           'c018': 298,
#           'c019': 217,
#           'c020': 678,
#           'c021': 356,
#           'c022': 280,
#           'c023': 278,
#           'c024': 89,
#           'c025': 187,
#           'c026': 615,
#           'c027': 280,
#           'c028': 248,
#           'c029': 92,
#           'c030': 257,
#           'c031': 58,
#           'c032': 483,
#           'c033': 575,
#           'c034': 276,
#           'c035': 286,
#           'c036': 154,
#           'c037': 125,
#           'c038': 232,
#           'c039': 96,
#           'c040': 331,
#           'c041': 181,
#           'c042': 201,
#           'c043': 180,
#           'c044': 154,
#           'c045': 34,
#           'c046': 100,
#           'c047': 259,
#           'c048': 99,
#           'c049': 91,
#           'c050': 82,
#           'c051': 347,
#           'c052': 341,
#           'c053': 233,
#           'c054': 177,
#           'c055': 162,
#           'c056': 160,
#           'c057': 196,
#           'c058': 73,
#           'c059': 1260,
#           'c060': 46,
#           'c061': 1075,
#           'c062': 495,
#           'c063': 683,
#           'c064': 52,
#           'c065': 459,
#           'c066': 29,
#           'c067': 400,
#           'c068': 154,
#           'c069': 161,
#           'c070': 443,
#           'c071': 205,
#           'c072': 323,
#           'c073': 200,
#           'c074': 105,
#           'c075': 139,
#           'c076': 385,
#           'c077': 171,
#           'c078': 159,
#           'c079': 161,
#           'c080': 134,
#           'c081': 503,
#           'c082': 228,
#           'c083': 74,
#           'c084': 133,
#           'c085': 28,
#           'c086': 62,
#           'c087': 231,
#           'c088': 198,
#           'c089': 53,
#           'c090': 87,
#           'c091': 39,
#           'c092': 305,
#           'c093': 94,
#           'c094': 111,
#           'c095': 37,
#           'c096': 449,
#           'c097': 1444,
#           'c098': 364,
#           'c099': 100,
#           'c100': 127,
#           'c101': 25,
#           'c102': 237,
#           'c103': 36,
#           'c104': 207,
#           'c105': 189,
#           'c106': 1134,
#           'c107': 1014,
#           'c108': 276,
#           'c109': 481,
#           'c110': 536,
#           'c111': 49,
#           'c112': 410,
#           'c113': 595,
#           'c114': 218,
#           'c115': 324,
#           'c116': 168,
#           'c117': 175,
#           'c118': 763,
#           'c119': 452,
#           'c120': 375,
#           'c121': 112,
#           'c122': 160,
#           'c123': 484,
#           'c124': 168,
#           'c125': 395,
#           'c126': 308,
#           'c127': 478,
#           'c128': 282,
#           'c129': 162,
#           'c130': 207,
#           'c131': 46,
#           'c132': 353,
#           'c133': 98,
#           'c134': 257,
#           'c135': 315,
#           'c136': 35,
#           'c137': 213,
#           'c138': 57,
#           'c139': 81,
#           'c140': 31,
#           'c141': 506,
#           'c142': 192,
#           'c143': 250,
#           'c144': 165,
#           'c145': 237,
#           'c146': 245,
#           'c147': 338,
#           'c148': 332,
#           'c149': 588,
#           'c150': 357,
#           'c151': 964,
#           'c152': 1029,
#           'c153': 643,
#           'c154': 1341,
#           'c155': 395,
#           'c156': 936})

# %%
# c000 Holding some clothes
# c001 Putting clothes somewhere
print(p('c000'))
print(p('c001'))
print(pxy('c000', 'c001')) # 0.0405
print(pmi('c000', 'c001'))
# Out:
# 0.012748700034130377
# 0.01284908349896605
# 0.04058379208808091
# 7.952744260921994

# %%
# c059 Sitting in a chair
# c011 Sitting at a table
print(p('c059'))
print(p('c011'))
print(pxy('c059', 'c011')) #0.0684
print(pmi('c059', 'c011'))
# Out:
# 0.025296633138589413
# 0.014615832480073882
# 0.06734092945845602
# 7.508862438035805

# %%
# c057 Taking off some shoes
# c065 Eating a sandwich
print(p('c057'))
print(p('c065'))
print(pxy('c057', 'c065'))
print(pmi('c057', 'c065'))
# Out:
# 0.003935031821558353
# 0.009215202071914714
# 0.00038407374215849446
# 3.404848420521618

# %%
classes_raw = open('Charades_v1_classes.txt', 'r')
classes = []
for i in classes_raw.readlines():
    arr = i.split(' ', 1)
    classes.append(arr)
# classes[0][0]
# len(classes) # 157x2, c000 to c156

# %%
two = []
two_pmi = []
for i in range(0, 157):
    for j in range(i+1, 157):
        arr = [classes[i], classes[j]]
        two.append(arr)
        two_pmi.append(pmi(classes[i][0], classes[j][0]))

# %%
print(len(two_pmi))
two_dim = np.zeros((157, 157))
k = 0
for i in range(0, 157):
    for j in range(i+1, 157):
        two_dim[j][i] = two_pmi[k]
        k += 1
print(two_dim)
import matplotlib.pyplot as plt
# %matplotlib inline

arr = np.array(two_dim)
plt.imshow(arr, interpolation=None)
plt.savefig('class.png', dpi=1000)
plt.show()
# Out:
# 12246
# [[ 0.          0.          0.         ...,  0.          0.          0.        ]
#  [ 7.95274426  0.          0.         ...,  0.          0.          0.        ]
#  [ 8.16048356  7.9699994   0.         ...,  0.          0.          0.        ]
#  ...,
#  [ 5.0690929   5.04165792  5.44340236 ...,  0.          0.          0.        ]
#  [ 7.40671367  7.92922201  7.37671204 ...,  4.90599993  0.          0.        ]
#  [ 4.18343145  3.78509301  4.40959014 ...,  5.28427441  4.58822747  0.        ]]

# %%
two = [x for _,x in sorted(zip(two_pmi,two), reverse=True)]
two_pmi = sorted(two_pmi, reverse=True)

# %%
two = np.array(two)
print(two.shape)
two_pmi = np.array(two_pmi)
print(two_pmi.shape)
tmp = two.reshape(-1, 4)
print(tmp.shape)
mypmi = np.column_stack((tmp, two_pmi))
# Out:
# (12246, 2, 2)
# (12246,)
# (12246, 4)

# %%
result = pd.DataFrame(mypmi, columns={"1st class":0,"1st class name":1,"2nd class":2,"2nd class name":3,"pointwise mutual info":4})

# %%
_Fdist
# Out:
# FreqDist({'c000': 635,
#           'c001': 640,
#           'c002': 479,
#           'c003': 303,
#           'c004': 266,
#           'c005': 81,
#           'c006': 618,
#           'c007': 27,
#           'c008': 784,
#           'c009': 879,
#           'c010': 46,
#           'c011': 728,
#           'c012': 202,
#           'c013': 42,
#           'c014': 241,
#           'c015': 1055,
#           'c016': 673,
#           'c017': 219,
#           'c018': 298,
#           'c019': 217,
#           'c020': 678,
#           'c021': 356,
#           'c022': 280,
#           'c023': 278,
#           'c024': 89,
#           'c025': 187,
#           'c026': 615,
#           'c027': 280,
#           'c028': 248,
#           'c029': 92,
#           'c030': 257,
#           'c031': 58,
#           'c032': 483,
#           'c033': 575,
#           'c034': 276,
#           'c035': 286,
#           'c036': 154,
#           'c037': 125,
#           'c038': 232,
#           'c039': 96,
#           'c040': 331,
#           'c041': 181,
#           'c042': 201,
#           'c043': 180,
#           'c044': 154,
#           'c045': 34,
#           'c046': 100,
#           'c047': 259,
#           'c048': 99,
#           'c049': 91,
#           'c050': 82,
#           'c051': 347,
#           'c052': 341,
#           'c053': 233,
#           'c054': 177,
#           'c055': 162,
#           'c056': 160,
#           'c057': 196,
#           'c058': 73,
#           'c059': 1260,
#           'c060': 46,
#           'c061': 1075,
#           'c062': 495,
#           'c063': 683,
#           'c064': 52,
#           'c065': 459,
#           'c066': 29,
#           'c067': 400,
#           'c068': 154,
#           'c069': 161,
#           'c070': 443,
#           'c071': 205,
#           'c072': 323,
#           'c073': 200,
#           'c074': 105,
#           'c075': 139,
#           'c076': 385,
#           'c077': 171,
#           'c078': 159,
#           'c079': 161,
#           'c080': 134,
#           'c081': 503,
#           'c082': 228,
#           'c083': 74,
#           'c084': 133,
#           'c085': 28,
#           'c086': 62,
#           'c087': 231,
#           'c088': 198,
#           'c089': 53,
#           'c090': 87,
#           'c091': 39,
#           'c092': 305,
#           'c093': 94,
#           'c094': 111,
#           'c095': 37,
#           'c096': 449,
#           'c097': 1444,
#           'c098': 364,
#           'c099': 100,
#           'c100': 127,
#           'c101': 25,
#           'c102': 237,
#           'c103': 36,
#           'c104': 207,
#           'c105': 189,
#           'c106': 1134,
#           'c107': 1014,
#           'c108': 276,
#           'c109': 481,
#           'c110': 536,
#           'c111': 49,
#           'c112': 410,
#           'c113': 595,
#           'c114': 218,
#           'c115': 324,
#           'c116': 168,
#           'c117': 175,
#           'c118': 763,
#           'c119': 452,
#           'c120': 375,
#           'c121': 112,
#           'c122': 160,
#           'c123': 484,
#           'c124': 168,
#           'c125': 395,
#           'c126': 308,
#           'c127': 478,
#           'c128': 282,
#           'c129': 162,
#           'c130': 207,
#           'c131': 46,
#           'c132': 353,
#           'c133': 98,
#           'c134': 257,
#           'c135': 315,
#           'c136': 35,
#           'c137': 213,
#           'c138': 57,
#           'c139': 81,
#           'c140': 31,
#           'c141': 506,
#           'c142': 192,
#           'c143': 250,
#           'c144': 165,
#           'c145': 237,
#           'c146': 245,
#           'c147': 338,
#           'c148': 332,
#           'c149': 588,
#           'c150': 357,
#           'c151': 964,
#           'c152': 1029,
#           'c153': 643,
#           'c154': 1341,
#           'c155': 395,
#           'c156': 936})

# %%
_Sents
# Out:
# [['c147', 'c092'],
#  ['c075', 'c127', 'c153', 'c098'],
#  ['c150', 'c148', 'c018', 'c141', 'c006', 'c000', 'c002'],
#  ['c015', 'c107'],
#  ['c009',
#   'c011',
#   'c015',
#   'c017',
#   'c019',
#   'c059',
#   'c061',
#   'c063',
#   'c156',
#   'c061'],
#  ['c001', 'c020', 'c127', 'c127', 'c004', 'c144', 'c127'],
#  ['c002', 'c000', 'c110', 'c107', 'c106', 'c148'],
#  ['c015'],
#  ['c102', 'c127', 'c151', 'c123', 'c106'],
#  ['c107',
#   'c132',
#   'c151',
#   'c135',
#   'c110',
#   'c106',
#   'c107',
#   'c009',
#   'c131',
#   'c152',
#   'c109',
#   'c154',
#   'c006'],
#  ['c004', 'c075', 'c107', 'c152', 'c135', 'c151', 'c106', 'c118'],
#  ['c001', 'c002', 'c034', 'c148', 'c129', 'c155', 'c096', 'c129', 'c106'],
#  ['c011', 'c014', 'c059'],
#  ['c124', 'c107', 'c106', 'c154', 'c146'],
#  ['c107', 'c118', 'c109', 'c119', 'c009', 'c088'],
#  ['c155',
#   'c023',
#   'c063',
#   'c061',
#   'c063',
#   'c081',
#   'c097',
#   'c020',
#   'c006',
#   'c141',
#   'c000',
#   'c001'],
#  ['c012', 'c154'],
#  ['c008', 'c097', 'c104', 'c130', 'c118', 'c061', 'c063'],
#  ['c101', 'c100', 'c098', 'c102', 'c127'],
#  ['c123', 'c097', 'c009', 'c154'],
#  ['c015', 'c106', 'c107', 'c019'],
#  ['c061', 'c151', 'c047', 'c125', 'c156', 'c048', 'c052'],
#  ['c107', 'c129', 'c106', 'c151', 'c059'],
#  ['c015', 'c016', 'c113', 'c114', 'c001', 'c081'],
#  ['c097', 'c040', 'c141', 'c008', 'c096', 'c155'],
#  ['c076', 'c039', 'c000', 'c042', 'c043', 'c040', 'c041'],
#  ['c026', 'c033', 'c035', 'c034', 'c155', 'c002', 'c001', 'c000'],
#  ['c154', 'c035', 'c033', 'c044', 'c000'],
#  ['c128', 'c129'],
#  ['c155', 'c098', 'c100', 'c003'],
#  ['c014', 'c051', 'c052', 'c061', 'c063', 'c156'],
#  ['c009', 'c118', 'c107', 'c106', 'c106'],
#  ['c059',
#   'c119',
#   'c132',
#   'c055',
#   'c063',
#   'c120',
#   'c118',
#   'c061',
#   'c156',
#   'c062'],
#  ['c092', 'c087', 'c097', 'c015'],
#  ['c120', 'c118', 'c119', 'c138', 'c137', 'c127', 'c121'],
#  ['c122',
#   'c122',
#   'c123',
#   'c065',
#   'c106',
#   'c156',
#   'c061',
#   'c063',
#   'c067',
#   'c069',
#   'c107'],
#  ['c073', 'c072', 'c057'],
#  ['c097', 'c155', 'c072', 'c073', 'c102', 'c100', 'c127', 'c001'],
#  ['c030',
#   'c032',
#   'c026',
#   'c009',
#   'c028',
#   'c154',
#   'c141',
#   'c008',
#   'c097',
#   'c006'],
#  ['c015', 'c016', 'c152', 'c062', 'c061', 'c156', 'c023', 'c020', 'c097'],
#  ['c026', 'c030', 'c032', 'c029', 'c025', 'c152', 'c149', 'c027'],
#  ['c015', 'c017', 'c020', 'c150', 'c065', 'c069', 'c021', 'c156', 'c067'],
#  ['c072', 'c132', 'c061', 'c156', 'c123', 'c151', 'c155', 'c073', 'c070'],
#  ['c017', 'c128', 'c087', 'c128', 'c107', 'c015', 'c129', 'c018'],
#  ['c011',
#   'c059',
#   'c063',
#   'c009',
#   'c017',
#   'c156',
#   'c018',
#   'c062',
#   'c015',
#   'c020'],
#  ['c011',
#   'c014',
#   'c026',
#   'c027',
#   'c032',
#   'c051',
#   'c059',
#   'c115',
#   'c145',
#   'c116',
#   'c126',
#   'c061',
#   'c063',
#   'c156',
#   'c067',
#   'c052',
#   'c115'],
#  ['c063', 'c139', 'c114', 'c113', 'c061'],
#  ['c010',
#   'c014',
#   'c061',
#   'c115',
#   'c118',
#   'c152',
#   'c149',
#   'c156',
#   'c145',
#   'c032',
#   'c065'],
#  ['c154',
#   'c109',
#   'c110',
#   'c064',
#   'c059',
#   'c011',
#   'c061',
#   'c023',
#   'c063',
#   'c024'],
#  ['c062', 'c130'],
#  ['c000', 'c094', 'c096', 'c152'],
#  ['c009', 'c062', 'c151', 'c123', 'c052', 'c011', 'c152', 'c014'],
#  ['c040', 'c041', 'c123', 'c132', 'c061', 'c156', 'c044', 'c070'],
#  ['c033', 'c097', 'c001', 'c082', 'c112', 'c006', 'c003', 'c034'],
#  ['c150',
#   'c009',
#   'c020',
#   'c027',
#   'c029',
#   'c117',
#   'c023',
#   'c030',
#   'c026',
#   'c022',
#   'c032'],
#  ['c067',
#   'c068',
#   'c118',
#   'c119',
#   'c011',
#   'c040',
#   'c041',
#   'c151',
#   'c009',
#   'c059'],
#  ['c118', 'c147'],
#  ['c043', 'c040', 'c150', 'c096'],
#  ['c024', 'c022', 'c127', 'c023', 'c020'],
#  ['c098', 'c149', 'c153'],
#  ['c034', 'c107', 'c088'],
#  ['c052', 'c123', 'c008', 'c020', 'c006'],
#  ['c084', 'c154', 'c044', 'c150', 'c083'],
#  ['c154',
#   'c004',
#   'c000',
#   'c002',
#   'c001',
#   'c003',
#   'c001',
#   'c002',
#   'c073',
#   'c071',
#   'c012',
#   'c009'],
#  ['c033', 'c037', 'c108', 'c105', 'c034'],
#  ['c098', 'c102', 'c127', 'c092'],
#  ['c007', 'c123', 'c151'],
#  ['c118',
#   'c119',
#   'c147',
#   'c061',
#   'c112',
#   'c009',
#   'c130',
#   'c113',
#   'c063',
#   'c062'],
#  ['c098', 'c127', 'c132', 'c102', 'c067', 'c156', 'c065', 'c152'],
#  ['c011',
#   'c052',
#   'c059',
#   'c154',
#   'c119',
#   'c120',
#   'c143',
#   'c126',
#   'c064',
#   'c153'],
#  ['c149', 'c152', 'c070', 'c075', 'c009', 'c071'],
#  ['c015', 'c016', 'c059', 'c106', 'c107'],
#  ['c151', 'c125', 'c022', 'c135', 'c021', 'c050', 'c048', 'c020', 'c023'],
#  ['c040', 'c047', 'c031'],
#  ['c072', 'c122', 'c146'],
#  ['c017', 'c081', 'c087', 'c107', 'c108', 'c015', 'c105', 'c106'],
#  ['c026', 'c032', 'c025', 'c097'],
#  ['c153', 'c082'],
#  ['c063',
#   'c061',
#   'c067',
#   'c118',
#   'c120',
#   'c065',
#   'c156',
#   'c073',
#   'c072',
#   'c097'],
#  ['c082', 'c110', 'c107', 'c108'],
#  ['c106', 'c107', 'c109', 'c038', 'c035', 'c121', 'c110', 'c111'],
#  ['c020', 'c023', 'c028', 'c021', 'c001', 'c054', 'c056', 'c053'],
#  ['c076', 'c123', 'c089', 'c154'],
#  ['c020',
#   'c021',
#   'c061',
#   'c062',
#   'c125',
#   'c154',
#   'c143',
#   'c064',
#   'c130',
#   'c081',
#   'c024'],
#  ['c076', 'c149', 'c152', 'c096', 'c155'],
#  ['c072', 'c122', 'c153', 'c063', 'c152', 'c156', 'c061'],
#  ['c000', 'c001', 'c004', 'c112', 'c006', 'c008', 'c100', 'c098', 'c102'],
#  ['c096', 'c097', 'c020', 'c130', 'c021', 'c144', 'c062', 'c008'],
#  ['c153', 'c126', 'c003', 'c155', 'c044', 'c096', 'c155'],
#  ['c113',
#   'c009',
#   'c129',
#   'c128',
#   'c128',
#   'c110',
#   'c112',
#   'c109',
#   'c151',
#   'c059',
#   'c107',
#   'c011',
#   'c108'],
#  ['c001',
#   'c155',
#   'c001',
#   'c151',
#   'c015',
#   'c124',
#   'c016',
#   'c018',
#   'c072',
#   'c016'],
#  ['c106', 'c092', 'c009', 'c109', 'c154'],
#  ['c115',
#   'c026',
#   'c030',
#   'c116',
#   'c081',
#   'c009',
#   'c028',
#   'c048',
#   'c052',
#   'c027',
#   'c025'],
#  ['c011', 'c014', 'c051', 'c052', 'c059', 'c151', 'c121', 'c111'],
#  ['c011',
#   'c015',
#   'c016',
#   'c059',
#   'c017',
#   'c009',
#   'c028',
#   'c117',
#   'c145',
#   'c027',
#   'c014',
#   'c032',
#   'c115'],
#  ['c136', 'c008'],
#  ['c008', 'c000', 'c113', 'c071', 'c081', 'c001', 'c112'],
#  ['c008',
#   'c097',
#   'c141',
#   'c006',
#   'c057',
#   'c056',
#   'c126',
#   'c154',
#   'c155',
#   'c002',
#   'c000',
#   'c001'],
#  ['c072',
#   'c132',
#   'c134',
#   'c001',
#   'c003',
#   'c074',
#   'c126',
#   'c132',
#   'c070',
#   'c000'],
#  ['c148', 'c057', 'c155', 'c056', 'c054'],
#  ['c092', 'c106', 'c006'],
#  ['c011',
#   'c014',
#   'c026',
#   'c032',
#   'c145',
#   'c149',
#   'c030',
#   'c035',
#   'c013',
#   'c038',
#   'c025',
#   'c116',
#   'c152',
#   'c012',
#   'c028',
#   'c125',
#   'c126'],
#  ['c097', 'c058', 'c126', 'c054', 'c104', 'c053', 'c149', 'c152'],
#  ['c098', 'c102', 'c127'],
#  ['c028', 'c122', 'c134', 'c025', 'c032'],
#  ['c025', 'c026', 'c027', 'c031', 'c097', 'c126', 'c105'],
#  ['c054', 'c082', 'c053', 'c056', 'c097', 'c141', 'c008'],
#  ['c061',
#   'c065',
#   'c069',
#   'c067',
#   'c112',
#   'c023',
#   'c063',
#   'c020',
#   'c068',
#   'c068',
#   'c021',
#   'c156',
#   'c024',
#   'c035',
#   'c033',
#   'c024',
#   'c034',
#   'c062',
#   'c113'],
#  ['c150', 'c097', 'c154', 'c054', 'c055', 'c059', 'c151'],
#  ['c113', 'c097', 'c006', 'c018', 'c015'],
#  ['c098', 'c097', 'c006', 'c015'],
#  ['c154', 'c048', 'c151', 'c059', 'c052'],
#  ['c001', 'c009', 'c151', 'c135', 'c035', 'c037', 'c033', 'c034'],
#  ['c011',
#   'c032',
#   'c061',
#   'c118',
#   'c156',
#   'c107',
#   'c108',
#   'c110',
#   'c106',
#   'c109',
#   'c109'],
#  ['c031', 'c135', 'c151', 'c026'],
#  ['c076', 'c078', 'c154'],
#  ['c075',
#   'c061',
#   'c156',
#   'c062',
#   'c039',
#   'c043',
#   'c154',
#   'c042',
#   'c040',
#   'c041',
#   'c044',
#   'c151',
#   'c063'],
#  ['c033', 'c001', 'c034', 'c081', 'c005', 'c005', 'c033', 'c081', 'c082'],
#  ['c098', 'c102', 'c127', 'c030', 'c026', 'c027', 'c032'],
#  ['c000', 'c097', 'c118', 'c003', 'c001', 'c034', 'c126', 'c126'],
#  ['c011', 'c015', 'c061', 'c087', 'c156', 'c153'],
#  ['c082',
#   'c082',
#   'c084',
#   'c042',
#   'c117',
#   'c032',
#   'c115',
#   'c116',
#   'c081',
#   'c042',
#   'c042',
#   'c081',
#   'c043'],
#  ['c084', 'c088', 'c123', 'c118', 'c106'],
#  ['c059', 'c148', 'c033', 'c154'],
#  ['c083', 'c088', 'c084'],
#  ['c000', 'c008', 'c150', 'c141'],
#  ['c132', 'c131'],
#  ['c010',
#   'c011',
#   'c020',
#   'c059',
#   'c061',
#   'c063',
#   'c156',
#   'c009',
#   'c062',
#   'c148',
#   'c001'],
#  ['c000', 'c002', 'c044', 'c001', 'c004', 'c003'],
#  ['c149', 'c040', 'c043', 'c045', 'c126'],
#  ['c020',
#   'c023',
#   'c061',
#   'c063',
#   'c022',
#   'c130',
#   'c081',
#   'c066',
#   'c067',
#   'c118',
#   'c106',
#   'c097'],
#  ['c065', 'c067', 'c156', 'c040', 'c041', 'c002', 'c044'],
#  ['c107', 'c145', 'c116', 'c143', 'c117', 'c115'],
#  ['c155', 'c000'],
#  ['c107', 'c109', 'c041', 'c128', 'c044', 'c106', 'c156', 'c129', 'c110'],
#  ['c008', 'c134'],
#  ['c061', 'c097', 'c150', 'c156', 'c006'],
#  ['c011', 'c059', 'c080', 'c076'],
#  ['c070', 'c076', 'c096', 'c153'],
#  ['c089', 'c112', 'c154', 'c015', 'c087', 'c016', 'c018'],
#  ['c097', 'c006', 'c004', 'c096', 'c148', 'c144'],
#  ['c051', 'c059', 'c061', 'c156', 'c008', 'c141', 'c097', 'c154'],
#  ['c124', 'c154'],
#  ['c124', 'c114', 'c038', 'c033', 'c091'],
#  ['c015', 'c016', 'c087', 'c002', 'c001'],
#  ['c125', 'c154', 'c015'],
#  ['c059', 'c107', 'c153', 'c109', 'c109', 'c154', 'c107', 'c128', 'c009'],
#  ['c140', 'c020', 'c022', 'c097'],
#  ['c001', 'c097', 'c000', 'c006', 'c134', 'c008', 'c113', 'c081', 'c112'],
#  ['c023', 'c021', 'c020', 'c097'],
#  ['c154', 'c127', 'c137', 'c124'],
#  ['c127', 'c099', 'c101', 'c132', 'c102', 'c098'],
#  ['c062', 'c063', 'c143', 'c082'],
#  ['c097', 'c119', 'c121', 'c100', 'c098', 'c104', 'c104', 'c119'],
#  ['c033', 'c053', 'c144'],
#  ['c002', 'c153', 'c008', 'c113', 'c141', 'c112', 'c128', 'c001', 'c148'],
#  ['c020', 'c097', 'c023'],
#  ['c082', 'c043', 'c045', 'c042'],
#  ['c070', 'c073', 'c075', 'c071', 'c034', 'c015', 'c016'],
#  ['c014', 'c048', 'c052', 'c046', 'c008'],
#  ['c052',
#   'c059',
#   'c124',
#   'c067',
#   'c068',
#   'c062',
#   'c069',
#   'c065',
#   'c156',
#   'c063',
#   'c061'],
#  ['c056', 'c057', 'c126', 'c155', 'c001'],
#  ['c008',
#   'c020',
#   'c097',
#   'c006',
#   'c059',
#   'c123',
#   'c151',
#   'c022',
#   'c024',
#   'c108'],
#  ['c097', 'c006', 'c096', 'c152', 'c094'],
#  ['c015', 'c016', 'c135', 'c153', 'c115', 'c116'],
#  ['c000', 'c004'],
#  ['c008', 'c130', 'c024', 'c152', 'c020', 'c006'],
#  ['c040', 'c042', 'c043', 'c154', 'c151', 'c125'],
#  ['c098', 'c102', 'c127'],
#  ['c059', 'c061', 'c156', 'c145'],
#  ['c040', 'c042', 'c081', 'c044', 'c130', 'c044', 'c062', 'c044', 'c062'],
#  ['c015',
#   'c059',
#   'c061',
#   'c065',
#   'c067',
#   'c156',
#   'c016',
#   'c154',
#   'c035',
#   'c002',
#   'c005',
#   'c033'],
#  ['c015', 'c019', 'c111'],
#  ['c151', 'c120', 'c118', 'c059', 'c154', 'c106'],
#  ['c147', 'c153', 'c128', 'c129'],
#  ['c078',
#   'c122',
#   'c146',
#   'c123',
#   'c154',
#   'c080',
#   'c126',
#   'c132',
#   'c131',
#   'c149'],
#  ['c000', 'c059', 'c148', 'c001', 'c148', 'c154', 'c020', 'c023'],
#  ['c147', 'c097', 'c009', 'c092'],
#  ['c097', 'c110', 'c109', 'c107', 'c106'],
#  ['c059', 'c096', 'c155', 'c000', 'c134', 'c078', 'c003', 'c001'],
#  ['c056', 'c150'],
#  ['c098', 'c099', 'c100', 'c102', 'c114', 'c153', 'c113'],
#  ['c098', 'c124', 'c153', 'c097'],
#  ['c107', 'c143', 'c109', 'c142', 'c006', 'c108'],
#  ['c097', 'c096', 'c015', 'c087'],
#  ['c061', 'c118', 'c156', 'c104', 'c105', 'c119', 'c009'],
#  ['c137', 'c001', 'c004', 'c138', 'c000'],
#  ['c097', 'c155', 'c095', 'c000', 'c096', 'c148'],
#  ['c134', 'c135', 'c133', 'c146', 'c003', 'c155', 'c155'],
#  ['c137', 'c020', 'c023', 'c022', 'c021', 'c063', 'c075', 'c070'],
#  ['c106', 'c107', 'c135', 'c119', 'c134'],
#  ['c132', 'c117', 'c115', 'c145', 'c151', 'c125', 'c154', 'c153'],
#  ['c040',
#   'c044',
#   'c061',
#   'c063',
#   'c156',
#   'c109',
#   'c149',
#   'c152',
#   'c042',
#   'c062',
#   'c110',
#   'c107',
#   'c106'],
#  ['c043', 'c063', 'c061', 'c023', 'c150'],
#  ['c043', 'c040', 'c008', 'c097', 'c039'],
#  ['c059', 'c029', 'c047', 'c152', 'c052', 'c026', 'c032'],
#  ['c127', 'c096', 'c144'],
#  ['c070', 'c072', 'c123', 'c057', 'c151', 'c122', 'c154', 'c071'],
#  ['c015', 'c016', 'c040'],
#  ['c011', 'c059', 'c070', 'c072', 'c078', 'c071', 'c153'],
#  ['c015', 'c075', 'c016', 'c107', 'c122', 'c134', 'c151'],
#  ['c137', 'c001', 'c127', 'c055'],
#  ['c020',
#   'c126',
#   'c022',
#   'c130',
#   'c024',
#   'c023',
#   'c061',
#   'c067',
#   'c065',
#   'c156'],
#  ['c000', 'c033', 'c115'],
#  ['c092',
#   'c022',
#   'c024',
#   'c023',
#   'c020',
#   'c021',
#   'c054',
#   'c056',
#   'c058',
#   'c053'],
#  ['c123', 'c132', 'c152', 'c073', 'c070', 'c151', 'c072', 'c154'],
#  ['c020', 'c061', 'c156'],
#  ['c097', 'c061', 'c065', 'c156', 'c064', 'c068', 'c067'],
#  ['c097',
#   'c107',
#   'c118',
#   'c154',
#   'c009',
#   'c119',
#   'c151',
#   'c125',
#   'c001',
#   'c002',
#   'c003'],
#  ['c072', 'c153', 'c070', 'c154', 'c146'],
#  ['c015', 'c016', 'c059', 'c152'],
#  ['c026', 'c032', 'c059', 'c115', 'c029', 'c149', 'c152', 'c153'],
#  ['c057',
#   'c125',
#   'c054',
#   'c018',
#   'c044',
#   'c041',
#   'c042',
#   'c016',
#   'c015',
#   'c087',
#   'c043',
#   'c040'],
#  ['c113', 'c126', 'c057', 'c002', 'c000', 'c058', 'c003', 'c112', 'c056'],
#  ['c125',
#   'c008',
#   'c113',
#   'c006',
#   'c154',
#   'c062',
#   'c114',
#   'c130',
#   'c130',
#   'c081'],
#  ['c020', 'c115', 'c151', 'c145', 'c059', 'c154', 'c021'],
#  ['c059',
#   'c151',
#   'c062',
#   'c014',
#   'c032',
#   'c027',
#   'c145',
#   'c011',
#   'c144',
#   'c016',
#   'c063',
#   'c154',
#   'c061',
#   'c156'],
#  ['c106', 'c107'],
#  ['c070', 'c072', 'c078', 'c076', 'c097'],
#  ['c009', 'c118', 'c119'],
#  ['c127', 'c137', 'c152', 'c023', 'c053', 'c127'],
#  ['c026',
#   'c030',
#   'c030',
#   'c135',
#   'c032',
#   'c027',
#   'c025',
#   'c028',
#   'c002',
#   'c154',
#   'c000',
#   'c155',
#   'c061',
#   'c156'],
#  ['c076', 'c125', 'c096', 'c078', 'c153'],
#  ['c015', 'c016', 'c047', 'c087', 'c149', 'c152'],
#  ['c028', 'c106', 'c118', 'c118', 'c030', 'c026', 'c027', 'c032'],
#  ['c020', 'c059', 'c147', 'c022', 'c154'],
#  ['c119', 'c069', 'c120', 'c118', 'c067'],
#  ['c128', 'c079', 'c076', 'c078', 'c009', 'c139'],
#  ['c133', 'c146', 'c096', 'c018', 'c015'],
#  ['c128',
#   'c129',
#   'c040',
#   'c129',
#   'c039',
#   'c009',
#   'c041',
#   'c128',
#   'c156',
#   'c012'],
#  ['c152', 'c149', 'c051'],
#  ['c059', 'c154', 'c127', 'c137', 'c151'],
#  ['c097', 'c006', 'c141', 'c139'],
#  ['c053', 'c097', 'c000', 'c002', 'c149', 'c152'],
#  ['c123', 'c135', 'c016', 'c152', 'c015', 'c154', 'c006', 'c112', 'c106'],
#  ['c020',
#   'c023',
#   'c066',
#   'c154',
#   'c063',
#   'c021',
#   'c068',
#   'c128',
#   'c129',
#   'c156',
#   'c067'],
#  ['c067', 'c020', 'c026', 'c150'],
#  ['c078', 'c026', 'c123', 'c011', 'c010', 'c151', 'c154', 'c009'],
#  ['c106', 'c107', 'c118'],
#  ['c097', 'c112', 'c063', 'c113', 'c061'],
#  ['c020', 'c061', 'c156', 'c137', 'c022', 'c009', 'c024', 'c137'],
#  ['c009',
#   'c151',
#   'c011',
#   'c059',
#   'c107',
#   'c108',
#   'c106',
#   'c119',
#   'c118',
#   'c110',
#   'c119'],
#  ['c091'],
#  ['c061', 'c064'],
#  ['c006', 'c097', 'c141', 'c008'],
#  ['c011',
#   'c014',
#   'c052',
#   'c061',
#   'c065',
#   'c067',
#   'c156',
#   'c015',
#   'c016',
#   'c019'],
#  ['c059', 'c061', 'c065', 'c156', 'c110'],
#  ['c134',
#   'c015',
#   'c146',
#   'c018',
#   'c016',
#   'c154',
#   'c017',
#   'c151',
#   'c027',
#   'c059',
#   'c011',
#   'c014',
#   'c032',
#   'c145'],
#  ['c106', 'c110', 'c147', 'c106', 'c109', 'c147'],
#  ['c059', 'c061', 'c118', 'c156', 'c149', 'c152', 'c062'],
#  ['c147', 'c118', 'c142', 'c143', 'c143', 'c156'],
#  ['c098', 'c100'],
#  ['c134', 'c132', 'c127', 'c137', 'c154'],
#  ['c082', 'c035', 'c002', 'c033', 'c003', 'c036', 'c152'],
#  ['c011',
#   'c059',
#   'c123',
#   'c107',
#   'c106',
#   'c108',
#   'c109',
#   'c120',
#   'c118',
#   'c119',
#   'c009',
#   'c012',
#   'c110',
#   'c154',
#   'c107'],
#  ['c008', 'c028', 'c116', 'c009', 'c127', 'c026', 'c115', 'c117', 'c030'],
#  ['c098', 'c123', 'c099', 'c141', 'c112', 'c097'],
#  ['c078', 'c123', 'c079', 'c076', 'c132'],
#  ['c015', 'c016', 'c107', 'c153', 'c017', 'c106'],
#  ['c102', 'c062', 'c063', 'c118', 'c097', 'c127', 'c099'],
#  ['c040', 'c050', 'c151', 'c125', 'c041'],
#  ['c147', 'c030', 'c026', 'c015'],
#  ['c096', 'c152', 'c084', 'c088'],
#  ['c026', 'c033', 'c097', 'c009', 'c034', 'c036', 'c003'],
#  ['c107', 'c153', 'c107', 'c129', 'c106', 'c109'],
#  ['c076'],
#  ['c000', 'c024', 'c070', 'c149'],
#  ['c155', 'c001', 'c000', 'c003', 'c072', 'c134'],
#  ['c152', 'c009', 'c108', 'c106', 'c110', 'c107'],
#  ['c008', 'c006', 'c118', 'c120'],
#  ['c110', 'c108', 'c107', 'c009'],
#  ['c125', 'c039', 'c042', 'c154'],
#  ['c059',
#   'c154',
#   'c113',
#   'c008',
#   'c141',
#   'c002',
#   'c001',
#   'c000',
#   'c003',
#   'c155'],
#  ['c023',
#   'c011',
#   'c110',
#   'c059',
#   'c107',
#   'c107',
#   'c108',
#   'c009',
#   'c109',
#   'c110',
#   'c106',
#   'c020',
#   'c022',
#   'c009',
#   'c151'],
#  ['c144', 'c030', 'c026', 'c114', 'c081', 'c028', 'c028', 'c127'],
#  ['c011', 'c014', 'c052', 'c059', 'c154'],
#  ['c072',
#   'c116',
#   'c023',
#   'c030',
#   'c026',
#   'c028',
#   'c027',
#   'c115',
#   'c117',
#   'c025'],
#  ['c143', 'c023', 'c020', 'c142'],
#  ['c011', 'c059', 'c062', 'c063', 'c156', 'c154', 'c097', 'c008', 'c006'],
#  ['c151', 'c120', 'c118', 'c106', 'c119', 'c139', 'c057', 'c058', 'c154'],
#  ['c015', 'c016', 'c135', 'c008', 'c154', 'c087'],
#  ['c002', 'c003', 'c126', 'c061', 'c156', 'c096', 'c113'],
#  ['c061', 'c063', 'c051', 'c108', 'c062'],
#  ['c097',
#   'c043',
#   'c042',
#   'c127',
#   'c081',
#   'c114',
#   'c040',
#   'c008',
#   'c141',
#   'c006',
#   'c112',
#   'c097',
#   'c042',
#   'c127',
#   'c141',
#   'c008',
#   'c113'],
#  ['c005', 'c015', 'c016', 'c054', 'c077'],
#  ['c006', 'c097', 'c141', 'c079', 'c076'],
#  ['c127', 'c137', 'c076', 'c079'],
#  ['c098', 'c110', 'c118', 'c147', 'c109', 'c119', 'c120', 'c009'],
#  ['c020', 'c154', 'c097', 'c127', 'c102'],
#  ['c059', 'c154', 'c113', 'c119', 'c081', 'c006', 'c119'],
#  ['c015', 'c016', 'c156', 'c056', 'c023', 'c020', 'c053', 'c044', 'c063'],
#  ['c147', 'c141', 'c008', 'c113', 'c120', 'c119', 'c110', 'c106'],
#  ['c128', 'c147', 'c152', 'c128', 'c149', 'c129'],
#  ['c147', 'c118', 'c111'],
#  ['c062', 'c147'],
#  ['c003', 'c153'],
#  ['c093', 'c154', 'c069', 'c067', 'c156', 'c065', 'c119', 'c068'],
#  ['c096', 'c155', 'c000', 'c026', 'c030', 'c155', 'c001', 'c038'],
#  ['c026', 'c032', 'c147', 'c113', 'c028', 'c081', 'c112', 'c025'],
#  ['c015', 'c033', 'c070', 'c019', 'c036', 'c097'],
#  ['c026', 'c032', 'c035', 'c001', 'c003', 'c073', 'c002'],
#  ['c097', 'c074', 'c070', 'c079', 'c071'],
#  ['c152', 'c147'],
#  ['c047', 'c051', 'c052', 'c059', 'c107', 'c106', 'c149', 'c152'],
#  ['c102', 'c127', 'c096', 'c144'],
#  ['c025', 'c106', 'c113', 'c112', 'c027'],
#  ['c001', 'c097', 'c155', 'c106', 'c152', 'c003', 'c134', 'c107'],
#  ['c150', 'c154', 'c008', 'c151', 'c059', 'c055', 'c097', 'c006'],
#  ['c008', 'c113', 'c006', 'c118', 'c112'],
#  ['c074', 'c009', 'c071', 'c081', 'c079', 'c070', 'c078', 'c076', 'c072'],
#  ['c011', 'c051', 'c052', 'c156'],
#  ['c030',
#   'c070',
#   'c072',
#   'c123',
#   'c029',
#   'c151',
#   'c025',
#   'c028',
#   'c107',
#   'c110',
#   'c109',
#   'c106',
#   'c026',
#   'c027',
#   'c032'],
#  ['c008',
#   'c113',
#   'c063',
#   'c023',
#   'c000',
#   'c003',
#   'c061',
#   'c112',
#   'c082',
#   'c114',
#   'c004'],
#  ['c051', 'c052', 'c156', 'c012', 'c137'],
#  ['c092', 'c090', 'c097'],
#  ['c011', 'c059', 'c118', 'c062', 'c045'],
#  ['c093', 'c106', 'c125'],
#  ['c118', 'c120', 'c147', 'c062'],
#  ['c061', 'c063', 'c006', 'c142', 'c097', 'c008', 'c062', 'c143'],
#  ['c020', 'c104', 'c061', 'c156'],
#  ['c092', 'c072', 'c070', 'c076', 'c078', 'c073'],
#  ['c008', 'c097', 'c006', 'c082', 'c038', 'c111', 'c121'],
#  ['c115', 'c145', 'c014', 'c051', 'c052'],
#  ['c096', 'c153'],
#  ['c107', 'c119', 'c109', 'c108', 'c111', 'c008', 'c121'],
#  ['c072',
#   'c122',
#   'c146',
#   'c070',
#   'c154',
#   'c073',
#   'c071',
#   'c075',
#   'c082',
#   'c123'],
#  ['c008', 'c061', 'c067', 'c107', 'c106', 'c006', 'c065'],
#  ['c002', 'c148', 'c020', 'c023', 'c132'],
#  ['c153', 'c137'],
#  ['c096', 'c154', 'c105'],
#  ['c014', 'c015', 'c019', 'c052', 'c152'],
#  ['c153', 'c153', 'c002', 'c127', 'c001', 'c009'],
#  ['c128', 'c152', 'c149', 'c143', 'c142', 'c129'],
#  ['c143',
#   'c142',
#   'c107',
#   'c110',
#   'c151',
#   'c059',
#   'c011',
#   'c106',
#   'c108',
#   'c062'],
#  ['c033', 'c073', 'c154', 'c151', 'c059', 'c072', 'c155'],
#  ['c134', 'c154', 'c053', 'c056', 'c054', 'c003', 'c001'],
#  ['c081', 'c082', 'c105', 'c150'],
#  ['c155',
#   'c002',
#   'c023',
#   'c020',
#   'c061',
#   'c151',
#   'c135',
#   'c021',
#   'c063',
#   'c132',
#   'c003',
#   'c156'],
#  ['c142', 'c147', 'c118'],
#  ['c051', 'c052', 'c125', 'c124'],
#  ['c000', 'c155', 'c106', 'c001', 'c022', 'c076', 'c096'],
#  ['c151', 'c135', 'c018', 'c016', 'c015', 'c076', 'c079', 'c077'],
#  ['c015', 'c017', 'c097', 'c151', 'c059', 'c055', 'c148', 'c152', 'c009'],
#  ['c008', 'c097', 'c107', 'c141', 'c006', 'c096'],
#  ['c011', 'c021', 'c059', 'c156', 'c032', 'c153', 'c154', 'c092'],
#  ['c098', 'c153', 'c125', 'c056', 'c057'],
#  ['c041',
#   'c151',
#   'c125',
#   'c042',
#   'c073',
#   'c000',
#   'c071',
#   'c154',
#   'c004',
#   'c002',
#   'c001'],
#  ['c006', 'c149', 'c152', 'c155', 'c001', 'c003'],
#  ['c047', 'c127', 'c137', 'c150'],
#  ['c061',
#   'c063',
#   'c065',
#   'c067',
#   'c152',
#   'c156',
#   'c027',
#   'c032',
#   'c025',
#   'c068',
#   'c062',
#   'c026',
#   'c030'],
#  ['c037', 'c033', 'c112', 'c113', 'c081', 'c034'],
#  ['c097', 'c002', 'c030', 'c070', 'c073', 'c028', 'c115', 'c117', 'c000'],
#  ['c015', 'c087', 'c149'],
#  ['c143', 'c156', 'c151', 'c059', 'c063', 'c142', 'c061', 'c118'],
#  ['c007', 'c113', 'c054', 'c127', 'c053', 'c056', 'c112'],
#  ['c004'],
#  ['c061', 'c135', 'c156', 'c040', 'c043', 'c039'],
#  ['c115', 'c123', 'c145', 'c152'],
#  ['c082', 'c114', 'c153', 'c110', 'c106'],
#  ['c127', 'c154', 'c102'],
#  ['c021', 'c153', 'c023', 'c020'],
#  ['c094',
#   'c096',
#   'c135',
#   'c153',
#   'c067',
#   'c065',
#   'c156',
#   'c000',
#   'c155',
#   'c003'],
#  ['c132', 'c134', 'c072', 'c074'],
#  ['c092', 'c100', 'c098', 'c099', 'c105', 'c097'],
#  ['c097', 'c001', 'c002', 'c004', 'c000'],
#  ['c065', 'c067', 'c092', 'c156'],
#  ['c107', 'c107', 'c110', 'c106', 'c106', 'c081', 'c109'],
#  ['c097', 'c044', 'c128', 'c149', 'c152', 'c113', 'c040', 'c041', 'c043'],
#  ['c097', 'c052', 'c047', 'c098', 'c099'],
#  ['c076',
#   'c135',
#   'c110',
#   'c118',
#   'c118',
#   'c107',
#   'c106',
#   'c154',
#   'c109',
#   'c152',
#   'c077',
#   'c146',
#   'c078',
#   'c133'],
#  ['c072', 'c076', 'c104', 'c105', 'c141', 'c006'],
#  ['c011', 'c015', 'c016', 'c153', 'c009', 'c011', 'c015', 'c016', 'c017'],
#  ['c137', 'c152'],
#  ['c050', 'c047', 'c097'],
#  ['c070', 'c015', 'c087', 'c074', 'c126', 'c071'],
#  ['c063',
#   'c112',
#   'c113',
#   'c043',
#   'c061',
#   'c041',
#   'c109',
#   'c062',
#   'c081',
#   'c039',
#   'c042',
#   'c110',
#   'c044',
#   'c108',
#   'c107'],
#  ['c059', 'c061', 'c156', 'c118', 'c082', 'c062', 'c119', 'c009', 'c154'],
#  ['c055', 'c059', 'c154', 'c150', 'c117', 'c115'],
#  ['c009',
#   'c011',
#   'c014',
#   'c063',
#   'c065',
#   'c069',
#   'c145',
#   'c061',
#   'c067',
#   'c062'],
#  ['c076', 'c124', 'c125', 'c155', 'c078', 'c057'],
#  ['c011',
#   'c012',
#   'c013',
#   'c014',
#   'c038',
#   'c038',
#   'c059',
#   'c106',
#   'c107',
#   'c118',
#   'c152'],
#  ['c020', 'c021', 'c024', 'c126'],
#  ['c015',
#   'c016',
#   'c135',
#   'c109',
#   'c110',
#   'c107',
#   'c106',
#   'c017',
#   'c151',
#   'c154',
#   'c126',
#   'c070',
#   'c071',
#   'c073',
#   'c074'],
#  ['c035', 'c038', 'c033', 'c034'],
#  ['c059', 'c145', 'c146', 'c011', 'c032', 'c027', 'c014'],
#  ['c020',
#   'c062',
#   'c063',
#   'c008',
#   'c113',
#   'c006',
#   'c112',
#   'c021',
#   'c130',
#   'c061',
#   'c081'],
#  ['c003',
#   'c004',
#   'c059',
#   'c151',
#   'c055',
#   'c059',
#   'c055',
#   'c002',
#   'c000',
#   'c148'],
#  ['c053', 'c110', 'c109', 'c054', 'c119', 'c120'],
#  ['c141', 'c008', 'c011', 'c048', 'c059', 'c052', 'c014', 'c051', 'c097'],
#  ['c151', 'c123', 'c100', 'c098', 'c125', 'c127', 'c102'],
#  ['c108',
#   'c106',
#   'c030',
#   'c026',
#   'c032',
#   'c027',
#   'c025',
#   'c028',
#   'c154',
#   'c151',
#   'c059',
#   'c115',
#   'c107',
#   'c110'],
#  ['c151',
#   'c059',
#   'c123',
#   'c154',
#   'c063',
#   'c011',
#   'c061',
#   'c062',
#   'c065',
#   'c156'],
#  ['c153', 'c069', 'c067', 'c065', 'c061', 'c156', 'c096'],
#  ['c016', 'c134', 'c015', 'c009', 'c154', 'c089', 'c004'],
#  ['c126', 'c003', 'c001', 'c002'],
#  ['c130', 'c081', 'c112', 'c006', 'c099', 'c081'],
#  ['c061', 'c156', 'c081', 'c073', 'c000', 'c002', 'c070', 'c137', 'c127'],
#  ['c004', 'c114', 'c137', 'c097', 'c098', 'c105'],
#  ['c072', 'c123', 'c143', 'c062', 'c130', 'c020', 'c097'],
#  ['c151',
#   'c123',
#   'c154',
#   'c061',
#   'c141',
#   'c008',
#   'c132',
#   'c000',
#   'c067',
#   'c070',
#   'c071',
#   'c074',
#   'c126',
#   'c006'],
#  ['c070', 'c072', 'c154', 'c073', 'c097', 'c008', 'c113'],
#  ['c011', 'c059', 'c146', 'c154', 'c096', 'c144'],
#  ['c063', 'c061', 'c120', 'c003', 'c000', 'c001'],
#  ['c026',
#   'c032',
#   'c059',
#   'c072',
#   'c115',
#   'c145',
#   'c025',
#   'c028',
#   'c154',
#   'c150'],
#  ['c019', 'c097', 'c015', 'c002'],
#  ['c047', 'c125', 'c049', 'c046', 'c081'],
#  ['c097', 'c150', 'c106', 'c109', 'c110'],
#  ['c070',
#   'c072',
#   'c134',
#   'c000',
#   'c154',
#   'c001',
#   'c004',
#   'c156',
#   'c065',
#   'c061',
#   'c063',
#   'c062',
#   'c155',
#   'c000',
#   'c074',
#   'c002'],
#  ['c026', 'c028', 'c081', 'c154', 'c117', 'c115', 'c151'],
#  ['c084',
#   'c087',
#   'c086',
#   'c083',
#   'c105',
#   'c104',
#   'c096',
#   'c018',
#   'c015',
#   'c123',
#   'c151',
#   'c088'],
#  ['c020', 'c004', 'c022', 'c024', 'c151', 'c059'],
#  ['c047', 'c051', 'c088', 'c065', 'c156', 'c063', 'c061', 'c153', 'c064'],
#  ['c063', 'c143', 'c147', 'c142', 'c062', 'c147'],
#  ['c053', 'c150', 'c097'],
#  ['c000', 'c033', 'c003', 'c070'],
#  ['c015', 'c153', 'c097', 'c016'],
#  ['c127', 'c137', 'c110', 'c107', 'c106', 'c009', 'c109'],
#  ['c026', 'c032', 'c059', 'c135', 'c029'],
#  ['c053', 'c056', 'c062', 'c041', 'c044'],
#  ['c150', 'c151', 'c125'],
#  ['c015', 'c019'],
#  ['c113', 'c128', 'c112'],
#  ['c006',
#   'c141',
#   'c110',
#   'c106',
#   'c153',
#   'c097',
#   'c018',
#   'c019',
#   'c015',
#   'c152',
#   'c107'],
#  ['c092', 'c155', 'c000', 'c001'],
#  ['c033'],
#  ['c065', 'c156', 'c065'],
#  ['c119', 'c115', 'c145', 'c116'],
#  ['c047',
#   'c097',
#   'c049',
#   'c009',
#   'c107',
#   'c063',
#   'c067',
#   'c069',
#   'c142',
#   'c143'],
#  ['c097', 'c015', 'c016', 'c063', 'c087'],
#  ['c111', 'c139', 'c109', 'c110', 'c106'],
#  ['c079', 'c076'],
#  ['c021', 'c153'],
#  ['c061', 'c118', 'c015', 'c087'],
#  ['c118', 'c154', 'c063', 'c119', 'c097', 'c106', 'c120', 'c123', 'c120'],
#  ['c092', 'c033', 'c004', 'c097', 'c153'],
#  ['c060',
#   'c062',
#   'c118',
#   'c120',
#   'c149',
#   'c152',
#   'c119',
#   'c081',
#   'c153',
#   'c082'],
#  ['c062', 'c051', 'c119', 'c066', 'c147', 'c063', 'c061', 'c120'],
#  ['c076', 'c150', 'c097'],
#  ['c053', 'c070', 'c001', 'c106', 'c075', 'c071', 'c054'],
#  ['c070',
#   'c113',
#   'c097',
#   'c075',
#   'c151',
#   'c059',
#   'c132',
#   'c081',
#   'c071',
#   'c112'],
#  ['c051', 'c052', 'c125', 'c047', 'c009', 'c154'],
#  ['c055', 'c135', 'c154', 'c097'],
#  ['c011',
#   'c059',
#   'c070',
#   'c075',
#   'c106',
#   'c009',
#   'c154',
#   'c034',
#   'c071',
#   'c110'],
#  ['c061', 'c156', 'c067', 'c064', 'c062'],
#  ['c088', 'c125', 'c132', 'c107', 'c120', 'c152', 'c110'],
#  ['c027', 'c154', 'c060', 'c030', 'c026'],
#  ['c106', 'c075'],
#  ['c000', 'c073', 'c002', 'c070', 'c001', 'c071', 'c008', 'c097'],
#  ['c154', 'c102', 'c127'],
#  ['c118', 'c147', 'c113', 'c120'],
#  ['c151', 'c075', 'c011', 'c070', 'c009', 'c059', 'c108', 'c097'],
#  ['c051', 'c059', 'c061', 'c062', 'c063', 'c147'],
#  ['c108', 'c129', 'c128', 'c107', 'c106', 'c129'],
#  ['c107', 'c081', 'c106'],
#  ['c015',
#   'c087',
#   'c125',
#   'c152',
#   'c027',
#   'c115',
#   'c030',
#   'c116',
#   'c154',
#   'c028',
#   'c017',
#   'c032',
#   'c025',
#   'c117',
#   'c026'],
#  ['c076', 'c078', 'c098', 'c125', 'c127', 'c102', 'c077', 'c079', 'c124'],
#  ['c134', 'c148', 'c000', 'c002', 'c096', 'c133', 'c146', 'c154'],
#  ['c098', 'c099', 'c128', 'c097'],
#  ['c102', 'c127', 'c151', 'c125'],
#  ['c097', 'c107', 'c141', 'c006', 'c110', 'c106', 'c119'],
#  ['c148', 'c097', 'c015', 'c016', 'c006', 'c112'],
#  ['c033', 'c154', 'c040', 'c034', 'c035', 'c009', 'c011', 'c151', 'c061'],
#  ['c040', 'c047', 'c051'],
#  ['c021', 'c020'],
#  ['c011', 'c059', 'c015', 'c016', 'c017'],
#  ['c074',
#   'c151',
#   'c135',
#   'c118',
#   'c061',
#   'c156',
#   'c065',
#   'c152',
#   'c149',
#   'c067'],
#  ['c063',
#   'c143',
#   'c011',
#   'c151',
#   'c061',
#   'c016',
#   'c059',
#   'c015',
#   'c142',
#   'c062'],
#  ['c030', 'c116', 'c031', 'c126', 'c116', 'c141', 'c008', 'c150', 'c097'],
#  ['c020',
#   'c021',
#   'c130',
#   'c063',
#   'c062',
#   'c022',
#   'c147',
#   'c063',
#   'c062',
#   'c063',
#   'c062'],
#  ['c052',
#   'c124',
#   'c151',
#   'c123',
#   'c009',
#   'c014',
#   'c011',
#   'c011',
#   'c156',
#   'c021',
#   'c063',
#   'c009',
#   'c062',
#   'c014',
#   'c154',
#   'c047',
#   'c050',
#   'c049'],
#  ['c000', 'c002', 'c092', 'c153'],
#  ['c127', 'c154', 'c028', 'c003'],
#  ['c020',
#   'c022',
#   'c023',
#   'c062',
#   'c063',
#   'c062',
#   'c021',
#   'c063',
#   'c009',
#   'c130'],
#  ['c045', 'c072', 'c070'],
#  ['c011', 'c015', 'c016', 'c059', 'c152', 'c143', 'c142'],
#  ['c098', 'c102', 'c127', 'c105', 'c097'],
#  ['c026', 'c115', 'c100', 'c098', 'c097', 'c153'],
#  ['c097', 'c113', 'c128', 'c148'],
#  ['c026', 'c032', 'c124', 'c025', 'c154', 'c008'],
#  ['c015', 'c016', 'c123', 'c124'],
#  ['c150',
#   'c081',
#   'c001',
#   'c001',
#   'c081',
#   'c023',
#   'c000',
#   'c021',
#   'c020',
#   'c152'],
#  ['c133', 'c134', 'c146', 'c104', 'c040', 'c041'],
#  ['c150', 'c008', 'c097', 'c020', 'c021', 'c006', 'c152'],
#  ['c008',
#   'c143',
#   'c107',
#   'c110',
#   'c109',
#   'c106',
#   'c142',
#   'c006',
#   'c153',
#   'c128',
#   'c128'],
#  ['c040', 'c061', 'c141', 'c008', 'c062', 'c156'],
#  ['c102', 'c127', 'c038'],
#  ['c020',
#   'c143',
#   'c008',
#   'c021',
#   'c130',
#   'c062',
#   'c024',
#   'c126',
#   'c006',
#   'c142',
#   'c081',
#   'c063',
#   'c061',
#   'c022'],
#  ['c145', 'c115'],
#  ['c011',
#   'c059',
#   'c061',
#   'c063',
#   'c064',
#   'c065',
#   'c067',
#   'c069',
#   'c156',
#   'c062',
#   'c068',
#   'c153'],
#  ['c061', 'c134', 'c155', 'c003', 'c065'],
#  ['c015', 'c153', 'c035', 'c033', 'c038', 'c034', 'c017', 'c006', 'c141'],
#  ['c125', 'c145', 'c059', 'c026', 'c115'],
#  ['c059', 'c065', 'c156', 'c106', 'c026', 'c032', 'c031', 'c028'],
#  ['c081', 'c113', 'c033', 'c020', 'c112'],
#  ['c002',
#   'c148',
#   'c001',
#   'c073',
#   'c070',
#   'c110',
#   'c107',
#   'c097',
#   'c008',
#   'c006'],
#  ['c061', 'c067', 'c097', 'c152', 'c048', 'c156', 'c065'],
#  ['c151', 'c001', 'c023', 'c154', 'c002', 'c000', 'c004'],
#  ['c113', 'c081', 'c151', 'c059', 'c130', 'c112', 'c020'],
#  ['c012', 'c051', 'c059', 'c116', 'c117'],
#  ['c044', 'c112', 'c113', 'c154', 'c153'],
#  ['c026', 'c076', 'c115', 'c027', 'c029', 'c152'],
#  ['c065', 'c156', 'c106', 'c106'],
#  ['c096', 'c082', 'c034', 'c035', 'c001', 'c081'],
#  ['c155', 'c000', 'c001', 'c151', 'c123', 'c059', 'c153', 'c053'],
#  ['c059', 'c076', 'c080'],
#  ['c070',
#   'c150',
#   'c090',
#   'c092',
#   'c033',
#   'c036',
#   'c071',
#   'c034',
#   'c074',
#   'c098',
#   'c101',
#   'c099'],
#  ['c098', 'c102', 'c034'],
#  ['c106', 'c109', 'c107', 'c154', 'c096'],
#  ['c008', 'c097', 'c009', 'c074', 'c003'],
#  ['c001', 'c081', 'c016', 'c018', 'c015', 'c155', 'c000'],
#  ['c118', 'c008', 'c143', 'c147'],
#  ['c011', 'c059', 'c132', 'c108'],
#  ['c033', 'c097', 'c098', 'c034', 'c102', 'c127'],
#  ['c093', 'c096', 'c073', 'c075', 'c070', 'c033', 'c154'],
#  ['c097', 'c098', 'c008', 'c102', 'c127', 'c141'],
#  ['c059', 'c135', 'c001', 'c002', 'c035', 'c004'],
#  ['c008',
#   'c097',
#   'c006',
#   'c104',
#   'c056',
#   'c057',
#   'c155',
#   'c054',
#   'c058',
#   'c126'],
#  ['c151', 'c123', 'c132', 'c142', 'c006'],
#  ['c108', 'c107'],
#  ['c152', 'c009', 'c039'],
#  ['c143', 'c142', 'c117', 'c115', 'c116', 'c153'],
#  ['c043', 'c081', 'c012', 'c153'],
#  ['c150', 'c137', 'c127', 'c119'],
#  ['c094', 'c096', 'c149', 'c152'],
#  ['c141', 'c097', 'c008', 'c015', 'c006'],
#  ['c151', 'c059', 'c055'],
#  ['c001', 'c002', 'c004', 'c081', 'c152'],
#  ['c072',
#   'c133',
#   'c134',
#   'c146',
#   'c151',
#   'c075',
#   'c135',
#   'c048',
#   'c154',
#   'c002',
#   'c148'],
#  ['c106', 'c110'],
#  ['c072', 'c153'],
#  ['c015', 'c016', 'c061', 'c067', 'c118', 'c062', 'c068', 'c119'],
#  ['c098', 'c127', 'c051', 'c102'],
#  ['c098', 'c100', 'c033', 'c035', 'c102', 'c038', 'c127'],
#  ['c020', 'c022', 'c008', 'c006', 'c021', 'c130'],
#  ['c008', 'c104', 'c114', 'c154'],
#  ['c113', 'c032'],
#  ['c097', 'c141', 'c151', 'c011', 'c048', 'c001', 'c144'],
#  ['c106', 'c109', 'c023', 'c000'],
#  ['c096', 'c144', 'c044', 'c079'],
#  ['c011', 'c113', 'c081', 'c112', 'c046', 'c047'],
#  ['c015', 'c016', 'c076', 'c080'],
#  ['c123', 'c152', 'c063', 'c061', 'c156', 'c057', 'c054', 'c053'],
#  ['c021', 'c023', 'c009'],
#  ['c052', 'c019', 'c020', 'c130', 'c113', 'c022', 'c018', 'c015'],
#  ['c072',
#   'c078',
#   'c122',
#   'c073',
#   'c057',
#   'c058',
#   'c126',
#   'c155',
#   'c154',
#   'c020',
#   'c023',
#   'c021',
#   'c151',
#   'c123',
#   'c146',
#   'c070',
#   'c074'],
#  ['c065', 'c106', 'c009', 'c132'],
#  ['c008',
#   'c070',
#   'c073',
#   'c072',
#   'c071',
#   'c132',
#   'c097',
#   'c006',
#   'c123',
#   'c151'],
#  ['c141', 'c008', 'c150', 'c097'],
#  ['c011', 'c048', 'c123', 'c061', 'c021', 'c156', 'c062', 'c051', 'c063'],
#  ['c052', 'c059', 'c065', 'c156', 'c061', 'c110', 'c106', 'c063'],
#  ['c107', 'c151', 'c059', 'c060', 'c082'],
#  ['c026', 'c061', 'c063', 'c156'],
#  ['c015', 'c016', 'c149', 'c152', 'c155', 'c017', 'c155'],
#  ['c010',
#   'c014',
#   'c051',
#   'c052',
#   'c070',
#   'c076',
#   'c078',
#   'c072',
#   'c110',
#   'c120',
#   'c107',
#   'c118',
#   'c106'],
#  ['c059', 'c143', 'c142', 'c121', 'c147', 'c120', 'c062', 'c063'],
#  ['c113',
#   'c047',
#   'c050',
#   'c123',
#   'c048',
#   'c151',
#   'c046',
#   'c049',
#   'c154',
#   'c153'],
#  ['c078', 'c124', 'c146', 'c154', 'c057'],
#  ['c054', 'c119', 'c120', 'c118', 'c062'],
#  ['c084',
#   'c088',
#   'c088',
#   'c115',
#   'c117',
#   'c151',
#   'c011',
#   'c038',
#   'c116',
#   'c036',
#   'c009',
#   'c033',
#   'c153'],
#  ['c115',
#   'c145',
#   'c116',
#   'c154',
#   'c062',
#   'c021',
#   'c023',
#   'c020',
#   'c063',
#   'c152',
#   'c029',
#   'c149'],
#  ['c003', 'c018', 'c036'],
#  ['c070', 'c128', 'c150', 'c141'],
#  ['c002', 'c001', 'c000', 'c055', 'c097'],
#  ['c020', 'c153', 'c149', 'c009', 'c130', 'c022', 'c152'],
#  ['c011',
#   'c026',
#   'c027',
#   'c032',
#   'c151',
#   'c025',
#   'c018',
#   'c015',
#   'c151',
#   'c154',
#   'c017',
#   'c001',
#   'c148',
#   'c002'],
#  ['c076', 'c079', 'c017', 'c081', 'c077'],
#  ['c008', 'c113'],
#  ['c055', 'c125', 'c148', 'c149', 'c152'],
#  ['c033',
#   'c070',
#   'c073',
#   'c156',
#   'c067',
#   'c065',
#   'c068',
#   'c009',
#   'c071',
#   'c061',
#   'c063',
#   'c069'],
#  ['c070', 'c072', 'c001', 'c003', 'c155'],
#  ['c008'],
#  ['c092', 'c067', 'c153'],
#  ['c151', 'c059', 'c015', 'c087'],
#  ['c054', 'c072', 'c075', 'c070'],
#  ['c002', 'c096', 'c155', 'c019', 'c015', 'c097', 'c113', 'c112'],
#  ['c020', 'c009'],
#  ['c076', 'c150', 'c080'],
#  ['c020', 'c026', 'c032', 'c115', 'c147', 'c149', 'c152'],
#  ['c096', 'c153', 'c097', 'c135', 'c132'],
#  ['c006',
#   'c104',
#   'c151',
#   'c059',
#   'c056',
#   'c057',
#   'c055',
#   'c054',
#   'c097',
#   'c153'],
#  ['c040', 'c009', 'c043', 'c041', 'c044', 'c039', 'c042'],
#  ['c000', 'c002', 'c004', 'c003', 'c148', 'c144', 'c001'],
#  ['c065', 'c061', 'c015', 'c016', 'c156'],
#  ['c113', 'c114', 'c152', 'c112', 'c038'],
#  ['c020', 'c006', 'c112', 'c024', 'c008', 'c113', 'c023'],
#  ['c137', 'c137', 'c008', 'c113', 'c114', 'c128', 'c097'],
#  ['c061', 'c156', 'c110', 'c106'],
#  ['c134', 'c154'],
#  ['c050', 'c151', 'c135', 'c047', 'c048', 'c052', 'c075'],
#  ['c008',
#   'c041',
#   'c044',
#   'c045',
#   'c126',
#   'c030',
#   'c026',
#   'c032',
#   'c027',
#   'c149',
#   'c040',
#   'c097',
#   'c025',
#   'c006'],
#  ['c008', 'c002', 'c076', 'c078', 'c152', 'c081', 'c077', 'c006'],
#  ['c135', 'c155', 'c001', 'c003', 'c076', 'c154', 'c113', 'c077', 'c112'],
#  ['c033', 'c038', 'c149', 'c152', 'c113', 'c112'],
#  ['c008',
#   'c001',
#   'c003',
#   'c057',
#   'c058',
#   'c126',
#   'c113',
#   'c105',
#   'c104',
#   'c000',
#   'c155'],
#  ['c042', 'c082', 'c110', 'c043', 'c112', 'c106'],
#  ['c113', 'c035', 'c033', 'c070', 'c097'],
#  ['c015', 'c016', 'c084', 'c088', 'c135', 'c152', 'c149'],
#  ['c033', 'c059', 'c036', 'c154', 'c105'],
#  ['c061',
#   'c063',
#   'c120',
#   'c118',
#   'c119',
#   'c009',
#   'c062',
#   'c061',
#   'c154',
#   'c151',
#   'c059',
#   'c123',
#   'c011'],
#  ['c070', 'c120', 'c118', 'c097'],
#  ['c011', 'c014', 'c052', 'c059', 'c012', 'c037', 'c154'],
#  ['c061', 'c065', 'c067', 'c097', 'c096', 'c156'],
#  ['c106'],
#  ['c125', 'c124', 'c151', 'c154'],
#  ['c059', 'c106', 'c107', 'c109', 'c015', 'c018', 'c016'],
#  ['c011', 'c020', 'c059', 'c061', 'c062', 'c063', 'c156'],
#  ['c015', 'c087', 'c144'],
#  ['c098', 'c020', 'c130', 'c099'],
#  ['c008', 'c061', 'c112', 'c113', 'c107'],
#  ['c001', 'c005', 'c015', 'c019'],
#  ['c096'],
#  ['c062', 'c107', 'c109', 'c118', 'c119', 'c106', 'c106'],
#  ['c051', 'c014', 'c152', 'c009', 'c048', 'c059', 'c011', 'c151'],
#  ['c059', 'c132', 'c152', 'c131', 'c141', 'c149', 'c154', 'c008'],
#  ['c148', 'c152', 'c033', 'c131', 'c132'],
#  ['c076', 'c009', 'c080', 'c077'],
#  ['c081', 'c113', 'c112', 'c123', 'c151', 'c108', 'c109'],
#  ['c011', 'c059', 'c009', 'c020', 'c041', 'c039'],
#  ['c006', 'c008', 'c097', 'c082', 'c063', 'c156'],
#  ['c108', 'c009', 'c107', 'c151', 'c106', 'c059', 'c011', 'c107', 'c118'],
#  ['c061', 'c072', 'c156'],
#  ['c098', 'c102', 'c127', 'c008', 'c097', 'c152'],
#  ['c082', 'c020', 'c020', 'c081', 'c021', 'c113', 'c008', 'c130'],
#  ['c098',
#   'c102',
#   'c127',
#   'c099',
#   'c073',
#   'c000',
#   'c071',
#   'c070',
#   'c075',
#   'c001'],
#  ['c081', 'c034', 'c112', 'c148', 'c037'],
#  ['c110', 'c153', 'c072', 'c070', 'c118', 'c107', 'c106'],
#  ['c006',
#   'c008',
#   'c097',
#   'c112',
#   'c141',
#   'c154',
#   'c113',
#   'c151',
#   'c125',
#   'c114'],
#  ['c118', 'c006', 'c142', 'c147'],
#  ['c123', 'c151', 'c154', 'c097', 'c033', 'c035', 'c059', 'c153'],
#  ['c008', 'c097', 'c119', 'c118', 'c121', 'c006', 'c081', 'c104', 'c120'],
#  ['c059', 'c061', 'c150', 'c065', 'c156'],
#  ['c015', 'c115', 'c016', 'c087'],
#  ['c026', 'c123', 'c027', 'c156', 'c032', 'c018', 'c019', 'c063'],
#  ['c026', 'c032', 'c059', 'c115', 'c145', 'c110', 'c118', 'c106', 'c009'],
#  ['c006', 'c152', 'c088', 'c082', 'c083', 'c023', 'c020'],
#  ['c086', 'c012'],
#  ['c118', 'c015', 'c016', 'c018', 'c102', 'c127', 'c099'],
#  ['c117', 'c026', 'c028'],
#  ['c089',
#   'c030',
#   'c117',
#   'c125',
#   'c009',
#   'c011',
#   'c026',
#   'c032',
#   'c027',
#   'c125'],
#  ['c134', 'c088', 'c084', 'c086', 'c135', 'c107', 'c106'],
#  ['c150',
#   'c028',
#   'c025',
#   'c082',
#   'c016',
#   'c015',
#   'c087',
#   'c030',
#   'c027',
#   'c026',
#   'c009'],
#  ['c076', 'c153', 'c079', 'c102', 'c127'],
#  ['c094', 'c152', 'c144', 'c096'],
#  ['c107',
#   'c135',
#   'c108',
#   'c062',
#   'c109',
#   'c119',
#   'c057',
#   'c134',
#   'c118',
#   'c061'],
#  ['c118', 'c119', 'c148'],
#  ['c151',
#   'c011',
#   'c095',
#   'c034',
#   'c036',
#   'c059',
#   'c009',
#   'c033',
#   'c035',
#   'c093',
#   'c014',
#   'c038'],
#  ['c008',
#   'c154',
#   'c025',
#   'c030',
#   'c082',
#   'c097',
#   'c026',
#   'c032',
#   'c081',
#   'c028',
#   'c096',
#   'c152',
#   'c151',
#   'c135'],
#  ['c018', 'c097', 'c152', 'c092', 'c017', 'c015'],
#  ['c016', 'c093'],
#  ['c143', 'c063', 'c061', 'c142', 'c062', 'c147'],
#  ['c019', 'c097', 'c129', 'c153'],
#  ['c021', 'c061', 'c061', 'c156', 'c113', 'c141', 'c020', 'c023', 'c112'],
#  ['c033', 'c113', 'c112', 'c143', 'c063', 'c063', 'c142', 'c061'],
#  ['c026', 'c027', 'c032', 'c151', 'c123'],
#  ['c033', 'c141'],
#  ['c142', 'c094', 'c147', 'c119'],
#  ['c096', 'c141', 'c008', 'c097', 'c155', 'c155', 'c000', 'c153'],
#  ['c009', 'c097'],
#  ['c026', 'c106', 'c032', 'c025'],
#  ['c076', 'c097', 'c113', 'c077', 'c112'],
#  ['c054', 'c126', 'c106', 'c110', 'c118', 'c119', 'c107'],
#  ['c120', 'c119', 'c150'],
#  ['c137', 'c118', 'c061', 'c097', 'c006'],
#  ['c093', 'c096', 'c128'],
#  ['c098', 'c149', 'c152', 'c084', 'c088', 'c016'],
#  ['c080', 'c001', 'c113', 'c112', 'c123', 'c004', 'c002', 'c000'],
#  ['c079', 'c080', 'c152', 'c108'],
#  ['c009', 'c011', 'c051', 'c059', 'c076', 'c153'],
#  ['c084', 'c088', 'c141', 'c008', 'c088', 'c081', 'c086'],
#  ['c135', 'c129', 'c106', 'c154', 'c151', 'c097'],
#  ['c046', 'c052'],
#  ['c021', 'c135', 'c149'],
#  ['c011', 'c051', 'c153'],
#  ['c087', 'c015'],
#  ['c152', 'c132', 'c106', 'c123', 'c107'],
#  ['c051', 'c052', 'c155', 'c096', 'c154'],
#  ['c106', 'c107', 'c142', 'c147', 'c143', 'c156', 'c063'],
#  ['c093'],
#  ['c015', 'c019', 'c059', 'c061', 'c156', 'c063', 'c016', 'c087'],
#  ['c118',
#   'c147',
#   'c142',
#   'c062',
#   'c130',
#   'c118',
#   'c008',
#   'c143',
#   'c063',
#   'c006'],
#  ['c026', 'c030', 'c097', 'c008', 'c113', 'c009', 'c028'],
#  ['c015', 'c016', 'c070', 'c072'],
#  ['c053', 'c125', 'c061', 'c118', 'c065', 'c156', 'c006', 'c054', 'c154'],
#  ['c097', 'c040', 'c141', 'c008'],
#  ['c143', 'c142', 'c147', 'c064'],
#  ['c075', 'c071', 'c020', 'c021', 'c156'],
#  ['c053', 'c098', 'c126', 'c054', 'c127', 'c102'],
#  ['c097', 'c152'],
#  ['c084', 'c115', 'c125', 'c154', 'c153', 'c086', 'c110'],
#  ['c059', 'c107', 'c154', 'c108', 'c106'],
#  ['c015', 'c016', 'c009', 'c017', 'c144', 'c106'],
#  ['c149'],
#  ['c062', 'c015', 'c018', 'c016'],
#  ['c143', 'c142', 'c132'],
#  ['c015', 'c155', 'c003', 'c001'],
#  ['c070', 'c055', 'c097', 'c154'],
#  ['c106', 'c040', 'c044'],
#  ['c006', 'c097', 'c150'],
#  ['c000', 'c148', 'c096', 'c149'],
#  ['c128', 'c129', 'c097', 'c006'],
#  ['c096', 'c116', 'c117', 'c115', 'c097', 'c097'],
#  ['c009', 'c106', 'c152'],
#  ['c107', 'c123', 'c153', 'c106'],
#  ['c061', 'c065', 'c097', 'c156', 'c110', 'c105', 'c039', 'c108'],
#  ['c107', 'c104', 'c038', 'c140', 'c106', 'c033', 'c097', 'c150'],
#  ['c015', 'c016', 'c052', 'c104'],
#  ['c020',
#   'c005',
#   'c023',
#   'c002',
#   'c004',
#   'c021',
#   'c000',
#   'c001',
#   'c000',
#   'c000',
#   'c106'],
#  ['c098', 'c127', 'c155', 'c000'],
#  ['c134',
#   'c146',
#   'c133',
#   'c017',
#   'c128',
#   'c129',
#   'c096',
#   'c009',
#   'c015',
#   'c016'],
#  ['c061', 'c062', 'c063', 'c123', 'c156', 'c030', 'c026'],
#  ['c006', 'c141', 'c008', 'c097', 'c073', 'c070'],
#  ['c026', 'c124', 'c154', 'c028', 'c031', 'c097', 'c146', 'c032'],
#  ['c076', 'c080', 'c149', 'c125', 'c156', 'c151'],
#  ['c118', 'c121', 'c139', 'c002', 'c121', 'c000'],
#  ['c139', 'c150', 'c097', 'c128', 'c038', 'c095'],
#  ['c051', 'c052', 'c125', 'c135', 'c061', 'c128', 'c129', 'c156', 'c046'],
#  ['c059', 'c115', 'c126', 'c149', 'c152'],
#  ['c015', 'c019', 'c092'],
#  ['c000', 'c148', 'c000', 'c155', 'c141', 'c003', 'c001', 'c153'],
#  ['c011',
#   'c063',
#   'c021',
#   'c149',
#   'c152',
#   'c149',
#   'c152',
#   'c106',
#   'c061',
#   'c156'],
#  ['c118', 'c120', 'c119'],
#  ['c020', 'c024', 'c022', 'c130'],
#  ['c059', 'c061', 'c065', 'c115', 'c145', 'c156', 'c132'],
#  ['c153', 'c097', 'c151', 'c125', 'c061'],
#  ['c048', 'c052', 'c033', 'c151', 'c150', 'c047', 'c070', 'c050', 'c125'],
#  ['c034',
#   'c004',
#   'c026',
#   'c030',
#   'c027',
#   'c032',
#   'c096',
#   'c035',
#   'c095',
#   'c033',
#   'c038',
#   'c038'],
#  ['c070',
#   'c072',
#   'c076',
#   'c078',
#   'c122',
#   'c132',
#   'c071',
#   'c068',
#   'c154',
#   'c069',
#   'c067',
#   'c156',
#   'c065',
#   'c077'],
#  ['c130', 'c008', 'c113', 'c112', 'c081', 'c082', 'c114'],
#  ['c009', 'c049', 'c023', 'c150', 'c041'],
#  ['c015', 'c016', 'c017', 'c104'],
#  ['c082'],
#  ['c026', 'c032', 'c153', 'c029', 'c152', 'c029'],
#  ['c104',
#   'c096',
#   'c030',
#   'c026',
#   'c027',
#   'c032',
#   'c097',
#   'c144',
#   'c152',
#   'c094'],
#  ['c004', 'c021', 'c001', 'c003'],
#  ['c150', 'c053', 'c097', 'c153'],
#  ['c009',
#   'c010',
#   'c011',
#   'c014',
#   'c026',
#   'c028',
#   'c032',
#   'c061',
#   'c063',
#   'c069',
#   'c106',
#   'c110',
#   'c115',
#   'c117',
#   'c145',
#   'c116',
#   'c107',
#   'c067'],
#  ['c006', 'c015', 'c112'],
#  ['c143', 'c142', 'c121'],
#  ['c026', 'c115', 'c145', 'c008', 'c141', 'c006', 'c147'],
#  ['c020', 'c155', 'c009', 'c130', 'c022', 'c002'],
#  ['c151', 'c135', 'c065', 'c092', 'c154'],
#  ['c011', 'c059', 'c152', 'c088'],
#  ['c102', 'c137', 'c127'],
#  ['c081', 'c130', 'c062', 'c066', 'c147'],
#  ['c012',
#   'c119',
#   'c130',
#   'c042',
#   'c113',
#   'c114',
#   'c081',
#   'c113',
#   'c112',
#   'c021',
#   'c009'],
#  ['c149', 'c108'],
#  ['c020',
#   'c033',
#   'c034',
#   'c036',
#   'c070',
#   'c075',
#   'c107',
#   'c009',
#   'c151',
#   'c011',
#   'c106',
#   'c071',
#   'c024'],
#  ['c003', 'c080'],
#  ['c000', 'c001', 'c148', 'c110', 'c118', 'c106', 'c075', 'c071'],
#  ['c150', 'c097', 'c104', 'c090', 'c113'],
#  ['c033', 'c034', 'c038', 'c152', 'c153'],
#  ['c008', 'c141', 'c143', 'c006', 'c142', 'c002', 'c000'],
#  ['c020', 'c034', 'c071', 'c075'],
#  ['c098', 'c102', 'c127', 'c149', 'c061', 'c063', 'c062', 'c130', 'c081'],
#  ['c000', 'c070', 'c067', 'c072', 'c156'],
#  ['c096', 'c148', 'c008'],
#  ['c061', 'c118', 'c008', 'c097', 'c106'],
#  ['c008', 'c097', 'c056', 'c057', 'c053'],
#  ['c070', 'c097', 'c040', 'c043', 'c081', 'c042', 'c071', 'c034'],
#  ['c070',
#   'c071',
#   'c106',
#   'c106',
#   'c074',
#   'c120',
#   'c118',
#   'c119',
#   'c075',
#   'c110'],
#  ['c150', 'c015', 'c016'],
#  ['c040', 'c059', 'c011', 'c042', 'c097', 'c154', 'c149'],
#  ['c008', 'c152', 'c004', 'c006', 'c154', 'c001', 'c054'],
#  ['c123', 'c154', 'c073', 'c070', 'c030', 'c026'],
#  ['c020',
#   'c062',
#   'c063',
#   'c081',
#   'c130',
#   'c152',
#   'c081',
#   'c081',
#   'c110',
#   'c109',
#   'c063',
#   'c063'],
#  ['c026',
#   'c027',
#   'c027',
#   'c028',
#   'c032',
#   'c117',
#   'c025',
#   'c028',
#   'c031',
#   'c117',
#   'c083',
#   'c084',
#   'c088'],
#  ['c147', 'c128'],
#  ['c106', 'c143', 'c106', 'c061'],
#  ['c006',
#   'c008',
#   'c112',
#   'c125',
#   'c081',
#   'c114',
#   'c082',
#   'c127',
#   'c027',
#   'c028',
#   'c032',
#   'c025'],
#  ['c104', 'c016', 'c154', 'c059', 'c151', 'c015', 'c017', 'c018', 'c097'],
#  ['c033', 'c061', 'c070'],
#  ['c134',
#   'c146',
#   'c000',
#   'c154',
#   'c077',
#   'c074',
#   'c004',
#   'c002',
#   'c127',
#   'c135',
#   'c126',
#   'c003'],
#  ['c127', 'c137', 'c110', 'c107', 'c118', 'c106', 'c009'],
#  ['c051', 'c046', 'c052'],
#  ['c125', 'c154', 'c079', 'c126', 'c077', 'c151'],
#  ['c001', 'c076', 'c077', 'c081', 'c074', 'c126'],
#  ['c003', 'c087', 'c015', 'c155'],
#  ['c107',
#   'c110',
#   'c118',
#   'c119',
#   'c120',
#   'c148',
#   'c001',
#   'c000',
#   'c148',
#   'c105'],
#  ['c097',
#   'c079',
#   'c035',
#   'c151',
#   'c006',
#   'c078',
#   'c076',
#   'c150',
#   'c034',
#   'c135',
#   'c077',
#   'c154',
#   'c033'],
#  ['c060', 'c103', 'c151'],
#  ['c097', 'c008', 'c118', 'c061', 'c152', 'c149', 'c006'],
#  ['c059', 'c081', 'c107', 'c109', 'c110', 'c106', 'c154', 'c082'],
#  ['c004', 'c016', 'c015', 'c018', 'c001', 'c002'],
#  ['c033', 'c097', 'c153', 'c008'],
#  ['c153', 'c144'],
#  ['c016', 'c009', 'c017', 'c014', 'c052'],
#  ['c149', 'c152', 'c097', 'c152'],
#  ['c093', 'c096', 'c041', 'c044', 'c042', 'c039', 'c040', 'c043'],
#  ['c015', 'c122', 'c146', 'c154', 'c107', 'c110', 'c106'],
#  ['c005',
#   'c040',
#   'c041',
#   'c041',
#   'c044',
#   'c009',
#   'c039',
#   'c097',
#   'c039',
#   'c042'],
#  ['c002',
#   'c153',
#   'c155',
#   'c120',
#   'c119',
#   'c118',
#   'c121',
#   'c069',
#   'c156',
#   'c067',
#   'c065'],
#  ['c149', 'c020', 'c024', 'c142', 'c143'],
#  ['c072', 'c132', 'c134', 'c070'],
#  ['c061', 'c128', 'c153'],
#  ['c141', 'c008', 'c097', 'c006', 'c150', 'c086'],
#  ['c107', 'c154', 'c110', 'c108', 'c123', 'c106', 'c109', 'c009'],
#  ['c094', 'c096', 'c152', 'c154', 'c113', 'c114'],
#  ['c026', 'c032', 'c135', 'c025', 'c109', 'c106', 'c154'],
#  ['c078',
#   'c080',
#   'c134',
#   'c146',
#   'c133',
#   'c077',
#   'c126',
#   'c135',
#   'c076',
#   'c152',
#   'c079'],
#  ['c139', 'c035', 'c038', 'c153', 'c034', 'c137', 'c127', 'c153'],
#  ['c143', 'c142', 'c153', 'c063', 'c130', 'c020'],
#  ['c076', 'c107', 'c150', 'c123', 'c080', 'c151'],
#  ['c059', 'c114', 'c063', 'c097', 'c154'],
#  ['c143', 'c130', 'c063', 'c120', 'c147', 'c062', 'c061'],
#  ['c038', 'c059', 'c070', 'c154', 'c100', 'c152', 'c149', 'c034'],
#  ['c002',
#   'c004',
#   'c081',
#   'c082',
#   'c114',
#   'c154',
#   'c023',
#   'c127',
#   'c000',
#   'c020',
#   'c021',
#   'c001',
#   'c035',
#   'c033',
#   'c034'],
#  ['c137', 'c141'],
#  ['c147', 'c143'],
#  ['c128', 'c152', 'c149', 'c107', 'c000', 'c153', 'c155'],
#  ['c011', 'c052', 'c059', 'c152', 'c153'],
#  ['c033', 'c096'],
#  ['c154', 'c114', 'c060', 'c063', 'c113', 'c082', 'c063'],
#  ['c008', 'c097', 'c123', 'c151', 'c107', 'c006', 'c132', 'c120', 'c118'],
#  ['c065', 'c067', 'c118', 'c156', 'c097'],
#  ['c107', 'c125', 'c092', 'c109', 'c153'],
#  ['c150', 'c141', 'c008'],
#  ['c015', 'c016', 'c087', 'c123', 'c152', 'c087'],
#  ['c131', 'c132', 'c149', 'c148'],
#  ['c019', 'c008', 'c055', 'c152', 'c148', 'c097', 'c151', 'c152', 'c059'],
#  ['c011', 'c015', 'c016', 'c059', 'c009', 'c017', 'c153', 'c154', 'c150'],
#  ['c006', 'c008', 'c020', 'c097', 'c141', 'c021', 'c006', 'c153'],
#  ['c020', 'c020', 'c143', 'c142', 'c021', 'c062', 'c130', 'c061'],
#  ['c015', 'c016', 'c017', 'c081', 'c061', 'c063'],
#  ['c041'],
#  ['c016', 'c147', 'c015'],
#  ['c059', 'c076', 'c078'],
#  ['c133',
#   'c134',
#   'c146',
#   'c072',
#   'c063',
#   'c156',
#   'c107',
#   'c129',
#   'c106',
#   'c009',
#   'c118'],
#  ['c016', 'c151', 'c015', 'c087', 'c135'],
#  ['c082', 'c114'],
#  ['c128', 'c126', 'c154', 'c096', 'c094'],
#  ['c106', 'c107', 'c009', 'c109'],
#  ['c000', 'c004', 'c020', 'c076', 'c149', 'c003', 'c022', 'c126', 'c077'],
#  ['c098'],
#  ['c107',
#   'c106',
#   'c009',
#   'c109',
#   'c050',
#   'c008',
#   'c047',
#   'c097',
#   'c141',
#   'c006'],
#  ['c145', 'c092', 'c152'],
#  ['c011', 'c059', 'c108', 'c109', 'c118', 'c106'],
#  ['c150', 'c152', 'c097', 'c149'],
#  ['c101', 'c126', 'c113', 'c006', 'c112'],
#  ['c106', 'c152'],
#  ['c047', 'c049', 'c009', 'c046', 'c097'],
#  ['c139'],
#  ['c031', 'c009', 'c109'],
#  ['c107', 'c110', 'c128', 'c106'],
#  ['c020', 'c021', 'c127', 'c054', 'c040', 'c152', 'c043'],
#  ['c006',
#   'c008',
#   'c020',
#   'c023',
#   'c097',
#   'c141',
#   'c021',
#   'c002',
#   'c148',
#   'c022',
#   'c000'],
#  ['c096', 'c148', 'c055'],
#  ['c118', 'c119', 'c151', 'c132', 'c097'],
#  ['c011', 'c059', 'c137', 'c153', 'c152', 'c127'],
#  ['c011', 'c059', 'c149', 'c145', 'c064'],
#  ['c020',
#   'c023',
#   'c001',
#   'c097',
#   'c141',
#   'c006',
#   'c022',
#   'c021',
#   'c002',
#   'c000',
#   'c004'],
#  ['c073', 'c071', 'c009', 'c070', 'c075'],
#  ['c132', 'c151', 'c135', 'c022'],
#  ['c106', 'c107', 'c152', 'c149', 'c127', 'c058', 'c056', 'c057'],
#  ['c081', 'c106'],
#  ['c060', 'c103', 'c151', 'c011', 'c059', 'c107', 'c106'],
#  ['c009', 'c040', 'c042', 'c112', 'c113'],
#  ['c098', 'c102', 'c126', 'c080', 'c127'],
#  ['c154', 'c148', 'c002', 'c000', 'c123', 'c151'],
#  ['c114', 'c141', 'c018', 'c015', 'c017', 'c113'],
#  ['c110', 'c106', 'c151', 'c123', 'c009', 'c109', 'c057'],
#  ['c015', 'c016', 'c147'],
#  ['c077', 'c080', 'c106', 'c009', 'c107'],
#  ['c015', 'c134', 'c146', 'c152', 'c106', 'c129', 'c009', 'c154', 'c107'],
#  ['c127', 'c137', 'c018', 'c015', 'c019'],
#  ['c012', 'c098', 'c009'],
#  ['c070', 'c122', 'c146', 'c071'],
#  ['c124', 'c146', 'c154', 'c150', 'c002', 'c035', 'c097', 'c125'],
#  ['c086', 'c088', 'c154', 'c110', 'c106', 'c107'],
#  ['c026', 'c032', 'c027', 'c025', 'c108', 'c106'],
#  ['c020', 'c097', 'c006', 'c022', 'c024', 'c008', 'c141'],
#  ['c098', 'c102', 'c154', 'c127', 'c152'],
#  ['c015', 'c016', 'c018', 'c087', 'c000', 'c002', 'c148'],
#  ['c070',
#   'c072',
#   'c122',
#   'c130',
#   'c023',
#   'c063',
#   'c020',
#   'c021',
#   'c009',
#   'c062',
#   'c022',
#   'c146',
#   'c071',
#   'c154'],
#  ['c113', 'c130', 'c082', 'c042', 'c081', 'c114'],
#  ['c070', 'c075', 'c076'],
#  ['c047', 'c051', 'c107', 'c153', 'c126'],
#  ['c120', 'c106', 'c118'],
#  ['c123', 'c132', 'c065', 'c067', 'c156'],
#  ['c028', 'c081', 'c015', 'c016'],
#  ['c026', 'c027', 'c032', 'c115', 'c124', 'c125', 'c152', 'c025'],
#  ['c020',
#   'c061',
#   'c063',
#   'c063',
#   'c156',
#   'c057',
#   'c126',
#   'c062',
#   'c100',
#   'c098'],
#  ['c061',
#   'c008',
#   'c141',
#   'c006',
#   'c092',
#   'c097',
#   'c062',
#   'c081',
#   'c118',
#   'c156',
#   'c065'],
#  ['c125', 'c136', 'c065', 'c156'],
#  ['c043', 'c040', 'c097', 'c042', 'c081'],
#  ['c011', 'c027', 'c030', 'c026', 'c032', 'c029', 'c152'],
#  ['c011', 'c019', 'c137', 'c152'],
#  ['c012', 'c081', 'c042', 'c022'],
#  ['c061', 'c065', 'c156', 'c067', 'c151', 'c123'],
#  ['c147', 'c155', 'c000', 'c002', 'c097', 'c141'],
#  ['c011', 'c123', 'c062', 'c087', 'c154', 'c015', 'c016'],
#  ['c015', 'c016', 'c053'],
#  ['c051', 'c076', 'c078', 'c125'],
#  ['c020', 'c047', 'c048', 'c021'],
#  ['c026', 'c032', 'c125', 'c027'],
#  ['c015', 'c097', 'c153', 'c062', 'c063', 'c061', 'c065', 'c156'],
#  ['c142', 'c061', 'c128', 'c143', 'c129', 'c156', 'c063'],
#  ['c009', 'c028', 'c031', 'c114', 'c115', 'c116'],
#  ['c123', 'c004', 'c127', 'c002', 'c000', 'c145', 'c106'],
#  ['c011', 'c106', 'c154', 'c150', 'c097', 'c009', 'c151', 'c059'],
#  ['c134', 'c016', 'c152', 'c149'],
#  ['c096', 'c018', 'c015', 'c016', 'c087', 'c148'],
#  ['c118', 'c119', 'c121', 'c010', 'c011', 'c132'],
#  ['c001', 'c072', 'c134', 'c135', 'c154', 'c151', 'c146', 'c133', 'c055'],
#  ['c137', 'c039', 'c147', 'c006'],
#  ['c061', 'c147', 'c081', 'c062', 'c112', 'c113', 'c128', 'c106', 'c129'],
#  ['c033', 'c035', 'c038', 'c140', 'c036'],
#  ['c015', 'c016', 'c051', 'c017'],
#  ['c008', 'c053', 'c097', 'c054'],
#  ['c147', 'c035', 'c114', 'c038', 'c061', 'c062', 'c063'],
#  ['c015', 'c016', 'c033', 'c038', 'c095', 'c114'],
#  ['c033', 'c088', 'c085'],
#  ['c093', 'c081', 'c082'],
#  ['c019', 'c082', 'c096'],
#  ['c107'],
#  ['c015', 'c018', 'c016', 'c152', 'c087'],
#  ['c033', 'c156', 'c119', 'c112', 'c113', 'c118', 'c120', 'c081'],
#  ['c082', 'c004', 'c009', 'c026', 'c030', 'c028', 'c116', 'c002', 'c009'],
#  ['c015', 'c016', 'c149'],
#  ['c096', 'c152', 'c144'],
#  ['c093', 'c096', 'c113', 'c007', 'c112', 'c152'],
#  ['c151', 'c071', 'c073', 'c070', 'c059', 'c009', 'c072'],
#  ['c070', 'c097', 'c118', 'c150'],
#  ['c084'],
#  ['c065', 'c067', 'c087', 'c018', 'c015', 'c016', 'c156', 'c061'],
#  ['c011', 'c059', 'c097', 'c082', 'c014', 'c145'],
#  ['c038', 'c121', 'c092', 'c118', 'c119', 'c120'],
#  ['c092', 'c125', 'c132'],
#  ['c008', 'c097', 'c141', 'c006'],
#  ['c040', 'c150', 'c041', 'c053'],
#  ['c040', 'c042', 'c110', 'c107', 'c106', 'c109', 'c008', 'c125', 'c006'],
#  ['c000', 'c004', 'c001', 'c153'],
#  ['c011',
#   'c026',
#   'c032',
#   'c059',
#   'c123',
#   'c151',
#   'c118',
#   'c097',
#   'c065',
#   'c009',
#   'c068',
#   'c119'],
#  ['c144', 'c141', 'c112', 'c006', 'c113', 'c008'],
#  ['c147', 'c041', 'c062', 'c147'],
#  ['c125', 'c140', 'c141'],
#  ['c061', 'c065', 'c124', 'c145', 'c156'],
#  ['c113', 'c130', 'c062', 'c112', 'c081', 'c082', 'c114'],
#  ['c047',
#   'c052',
#   'c046',
#   'c049',
#   'c069',
#   'c156',
#   'c063',
#   'c065',
#   'c061',
#   'c067'],
#  ['c059',
#   'c132',
#   'c107',
#   'c110',
#   'c106',
#   'c079',
#   'c154',
#   'c077',
#   'c109',
#   'c119'],
#  ['c020', 'c023', 'c008', 'c104', 'c022'],
#  ['c092', 'c082', 'c114', 'c043', 'c040', 'c150'],
#  ['c015',
#   'c016',
#   'c059',
#   'c123',
#   'c077',
#   'c017',
#   'c008',
#   'c141',
#   'c097',
#   'c006',
#   'c076',
#   'c154'],
#  ['c132', 'c156', 'c131', 'c061', 'c152'],
#  ['c018', 'c021', 'c059', 'c015', 'c016'],
#  ['c147'],
#  ['c015', 'c016', 'c033', 'c037'],
#  ['c144', 'c097', 'c148', 'c001', 'c153'],
#  ['c150',
#   'c154',
#   'c151',
#   'c156',
#   'c120',
#   'c118',
#   'c011',
#   'c059',
#   'c119',
#   'c009',
#   'c012',
#   'c145'],
#  ['c011', 'c014', 'c009', 'c107', 'c106', 'c152'],
#  ['c015', 'c135', 'c016', 'c017', 'c117', 'c154', 'c087'],
#  ['c022', 'c036', 'c020', 'c149', 'c097', 'c024', 'c114', 'c127'],
#  ['c026', 'c032', 'c085', 'c149', 'c097', 'c033', 'c029', 'c009', 'c017'],
#  ['c155', 'c107', 'c106', 'c002', 'c026', 'c032', 'c027', 'c030'],
#  ['c020', 'c061', 'c022', 'c062'],
#  ['c059', 'c076', 'c092'],
#  ['c033', 'c070', 'c152'],
#  ['c057', 'c144', 'c053', 'c054', 'c058', 'c126'],
#  ['c092', 'c020', 'c021', 'c002', 'c056'],
#  ['c124', 'c000', 'c002', 'c148', 'c080', 'c154', 'c097', 'c008', 'c146'],
#  ['c015', 'c016', 'c135', 'c154', 'c008', 'c097'],
#  ['c008', 'c141', 'c054', 'c059', 'c055', 'c151'],
#  ['c061', 'c065', 'c156', 'c015', 'c016'],
#  ['c149', 'c152', 'c075', 'c073', 'c070', 'c009', 'c012'],
#  ['c059', 'c051', 'c052', 'c014', 'c088'],
#  ['c008', 'c113', 'c006', 'c141'],
#  ['c118', 'c119', 'c081'],
#  ['c008', 'c082', 'c114', 'c062', 'c038', 'c112'],
#  ['c124', 'c125', 'c146', 'c115', 'c117', 'c154', 'c081', 'c116'],
#  ['c072', 'c122', 'c146', 'c069', 'c067', 'c061'],
#  ['c081', 'c155', 'c002', 'c000'],
#  ['c011', 'c014', 'c032', 'c059', 'c025', 'c149', 'c152', 'c154'],
#  ['c153', 'c008', 'c079', 'c076'],
#  ['c117',
#   'c031',
#   'c024',
#   'c026',
#   'c115',
#   'c021',
#   'c144',
#   'c097',
#   'c020',
#   'c030'],
#  ['c059', 'c155', 'c000', 'c001', 'c003', 'c054', 'c058', 'c053'],
#  ['c040', 'c112', 'c114', 'c113', 'c042', 'c081'],
#  ['c040', 'c042', 'c009', 'c041', 'c044', 'c117', 'c097'],
#  ['c129', 'c000', 'c095', 'c106'],
#  ['c033', 'c125', 'c149', 'c152'],
#  ['c015', 'c016', 'c087', 'c009', 'c017', 'c151', 'c134', 'c122'],
#  ['c015', 'c019', 'c021', 'c061', 'c063', 'c062', 'c147', 'c018'],
#  ['c152', 'c155', 'c113', 'c155'],
#  ['c123', 'c156', 'c015', 'c016', 'c018'],
#  ['c026',
#   'c072',
#   'c115',
#   'c122',
#   'c146',
#   'c116',
#   'c028',
#   'c153',
#   'c070',
#   'c071',
#   'c154'],
#  ['c133', 'c134', 'c146', 'c075', 'c135', 'c154'],
#  ['c023', 'c153', 'c057', 'c112', 'c113'],
#  ['c033', 'c072', 'c037', 'c034', 'c073', 'c070'],
#  ['c072',
#   'c076',
#   'c077',
#   'c078',
#   'c133',
#   'c134',
#   'c070',
#   'c001',
#   'c003',
#   'c036',
#   'c154',
#   'c097',
#   'c071',
#   'c002',
#   'c000'],
#  ['c014', 'c085', 'c149', 'c154', 'c151', 'c052', 'c059', 'c011'],
#  ['c033', 'c090', 'c113', 'c153'],
#  ['c124', 'c070', 'c071', 'c074', 'c146', 'c154', 'c073'],
#  ['c011',
#   'c061',
#   'c065',
#   'c067',
#   'c069',
#   'c156',
#   'c062',
#   'c068',
#   'c035',
#   'c033',
#   'c038'],
#  ['c096', 'c144', 'c153', 'c015', 'c019', 'c152', 'c094'],
#  ['c107', 'c118'],
#  ['c154', 'c106', 'c109'],
#  ['c137', 'c098', 'c000', 'c076', 'c001', 'c148'],
#  ['c017', 'c154', 'c012', 'c054', 'c058', 'c053', 'c016'],
#  ['c015', 'c113', 'c002', 'c019', 'c149', 'c148'],
#  ['c061', 'c062', 'c063', 'c064', 'c147', 'c017', 'c018', 'c087', 'c015'],
#  ['c063', 'c069', 'c061', 'c051', 'c062', 'c064', 'c068'],
#  ['c011', 'c014', 'c059', 'c115', 'c145', 'c156', 'c062', 'c063'],
#  ...]

# %%
class_count = np.load('class_counts.npy')

cnt1 = np.zeros(result.shape[0], dtype=int) # class count
cnt2 = np.zeros(result.shape[0], dtype=int)
for i in range(0, result.shape[0]): 
    cls1 = result['1st class'][i]
    cls2 = result['2nd class'][i]
    cnt1[i] = class_count[int(cls1[-3:])]
    cnt2[i] = class_count[int(cls2[-3:])]
result['cnt1'] = cnt1
result['cnt2'] = cnt2

# %%
# result[0:50] # 0, 1, 2, 3, 6, 7, 8, 9
# 1st 困難：8	c089	Closing a window\n	c090	Opening a window\n	
# 2nd 困難：how about 3 and 7? c084有兩種結果...

# 0, 1, 3, 5, 21, 23
# door, chair, cup/dishes, picture, laptop, window

MIN_CNT = 0 # 不知道會不會太少
tmp = result[result['cnt1'] >= MIN_CNT]
tmp = tmp[tmp['cnt2'] >= MIN_CNT]
# tmp[tmp['2nd class'] == 'c019']
tmp[0:50]
# 
# 20180117: 
# 1. Chair, Light(none)
# 6. Bottle/Wine Glass/Cup, Dishes(none)
# (x)10 and 21. Laptop
# 29. Laptop
# 11. Regrigerator
# (x)12. Bed 
# 20. Bed
# phone? too low mut info
# 99. Sandwich
# 389. phone/camera

# 1, 6, 11, 20, 29, 99, 389
# Out:
#    1st class                            1st class name 2nd class  \
# 0       c007                           Fixing a door\n      c140
# 1       c060                     Standing on a chair\n      c103
# 2       c099               Putting a broom somewhere\n      c101
# 3       c084                       Holding a picture\n      c086
# 4       c083     Reaching for and grabbing a picture\n      c086
# 5       c083     Reaching for and grabbing a picture\n      c084
# 6       c111              Washing a cup/glass/bottle\n      c121
# 7       c084                       Holding a picture\n      c085
# 8       c089                        Closing a window\n      c090
# 9       c012                      Tidying up a table\n      c013
# 10      c049              Putting a laptop somewhere\n      c050
# 11      c142                  Closing a refrigerator\n      c143
# 12      c133             Someone is awakening in bed\n      c146
# 13      c083     Reaching for and grabbing a picture\n      c088
# 14      c039                           Closing a box\n      c041
# 15      c086             Putting a picture somewhere\n      c088
# 16      c084                       Holding a picture\n      c088
# 17      c137                        Holding a vacuum\n      c138
# 18      c085                   Laughing at a picture\n      c088
# 19      c083     Reaching for and grabbing a picture\n      c085
# 20      c133             Someone is awakening in bed\n      c134
# 21      c047                        Holding a laptop\n      c050
# 22      c041                           Opening a box\n      c044
# 23      c068            Putting a sandwich somewhere\n      c069
# 24      c048                        Opening a laptop\n      c049
# 25      c047                        Holding a laptop\n      c049
# 26      c048                        Opening a laptop\n      c050
# 27      c013                         Washing a table\n      c038
# 28      c038          Washing something with a towel\n      c095
# 29      c046                        Closing a laptop\n      c049
# 30      c077              Putting a pillow somewhere\n      c079
# 31      c100           Taking a broom from somewhere\n      c101
# 32      c071             Putting a blanket somewhere\n      c074
# 33      c131                  Laughing at television\n      c132
# 34      c057                   Taking off some shoes\n      c058
# 35      c042                 Putting a box somewhere\n      c043
# 36      c089                        Closing a window\n      c091
# 37      c098                         Holding a broom\n      c101
# 38      c040                           Holding a box\n      c043
# 39      c098                         Holding a broom\n      c100
# 40      c098                         Holding a broom\n      c099
# 41      c085                   Laughing at a picture\n      c086
# 42      c128                   Holding some medicine\n      c129
# 43      c053                    Holding a shoe/shoes\n      c054
# 44      c053                    Holding a shoe/shoes\n      c056
# 45      c116  Putting their paper/notebook somewhere\n      c117
# 46      c046                        Closing a laptop\n      c048
# 47      c095                        Washing a mirror\n      c111
# 48      c093                        Holding a mirror\n      c094
# 49      c025                          Closing a book\n      c027
#
#                             2nd class name pointwise mutual info  cnt1  cnt2
# 0                      Fixing a doorknob\n    11.737787296221445    27    31
# 1                         Fixing a light\n    11.583459149830153    46    36
# 2             Throwing a broom somewhere\n    10.896124323388547   100    25
# 3            Putting a picture somewhere\n     10.72689898007871   133    62
# 4            Putting a picture somewhere\n    10.636858387370665    74    62
# 5                      Holding a picture\n    10.597172806920494    74   133
# 6                     Wash a dish/dishes\n    10.439843841877822    49   112
# 7                  Laughing at a picture\n    10.414308749770683   133    28
# 8                       Opening a window\n    10.354009670361135    53    87
# 9                        Washing a table\n    10.270811321157376   202    42
# 10        Taking a laptop from somewhere\n     10.26958045764027    91    82
# 11                Opening a refrigerator\n    10.185630940583533   192   250
# 12        Someone is awakening somewhere\n    10.151863078913797    98   245
# 13         Watching/looking at a picture\n     10.13857583976201    74   198
# 14                         Opening a box\n    10.122875057088002    96   181
# 15         Watching/looking at a picture\n     10.11965793156509    62   198
# 16         Watching/looking at a picture\n     10.11586900780569   133   198
# 17        Taking a vacuum from somewhere\n    10.101663895717659   213    57
# 18         Watching/looking at a picture\n    10.088162078635849    28   198
# 19                 Laughing at a picture\n    10.067492741700528    74    28
# 20                        Lying on a bed\n     9.996461716905015    98   257
# 21        Taking a laptop from somewhere\n      9.99004865627518   259    82
# 22           Taking something from a box\n      9.98604711051777   181   154
# 23      Taking a sandwich from somewhere\n     9.964644907382208   154   161
# 24            Putting a laptop somewhere\n     9.947149769108776    99    91
# 25            Putting a laptop somewhere\n     9.942167738324244   259    91
# 26        Taking a laptop from somewhere\n     9.933893672406509    99    82
# 27        Washing something with a towel\n     9.884628684550718    42   232
# 28                      Washing a mirror\n      9.85336793634768   232    37
# 29            Putting a laptop somewhere\n     9.825734995497148   100    91
# 30        Taking a pillow from somewhere\n     9.677923833833646   171   161
# 31            Throwing a broom somewhere\n     9.644405230782587   127    25
# 32          Throwing a blanket somewhere\n     9.638107992321377   205   105
# 33                   Watching television\n     9.611787872888646    46   353
# 34              Throwing shoes somewhere\n      9.60169472127922   196    73
# 35           Taking a box from somewhere\n     9.593472938458172   201   180
# 36                      Washing a window\n     9.585551528791393    53    39
# 37            Throwing a broom somewhere\n     9.584726895993354   364    25
# 38           Taking a box from somewhere\n     9.584330605634896   331   180
# 39         Taking a broom from somewhere\n     9.574882646708723   364   127
# 40             Putting a broom somewhere\n     9.551560032058154   364   100
# 41           Putting a picture somewhere\n     9.515394874884999    28    62
# 42        Taking/consuming some medicine\n      9.49798447018715   282   162
# 43               Putting shoes somewhere\n      9.48431322370023   233   177
# 44           Taking shoes from somewhere\n     9.483149290566596   233   160
# 45  Taking paper/notebook from somewhere\n     9.477811692076841   168   175
# 46                      Opening a laptop\n     9.463164916112442   100    99
# 47            Washing a cup/glass/bottle\n     9.452782897585319    37    49
# 48                   Smiling in a mirror\n     9.451503345358747    94   111
# 49                        Opening a book\n     9.446258681441249   187   280

# %%
picked = [1, 6, 11, 20, 29, 99, 389] 
result_class = []
for i in picked:
    result_class.append(mypmi[i][0])
    result_class.append(mypmi[i][2])

# %%
# result_class.remove('c084') # repeated

# %%
result_class # 14 classes in total
# ['c060',
#  'c103',
#  'c111',
#  'c121',
#  'c142',
#  'c143',
#  'c133',
#  'c134',
#  'c046',
#  'c049',
#  'c065',
#  'c069',
#  'c015',
#  'c019']
# Out:
# ['c060',
#  'c103',
#  'c111',
#  'c121',
#  'c142',
#  'c143',
#  'c133',
#  'c134',
#  'c046',
#  'c049',
#  'c065',
#  'c069',
#  'c015',
#  'c019']

# %%
video_fps = open('video_fps.txt', 'r')
mydict = {}
for line in video_fps.readlines():
#     print(line)
    split = line.split(' ')
    mydict[split[0]] = float(split[1])

# %%
df2 = df

result = []
for (idx, row) in df2.iterrows():
    act = row['actions']
    if True:

        myid = row['id']
        fps = mydict[myid]
        split = act.split(';')
        for myaction in split: #c092 11.90 21.20
            c = myaction.split(' ')
            if c[0] in result_class:
#                 print(myaction + " " + myid + " " + fps)
                arr = []
                arr.append(myid)
                x = myaction.split(' ')
                x1 = float(x[1]) * fps
                x2 = float(x[2]) * fps
                arr.append(x[0])
                arr.append(round(x1))
                arr.append(round(x2))
                arr.append(fps)
                arr.append(myaction)
                result.append(arr)
    else:
        df2 = df2.drop(idx)

# %%
# print(df.shape)
# df = df.reset_index(drop=True)
# df

# %%
# df.to_csv('train.csv')

# %%
sor = sorted(result)

# %%
npsor = np.array(sor)

# %%
npsor.shape
# Out:
# (3123, 6)

# %%
npsor
# Out:
# array([['00YZL', 'c065', '17', '626', '24.0', 'c065 0.70 26.10'],
#        ['00YZL', 'c142', '718', '816', '24.0', 'c142 29.90 34.00'],
#        ['00YZL', 'c143', '610', '816', '24.0', 'c143 25.40 34.00'],
#        ...,
#        ['ZZ89F', 'c143', '66', '126', '8.981', 'c143 7.40 14.00'],
#        ['ZZDBH', 'c015', '10', '318', '10.271', 'c015 1.00 31.00'],
#        ['ZZDBH', 'c019', '21', '318', '10.271', 'c019 2.00 31.00']],
#       dtype='<U18')

# %%
np.savetxt('train.csv', npsor, delimiter=',', fmt='%s')
