# %%
import os
import pandas as pd
import numpy as np
import sklearn
import csv

# %%
df = pd.read_csv('Charades_v1_train.csv')

# %%
df.head()
# Out:
#       id subject         scene  quality  relevance verified  \
# 0  46GP8    HR43       Kitchen      6.0        7.0      Yes
# 1  N11GT    0KZ7        Stairs      6.0        7.0      Yes
# 2  0IH69    6RE8       Bedroom      6.0        5.0      Yes
# 3  KRF68    YA10  Laundry room      6.0        7.0      Yes
# 4  MJO7C    6RE8       Kitchen      6.0        6.0      Yes
#
#                                               script                 objects  \
# 0  A person cooking on a stove while watching som...       food;stove;window
# 1  One person opens up a folded blanket, then sne...     blanket;broom;floor
# 2  A person is seen leaving a cabinet. They then ...  book;box;cabinet;shelf
# 3  A person runs into their laundry room. They gr...      clothes;door;phone
# 4  A person runs into their pantry holding a bott...               cup;phone
#
#                                         descriptions  \
# 0  A person cooks food on a stove before looking ...
# 1  Person at the bottom of the staircase shakes a...
# 2  A person is standing in a bedroom. They walk o...
# 3  A person runs in and shuts door. The person gr...
# 4  A person runs in place while holding a bottle ...
#
#                                              actions  length
# 0                   c092 11.90 21.20;c147 0.00 12.60   24.83
# 1  c098 8.60 14.20;c075 0.00 11.70;c127 0.00 15.2...   18.33
# 2                                                NaN   30.25
# 3  c018 22.60 27.80;c141 4.10 9.60;c148 10.30 25....   30.33
# 4                    c015 0.00 32.00;c107 0.00 32.00   31.38

# %%
print(df.shape)
df = df[pd.notnull(df['actions'])] # drop NA in column['actions']
print(df.shape)

# df = df[df.quality >=6 ]
# df = df[df.relevance == 7] #  和 script 的相關性，但我們不需要管 script ，所以用不到
df['origin_index'] = df.index.values
df.head()
# Out:
# (7985, 11)
# (7811, 11)
#       id subject                                              scene  quality  \
# 0  46GP8    HR43                                            Kitchen      6.0
# 1  N11GT    0KZ7                                             Stairs      6.0
# 3  KRF68    YA10                                       Laundry room      6.0
# 4  MJO7C    6RE8                                            Kitchen      6.0
# 5  S6MPZ    EA2K  Home Office / Study (A room in a house used fo...      6.0
#
#    relevance verified                                             script  \
# 0        7.0      Yes  A person cooking on a stove while watching som...
# 1        7.0      Yes  One person opens up a folded blanket, then sne...
# 3        7.0      Yes  A person runs into their laundry room. They gr...
# 4        6.0      Yes  A person runs into their pantry holding a bott...
# 5        6.0      Yes  A person is eating at the desk and lying the p...
#
#                                     objects  \
# 0                         food;stove;window
# 1                       blanket;broom;floor
# 3                        clothes;door;phone
# 4                                 cup;phone
# 5  chair;desk;food;phone;plate;snacks;table
#
#                                         descriptions  \
# 0  A person cooks food on a stove before looking ...
# 1  Person at the bottom of the staircase shakes a...
# 3  A person runs in and shuts door. The person gr...
# 4  A person runs in place while holding a bottle ...
# 5  A person in a blue shirt is eating snacks off ...
#
#                                              actions  length  origin_index
# 0                   c092 11.90 21.20;c147 0.00 12.60   24.83             0
# 1  c098 8.60 14.20;c075 0.00 11.70;c127 0.00 15.2...   18.33             1
# 3  c018 22.60 27.80;c141 4.10 9.60;c148 10.30 25....   30.33             3
# 4                    c015 0.00 32.00;c107 0.00 32.00   31.38             4
# 5  c009 0.00 4.30;c011 0.00 39.00;c015 0.00 39.00...   38.46             5

# %%
df = df.reset_index(drop=True)
df.head()
# Out:
#       id subject                                              scene  quality  \
# 0  46GP8    HR43                                            Kitchen      6.0
# 1  N11GT    0KZ7                                             Stairs      6.0
# 2  KRF68    YA10                                       Laundry room      6.0
# 3  MJO7C    6RE8                                            Kitchen      6.0
# 4  S6MPZ    EA2K  Home Office / Study (A room in a house used fo...      6.0
#
#    relevance verified                                             script  \
# 0        7.0      Yes  A person cooking on a stove while watching som...
# 1        7.0      Yes  One person opens up a folded blanket, then sne...
# 2        7.0      Yes  A person runs into their laundry room. They gr...
# 3        6.0      Yes  A person runs into their pantry holding a bott...
# 4        6.0      Yes  A person is eating at the desk and lying the p...
#
#                                     objects  \
# 0                         food;stove;window
# 1                       blanket;broom;floor
# 2                        clothes;door;phone
# 3                                 cup;phone
# 4  chair;desk;food;phone;plate;snacks;table
#
#                                         descriptions  \
# 0  A person cooks food on a stove before looking ...
# 1  Person at the bottom of the staircase shakes a...
# 2  A person runs in and shuts door. The person gr...
# 3  A person runs in place while holding a bottle ...
# 4  A person in a blue shirt is eating snacks off ...
#
#                                              actions  length  origin_index
# 0                   c092 11.90 21.20;c147 0.00 12.60   24.83             0
# 1  c098 8.60 14.20;c075 0.00 11.70;c127 0.00 15.2...   18.33             1
# 2  c018 22.60 27.80;c141 4.10 9.60;c148 10.30 25....   30.33             3
# 3                    c015 0.00 32.00;c107 0.00 32.00   31.38             4
# 4  c009 0.00 4.30;c011 0.00 39.00;c015 0.00 39.00...   38.46             5

# %%
dat_id = df['id']
dat_actions = df['actions']
dat_origin_index = df['origin_index']
dat = pd.concat([dat_id, dat_origin_index, dat_actions], axis=1)
split_arr = dat['actions'].str.split(';')

# %%
large_arr = []
for element in enumerate(split_arr):
    arr = []
    time = []
    for i in element[1]:
        k = i.split(" ")
        d = k[0]
        t = k[1]
        arr.append(d)
        time.append(t)
#     print(arr)
#     print(time)
    arr = [x for _,x in sorted(zip(time,arr))]
#     print(arr)
    large_arr.append(arr)
dat['split'] = large_arr

# %%
dat = dat.drop('actions', 1)

# %%
str_actions = dat['split']
int_actions = []
for action in str_actions:
    arr = []
    for act in action:
        a = int(act[1:])
        arr.append(a)
    int_actions.append(arr)

# %%
dat
# str_actions
# Out:
#          id  origin_index                                              split
# 0     46GP8             0                                       [c147, c092]
# 1     N11GT             1                           [c075, c127, c153, c098]
# 2     KRF68             3         [c150, c148, c018, c141, c006, c000, c002]
# 3     MJO7C             4                                       [c015, c107]
# 4     S6MPZ             5  [c009, c011, c015, c017, c019, c059, c061, c06...
# 5     7HVU8             6         [c001, c020, c127, c127, c004, c144, c127]
# 6     MCQO5             7               [c002, c000, c110, c107, c106, c148]
# 7     VPIYF             8                                             [c015]
# 8     JSUF4             9                     [c102, c127, c151, c123, c106]
# 9     8WJIR            10  [c107, c132, c151, c135, c110, c106, c107, c00...
# 10    INQNU            11   [c004, c075, c107, c152, c135, c151, c106, c118]
# 11    LI6LV            12  [c001, c002, c034, c148, c129, c155, c096, c12...
# 12    MGCM8            13                                 [c011, c014, c059]
# 13    I8QJN            14                     [c124, c107, c106, c154, c146]
# 14    XC9EY            15               [c107, c118, c109, c119, c009, c088]
# 15    DOQ9Y            16  [c155, c023, c063, c061, c063, c081, c097, c02...
# 16    RK9II            17                                       [c012, c154]
# 17    QGQGZ            18         [c008, c097, c104, c130, c118, c061, c063]
# 18    5S1WQ            19                     [c101, c100, c098, c102, c127]
# 19    CUCBN            20                           [c123, c097, c009, c154]
# 20    SX0HE            21                           [c015, c106, c107, c019]
# 21    72JYK            22         [c061, c151, c047, c125, c156, c048, c052]
# 22    BDFDE            23                     [c107, c129, c106, c151, c059]
# 23    H6N4Z            24               [c015, c016, c113, c114, c001, c081]
# 24    OBTP8            25               [c097, c040, c141, c008, c096, c155]
# 25    4021N            26         [c076, c039, c000, c042, c043, c040, c041]
# 26    ZSHWE            27   [c026, c033, c035, c034, c155, c002, c001, c000]
# 27    SFDTP            28                     [c154, c035, c033, c044, c000]
# 28    Q5EPP            29                                       [c128, c129]
# 29    SK6FW            30                           [c155, c098, c100, c003]
# ...     ...           ...                                                ...
# 7781  9KYMU          7954                           [c150, c041, c044, c040]
# 7782  UJT87          7955                                 [c015, c152, c076]
# 7783  6U082          7956                           [c098, c127, c002, c150]
# 7784  MR3ON          7957                                 [c124, c125, c136]
# 7785  OZSB3          7958         [c011, c059, c132, c076, c079, c020, c021]
# 7786  OUH2U          7959                           [c040, c097, c020, c006]
# 7787  82R7V          7960  [c056, c152, c063, c107, c118, c123, c110, c02...
# 7788  MOQIU          7961  [c011, c051, c123, c131, c132, c018, c154, c01...
# 7789  JJZ1X          7962                           [c011, c061, c156, c107]
# 7790  XAW3U          7963                           [c061, c156, c090, c092]
# 7791  38QA4          7964         [c155, c000, c120, c118, c107, c097, c002]
# 7792  WJL39          7965                                 [c148, c008, c096]
# 7793  FPWD0          7966         [c097, c143, c011, c142, c130, c142, c059]
# 7794  L1O0N          7967         [c155, c079, c076, c077, c110, c107, c106]
# 7795  OTLX9          7968  [c011, c014, c148, c110, c106, c109, c032, c14...
# 7796  B4F0T          7969   [c107, c128, c128, c151, c125, c129, c154, c106]
# 7797  0L0KS          7970                     [c015, c059, c154, c019, c018]
# 7798  F7AIA          7971   [c061, c125, c149, c152, c059, c065, c156, c029]
# 7799  B6LRC          7972                           [c082, c056, c053, c153]
# 7800  LD011          7974                                 [c148, c030, c110]
# 7801  WPFKR          7975                           [c057, c152, c008, c113]
# 7802  WO0OM          7976               [c015, c016, c067, c017, c156, c149]
# 7803  1AA6Z          7977  [c155, c118, c061, c156, c002, c000, c001, c06...
# 7804  LV24Z          7978                                 [c153, c047, c050]
# 7805  8U3SS          7979                           [c020, c137, c152, c149]
# 7806  7K2CS          7980         [c097, c153, c065, c067, c156, c141, c155]
# 7807  S2A89          7981                           [c097, c151, c006, c141]
# 7808  01O27          7982                           [c008, c096, c124, c006]
# 7809  2MJ72          7983                           [c092, c006, c037, c033]
# 7810  PG1ID          7984               [c047, c051, c052, c098, c100, c151]
#
# [7811 rows x 3 columns]

# %%
join_str = []
for it in str_actions:
    for s in it:
        join_str.append(s)
        
# join_str

# %%
import nltk
from nltk.corpus import brown
from nltk import WordNetLemmatizer
from math import log 

# brown = nltk.download('brown')
# wd = nltk.download('wordnet')

wnl=WordNetLemmatizer()
# lemmatize 詞型還原

_Fdist = nltk.FreqDist([wnl.lemmatize(w.lower()) for w in join_str])

_Sents = [[wnl.lemmatize(j.lower()) for j in i] for i in str_actions]

MAX_DISTANCE = 1 # 只有這兩個動作距離 = 1，這筆 video 才算數。

def inSents(x, y):
    c = 0
    l = []
    for s in _Sents:
        
#         first method:
        index1 = 0
        index2 = 0
        bool1 = False
        bool2 = False
        k = 0
        for index, st in enumerate(s):    
            if x == st and not bool1:
                k += 1
                index1 = index
                bool1 = True
            if y == st and not bool2:
                k += 1
                index2 = index  
                bool2 = True
        if k == 2: # x in s and y in s
            if abs(index1 - index2) == MAX_DISTANCE: # i.e 必定為 1 
                l.append(s)
                
#         second method:
#         if x in s and y in s:
#             l.append(s)
        
    return l

# int_actions
def p(x):
    return _Fdist[x]/ float(sum(_Fdist.values())) #float(len(_Fdist))
    

def pxy(x,y):
    return (len(inSents(x,y)) + 1) / float(len(_Sents) )

def pmi(x,y):
    return  log(pxy(x,y)/(p(x)*p(y)),2)

# %%
# _Fdist
# _Sents

# %%
# c000 Holding some clothes
# c001 Putting clothes somewhere
print(p('c000'))
print(p('c001'))
print(pxy('c000', 'c001')) # 0.0405
print(pmi('c000', 'c001'))
# Out:
# 0.012748700034130377
# 0.01284908349896605
# 0.014722826782742287
# 6.4898952817269615

# %%
# c059 Sitting in a chair
# c011 Sitting at a table
print(p('c059'))
print(p('c011'))
print(pxy('c059', 'c011')) #0.0684
print(pmi('c059', 'c011'))
# Out:
# 0.025296633138589413
# 0.014615832480073882
# 0.03290231724491102
# 6.47556799793738

# %%
# c057 Taking off some shoes
# c065 Eating a sandwich
print(p('c057'))
print(p('c065'))
print(pxy('c057', 'c065'))
print(pmi('c057', 'c065'))
# Out:
# 0.003935031821558353
# 0.009215202071914714
# 0.00012802458071949814
# 1.8198859198004613

# %%
classes_raw = open('Charades_v1_classes.txt', 'r')
classes = []
for i in classes_raw.readlines():
    arr = i.split(' ', 1)
    classes.append(arr)
# classes[0][0]
# len(classes) # 157x2, c000 to c156

# %%
two = []
two_pmi = []
for i in range(0, 157):
    for j in range(i+1, 157):
        arr = [classes[i], classes[j]]
        two.append(arr)
        two_pmi.append(pmi(classes[i][0], classes[j][0]))

# %%
two = [x for _,x in sorted(zip(two_pmi,two), reverse=True)]
two_pmi = sorted(two_pmi, reverse=True)

# %%
two = np.array(two)
print(two.shape)
two_pmi = np.array(two_pmi)
print(two_pmi.shape)
tmp = two.reshape(-1, 4)
print(tmp.shape)
mypmi = np.column_stack((tmp, two_pmi))
# Out:
# (12246, 2, 2)
# (12246,)
# (12246, 4)

# %%
result = pd.DataFrame(mypmi, columns={"1st class":0,"1st class name":1,"2nd class":2,"2nd class name":3,"pointwise mutual info":4})

# %%
_Fdist
# Out:
# FreqDist({'c000': 635,
#           'c001': 640,
#           'c002': 479,
#           'c003': 303,
# Out:
# [['c147', 'c092'],
#  ['c075', 'c127', 'c153', 'c098'],
#  ['c150', 'c148', 'c018', 'c141', 'c006', 'c000', 'c002'],
#  ['c015', 'c107'],
#  ['c009',
#   'c011',
#   'c015',
#   'c017',
#   'c019',
#   'c059',
#   'c061',
#   'c063',
#   'c156',
#   'c061'],
#  ['c001', 'c020', 'c127', 'c127', 'c004', 'c144', 'c127'],
#  ['c002', 'c000', 'c110', 'c107', 'c106', 'c148'],
#  ['c015'],
#  ['c102', 'c127', 'c151', 'c123', 'c106'],
#  ['c107',
#   'c132',
#   'c151',
#   'c135',
#   'c110',
#   'c106',
#   'c107',
#   'c009',
#   'c131',
#   'c152',
#   'c109',
#   'c154',
#   'c006'],
#  ['c004', 'c075', 'c107', 'c152', 'c135', 'c151', 'c106', 'c118'],
#  ['c001', 'c002', 'c034', 'c148', 'c129', 'c155', 'c096', 'c129', 'c106'],
#  ['c011', 'c014', 'c059'],
#  ['c124', 'c107', 'c106', 'c154', 'c146'],
#  ['c107', 'c118', 'c109', 'c119', 'c009', 'c088'],
#  ['c155',
#   'c023',
#   'c063',
#   'c061',
#   'c063',
#   'c081',
#   'c097',
#   'c020',
#   'c006',
#   'c141',
#   'c000',
#   'c001'],
#  ['c012', 'c154'],
#  ['c008', 'c097', 'c104', 'c130', 'c118', 'c061', 'c063'],
#  ['c101', 'c100', 'c098', 'c102', 'c127'],
#  ['c123', 'c097', 'c009', 'c154'],
#  ['c015', 'c106', 'c107', 'c019'],
#  ['c061', 'c151', 'c047', 'c125', 'c156', 'c048', 'c052'],
#  ['c107', 'c129', 'c106', 'c151', 'c059'],
#  ['c015', 'c016', 'c113', 'c114', 'c001', 'c081'],
#  ['c097', 'c040', 'c141', 'c008', 'c096', 'c155'],
#  ['c076', 'c039', 'c000', 'c042', 'c043', 'c040', 'c041'],
#  ['c026', 'c033', 'c035', 'c034', 'c155', 'c002', 'c001', 'c000'],
#  ['c154', 'c035', 'c033', 'c044', 'c000'],
#  ['c128', 'c129'],
#  ['c155', 'c098', 'c100', 'c003'],
#  ['c014', 'c051', 'c052', 'c061', 'c063', 'c156'],
#  ['c009', 'c118', 'c107', 'c106', 'c106'],
#  ['c059',
#   'c119',
#   'c132',
#   'c055',
#   'c063',
#   'c120',
#   'c118',
#   'c061',
#   'c156',
#   'c062'],
#  ['c092', 'c087', 'c097', 'c015'],
#  ['c120', 'c118', 'c119', 'c138', 'c137', 'c127', 'c121'],
#  ['c122',
#   'c122',
#   'c123',
#   'c065',
#   'c106',
#   'c156',
#   'c061',
#   'c063',
#   'c067',
#   'c069',
#   'c107'],
#  ['c073', 'c072', 'c057'],
#  ['c097', 'c155', 'c072', 'c073', 'c102', 'c100', 'c127', 'c001'],
#  ['c030',
#   'c032',
#   'c026',
#   'c009',
#   'c028',
#   'c154',
#   'c141',
#   'c008',
#   'c097',
#   'c006'],
#  ['c015', 'c016', 'c152', 'c062', 'c061', 'c156', 'c023', 'c020', 'c097'],
#  ['c026', 'c030', 'c032', 'c029', 'c025', 'c152', 'c149', 'c027'],
#  ['c015', 'c017', 'c020', 'c150', 'c065', 'c069', 'c021', 'c156', 'c067'],
#  ['c072', 'c132', 'c061', 'c156', 'c123', 'c151', 'c155', 'c073', 'c070'],
#  ['c017', 'c128', 'c087', 'c128', 'c107', 'c015', 'c129', 'c018'],
#  ['c011',
#   'c059',
#   'c063',
#   'c009',
#   'c017',
#   'c156',
#   'c018',
#   'c062',
#   'c015',
#   'c020'],
#  ['c011',
#   'c014',
#   'c026',
#   'c027',
#   'c032',
#   'c051',
#   'c059',
#   'c115',
#   'c145',
#   'c116',
#   'c126',
#   'c061',
#   'c063',
#   'c156',
#   'c067',
#   'c052',
#   'c115'],
#  ['c063', 'c139', 'c114', 'c113', 'c061'],
#  ['c010',
#   'c014',
#   'c061',
#   'c115',
#   'c118',
#   'c152',
#   'c149',
#   'c156',
#   'c145',
#   'c032',
#   'c065'],
#  ['c154',
#   'c109',
#   'c110',
#   'c064',
#   'c059',
#   'c011',
#   'c061',
#   'c023',
#   'c063',
#   'c024'],
#  ['c062', 'c130'],
#  ['c000', 'c094', 'c096', 'c152'],
#  ['c009', 'c062', 'c151', 'c123', 'c052', 'c011', 'c152', 'c014'],
#  ['c040', 'c041', 'c123', 'c132', 'c061', 'c156', 'c044', 'c070'],
#  ['c033', 'c097', 'c001', 'c082', 'c112', 'c006', 'c003', 'c034'],
#  ['c150',
#   'c009',
#   'c020',
#   'c027',
#   'c029',
#   'c117',
#   'c023',
#   'c030',
#   'c026',
#   'c022',
#   'c032'],
#  ['c067',
#   'c068',
#   'c118',
#   'c119',
#   'c011',
#   'c040',
#   'c041',
#   'c151',
#   'c009',
#   'c059'],
#  ['c118', 'c147'],
#  ['c043', 'c040', 'c150', 'c096'],
#  ['c024', 'c022', 'c127', 'c023', 'c020'],
#  ['c098', 'c149', 'c153'],
#  ['c034', 'c107', 'c088'],
#  ['c052', 'c123', 'c008', 'c020', 'c006'],
#  ['c084', 'c154', 'c044', 'c150', 'c083'],
#  ['c154',
#   'c004',
#   'c000',
#   'c002',
#   'c001',
#   'c003',
#   'c001',
#   'c002',
#   'c073',
#   'c071',
#   'c012',
#   'c009'],
#  ['c033', 'c037', 'c108', 'c105', 'c034'],
#  ['c098', 'c102', 'c127', 'c092'],
#  ['c007', 'c123', 'c151'],
#  ['c118',
#   'c119',
#   'c147',
#   'c061',
#   'c112',
#   'c009',
#   'c130',
#   'c113',
#   'c063',
#   'c062'],
#  ['c098', 'c127', 'c132', 'c102', 'c067', 'c156', 'c065', 'c152'],
#  ['c011',
#   'c052',
#   'c059',
#   'c154',
#   'c119',
#   'c120',
#   'c143',
#   'c126',
#   'c064',
#   'c153'],
#  ['c149', 'c152', 'c070', 'c075', 'c009', 'c071'],
#  ['c015', 'c016', 'c059', 'c106', 'c107'],
#  ['c151', 'c125', 'c022', 'c135', 'c021', 'c050', 'c048', 'c020', 'c023'],
#  ['c040', 'c047', 'c031'],
#  ['c072', 'c122', 'c146'],
#  ['c017', 'c081', 'c087', 'c107', 'c108', 'c015', 'c105', 'c106'],
#  ['c026', 'c032', 'c025', 'c097'],
#  ['c153', 'c082'],
#  ['c063',
#   'c061',
#   'c067',
#   'c118',
#   'c120',
#   'c065',
#   'c156',
#   'c073',
#   'c072',
#   'c097'],
#  ['c082', 'c110', 'c107', 'c108'],
#  ['c106', 'c107', 'c109', 'c038', 'c035', 'c121', 'c110', 'c111'],
#  ['c020', 'c023', 'c028', 'c021', 'c001', 'c054', 'c056', 'c053'],
#  ['c076', 'c123', 'c089', 'c154'],
#  ['c020',
#   'c021',
#   'c061',
#   'c062',
#   'c125',
#   'c154',
#   'c143',
#   'c064',
#   'c130',
#   'c081',
#   'c024'],
#  ['c076', 'c149', 'c152', 'c096', 'c155'],
#  ['c072', 'c122', 'c153', 'c063', 'c152', 'c156', 'c061'],
#  ['c000', 'c001', 'c004', 'c112', 'c006', 'c008', 'c100', 'c098', 'c102'],
#  ['c096', 'c097', 'c020', 'c130', 'c021', 'c144', 'c062', 'c008'],
#  ['c153', 'c126', 'c003', 'c155', 'c044', 'c096', 'c155'],
#  ['c113',
#   'c009',
#   'c129',
#   'c128',
#   'c128',
#   'c110',
#   'c112',
#   'c109',
#   'c151',
#   'c059',
#   'c107',
#   'c011',
#   'c108'],
#  ['c001',
#   'c155',
#   'c001',
#   'c151',
#   'c015',
#   'c124',
#   'c016',
#   'c018',
#   'c072',
#   'c016'],
#  ['c106', 'c092', 'c009', 'c109', 'c154'],
#  ['c115',
#   'c026',
#   'c030',
#   'c116',
#   'c081',
#   'c009',
#   'c028',
#   'c048',
#   'c052',
#   'c027',
#   'c025'],
#  ['c011', 'c014', 'c051', 'c052', 'c059', 'c151', 'c121', 'c111'],
#  ['c011',
#   'c015',
#   'c016',
#   'c059',
#   'c017',
#   'c009',
#   'c028',
#   'c117',
#   'c145',
#   'c027',
#   'c014',
#   'c032',
#   'c115'],
#  ['c136', 'c008'],
#  ['c008', 'c000', 'c113', 'c071', 'c081', 'c001', 'c112'],
#  ['c008',
#   'c097',
#   'c141',
#   'c006',
#   'c057',
#   'c056',
#   'c126',
#   'c154',
#   'c155',
#   'c002',
#   'c000',
#   'c001'],
#  ['c072',
#   'c132',
#   'c134',
#   'c001',
#   'c003',
#   'c074',
#   'c126',
#   'c132',
#   'c070',
#   'c000'],
#  ['c148', 'c057', 'c155', 'c056', 'c054'],
#  ['c092', 'c106', 'c006'],
#  ['c011',
#   'c014',
#   'c026',
#   'c032',
#   'c145',
#   'c149',
#   'c030',
#   'c035',
#   'c013',
#   'c038',
#   'c025',
#   'c116',
#   'c152',
#   'c012',
#   'c028',
#   'c125',
#   'c126'],
#  ['c097', 'c058', 'c126', 'c054', 'c104', 'c053', 'c149', 'c152'],
#  ['c098', 'c102', 'c127'],
#  ['c028', 'c122', 'c134', 'c025', 'c032'],
#  ['c025', 'c026', 'c027', 'c031', 'c097', 'c126', 'c105'],
#  ['c054', 'c082', 'c053', 'c056', 'c097', 'c141', 'c008'],
#  ['c061',
#   'c065',
#   'c069',
#   'c067',
#   'c112',
#   'c023',
#   'c063',
#   'c020',
#   'c068',
#   'c068',
#   'c021',
#   'c156',
#   'c024',
#   'c035',
#   'c033',
#   'c024',
#   'c034',
#   'c062',
#   'c113'],
#  ['c150', 'c097', 'c154', 'c054', 'c055', 'c059', 'c151'],
#  ['c113', 'c097', 'c006', 'c018', 'c015'],
#  ['c098', 'c097', 'c006', 'c015'],
#  ['c154', 'c048', 'c151', 'c059', 'c052'],
#  ['c001', 'c009', 'c151', 'c135', 'c035', 'c037', 'c033', 'c034'],
#  ['c011',
#   'c032',
#   'c061',
#   'c118',
#   'c156',
#   'c107',
#   'c108',
#   'c110',
#   'c106',
#   'c109',
#   'c109'],
#  ['c031', 'c135', 'c151', 'c026'],
#  ['c076', 'c078', 'c154'],
#  ['c075',
#   'c061',
#   'c156',
#   'c062',
#   'c039',
#   'c043',
#   'c154',
#   'c042',
#   'c040',
#   'c041',
#   'c044',
#   'c151',
#   'c063'],
#  ['c033', 'c001', 'c034', 'c081', 'c005', 'c005', 'c033', 'c081', 'c082'],
#  ['c098', 'c102', 'c127', 'c030', 'c026', 'c027', 'c032'],
#  ['c000', 'c097', 'c118', 'c003', 'c001', 'c034', 'c126', 'c126'],
#  ['c011', 'c015', 'c061', 'c087', 'c156', 'c153'],
#  ['c082',
#   'c082',
#   'c084',
#   'c042',
#   'c117',
#   'c032',
#   'c115',
#   'c116',
#   'c081',
#   'c042',
#   'c042',
#   'c081',
#   'c043'],
#  ['c084', 'c088', 'c123', 'c118', 'c106'],
#  ['c059', 'c148', 'c033', 'c154'],
#  ['c083', 'c088', 'c084'],
#  ['c000', 'c008', 'c150', 'c141'],
#  ['c132', 'c131'],
#  ['c010',
#   'c011',
#   'c020',
#   'c059',
#   'c061',
#   'c063',
#   'c156',
#   'c009',
#   'c062',
#   'c148',
#   'c001'],
#  ['c000', 'c002', 'c044', 'c001', 'c004', 'c003'],
#  ['c149', 'c040', 'c043', 'c045', 'c126'],
#  ['c020',
#   'c023',
#   'c061',
#   'c063',
#   'c022',
#   'c130',
#   'c081',
#   'c066',
#   'c067',
#   'c118',
#   'c106',
#   'c097'],
#  ['c065', 'c067', 'c156', 'c040', 'c041', 'c002', 'c044'],
#  ['c107', 'c145', 'c116', 'c143', 'c117', 'c115'],
#  ['c155', 'c000'],
#  ['c107', 'c109', 'c041', 'c128', 'c044', 'c106', 'c156', 'c129', 'c110'],
#  ['c008', 'c134'],
#  ['c061', 'c097', 'c150', 'c156', 'c006'],
#  ['c011', 'c059', 'c080', 'c076'],
#  ['c070', 'c076', 'c096', 'c153'],
#  ['c089', 'c112', 'c154', 'c015', 'c087', 'c016', 'c018'],
#  ['c097', 'c006', 'c004', 'c096', 'c148', 'c144'],
#  ['c051', 'c059', 'c061', 'c156', 'c008', 'c141', 'c097', 'c154'],
#  ['c124', 'c154'],
#  ['c124', 'c114', 'c038', 'c033', 'c091'],
#  ['c015', 'c016', 'c087', 'c002', 'c001'],
#  ['c125', 'c154', 'c015'],
#  ['c059', 'c107', 'c153', 'c109', 'c109', 'c154', 'c107', 'c128', 'c009'],
#  ['c140', 'c020', 'c022', 'c097'],
#  ['c001', 'c097', 'c000', 'c006', 'c134', 'c008', 'c113', 'c081', 'c112'],
#  ['c023', 'c021', 'c020', 'c097'],
#  ['c154', 'c127', 'c137', 'c124'],
#  ['c127', 'c099', 'c101', 'c132', 'c102', 'c098'],
#  ['c062', 'c063', 'c143', 'c082'],
#  ['c097', 'c119', 'c121', 'c100', 'c098', 'c104', 'c104', 'c119'],
#  ['c033', 'c053', 'c144'],
#  ['c002', 'c153', 'c008', 'c113', 'c141', 'c112', 'c128', 'c001', 'c148'],
#  ['c020', 'c097', 'c023'],
#  ['c082', 'c043', 'c045', 'c042'],
#  ['c070', 'c073', 'c075', 'c071', 'c034', 'c015', 'c016'],
#  ['c014', 'c048', 'c052', 'c046', 'c008'],
#  ['c052',
#   'c059',
#   'c124',
#   'c067',
#   'c068',
#   'c062',
#   'c069',
#   'c065',
#   'c156',
#   'c063',
#   'c061'],
#  ['c056', 'c057', 'c126', 'c155', 'c001'],
#  ['c008',
#   'c020',
#   'c097',
#   'c006',
#   'c059',
#   'c123',
#   'c151',
#   'c022',
#   'c024',
#   'c108'],
#  ['c097', 'c006', 'c096', 'c152', 'c094'],
#  ['c015', 'c016', 'c135', 'c153', 'c115', 'c116'],
#  ['c000', 'c004'],
#  ['c008', 'c130', 'c024', 'c152', 'c020', 'c006'],
#  ['c040', 'c042', 'c043', 'c154', 'c151', 'c125'],
#  ['c098', 'c102', 'c127'],
#  ['c059', 'c061', 'c156', 'c145'],
#  ['c040', 'c042', 'c081', 'c044', 'c130', 'c044', 'c062', 'c044', 'c062'],
#  ['c015',
#   'c059',
#   'c061',
#   'c065',
#   'c067',
#   'c156',
#   'c016',
#   'c154',
#   'c035',
#   'c002',
#   'c005',
#   'c033'],
#  ['c015', 'c019', 'c111'],
#  ['c151', 'c120', 'c118', 'c059', 'c154', 'c106'],
#  ['c147', 'c153', 'c128', 'c129'],
#  ['c078',
#   'c122',
#   'c146',
#   'c123',
#   'c154',
#   'c080',
#   'c126',
#   'c132',
#   'c131',
#   'c149'],
#  ['c000', 'c059', 'c148', 'c001', 'c148', 'c154', 'c020', 'c023'],
#  ['c147', 'c097', 'c009', 'c092'],
#  ['c097', 'c110', 'c109', 'c107', 'c106'],
#  ['c059', 'c096', 'c155', 'c000', 'c134', 'c078', 'c003', 'c001'],
#  ['c056', 'c150'],
#  ['c098', 'c099', 'c100', 'c102', 'c114', 'c153', 'c113'],
#  ['c098', 'c124', 'c153', 'c097'],
#  ['c107', 'c143', 'c109', 'c142', 'c006', 'c108'],
#  ['c097', 'c096', 'c015', 'c087'],
#  ['c061', 'c118', 'c156', 'c104', 'c105', 'c119', 'c009'],
#  ['c137', 'c001', 'c004', 'c138', 'c000'],
#  ['c097', 'c155', 'c095', 'c000', 'c096', 'c148'],
#  ['c134', 'c135', 'c133', 'c146', 'c003', 'c155', 'c155'],
#  ['c137', 'c020', 'c023', 'c022', 'c021', 'c063', 'c075', 'c070'],
#  ['c106', 'c107', 'c135', 'c119', 'c134'],
#  ['c132', 'c117', 'c115', 'c145', 'c151', 'c125', 'c154', 'c153'],
#  ['c040',
#   'c044',
#   'c061',
#   'c063',
#   'c156',
#   'c109',
#   'c149',
#   'c152',
#   'c042',
#   'c062',
#   'c110',
#   'c107',
#   'c106'],
#  ['c043', 'c063', 'c061', 'c023', 'c150'],
#  ['c043', 'c040', 'c008', 'c097', 'c039'],
#  ['c059', 'c029', 'c047', 'c152', 'c052', 'c026', 'c032'],
#  ['c127', 'c096', 'c144'],
#  ['c070', 'c072', 'c123', 'c057', 'c151', 'c122', 'c154', 'c071'],
#  ['c015', 'c016', 'c040'],
#  ['c011', 'c059', 'c070', 'c072', 'c078', 'c071', 'c153'],
#  ['c015', 'c075', 'c016', 'c107', 'c122', 'c134', 'c151'],
#  ['c137', 'c001', 'c127', 'c055'],
#  ['c020',
#   'c126',
#   'c022',
#   'c130',
#   'c024',
#   'c023',
#   'c061',
#   'c067',
#   'c065',
#   'c156'],
#  ['c000', 'c033', 'c115'],
#  ['c092',
#   'c022',
#   'c024',
#   'c023',
#   'c020',
#   'c021',
#   'c054',
#   'c056',
#   'c058',
#   'c053'],
#  ['c123', 'c132', 'c152', 'c073', 'c070', 'c151', 'c072', 'c154'],
#  ['c020', 'c061', 'c156'],
#  ['c097', 'c061', 'c065', 'c156', 'c064', 'c068', 'c067'],
#  ['c097',
#   'c107',
#   'c118',
#   'c154',
#   'c009',
#   'c119',
#   'c151',
#   'c125',
#   'c001',
#   'c002',
#   'c003'],
#  ['c072', 'c153', 'c070', 'c154', 'c146'],
#  ['c015', 'c016', 'c059', 'c152'],
#  ['c026', 'c032', 'c059', 'c115', 'c029', 'c149', 'c152', 'c153'],
#  ['c057',
#   'c125',
#   'c054',
#   'c018',
#   'c044',
#   'c041',
#   'c042',
#   'c016',
#   'c015',
#   'c087',
#   'c043',
#   'c040'],
#  ['c113', 'c126', 'c057', 'c002', 'c000', 'c058', 'c003', 'c112', 'c056'],
#  ['c125',
#   'c008',
#   'c113',
#   'c006',
#   'c154',
#   'c062',
#   'c114',
#   'c130',
#   'c130',
#   'c081'],
#  ['c020', 'c115', 'c151', 'c145', 'c059', 'c154', 'c021'],
#  ['c059',
#   'c151',
#   'c062',
#   'c014',
#   'c032',
#   'c027',
#   'c145',
#   'c011',
#   'c144',
#   'c016',
#   'c063',
#   'c154',
#   'c061',
#   'c156'],
#  ['c106', 'c107'],
#  ['c070', 'c072', 'c078', 'c076', 'c097'],
#  ['c009', 'c118', 'c119'],
#  ['c127', 'c137', 'c152', 'c023', 'c053', 'c127'],
#  ['c026',
#   'c030',
#   'c030',
#   'c135',
#   'c032',
#   'c027',
#   'c025',
#   'c028',
#   'c002',
#   'c154',
#   'c000',
#   'c155',
#   'c061',
#   'c156'],
#  ['c076', 'c125', 'c096', 'c078', 'c153'],
#  ['c015', 'c016', 'c047', 'c087', 'c149', 'c152'],
#  ['c028', 'c106', 'c118', 'c118', 'c030', 'c026', 'c027', 'c032'],
#  ['c020', 'c059', 'c147', 'c022', 'c154'],
#  ['c119', 'c069', 'c120', 'c118', 'c067'],
#  ['c128', 'c079', 'c076', 'c078', 'c009', 'c139'],
#  ['c133', 'c146', 'c096', 'c018', 'c015'],
#  ['c128',
#   'c129',
#   'c040',
#   'c129',
#   'c039',
#   'c009',
#   'c041',
#   'c128',
#   'c156',
#   'c012'],
#  ['c152', 'c149', 'c051'],
#  ['c059', 'c154', 'c127', 'c137', 'c151'],
#  ['c097', 'c006', 'c141', 'c139'],
#  ['c053', 'c097', 'c000', 'c002', 'c149', 'c152'],
#  ['c123', 'c135', 'c016', 'c152', 'c015', 'c154', 'c006', 'c112', 'c106'],
#  ['c020',
#   'c023',
#   'c066',
#   'c154',
#   'c063',
#   'c021',
#   'c068',
#   'c128',
#   'c129',
#   'c156',
#   'c067'],
#  ['c067', 'c020', 'c026', 'c150'],
#  ['c078', 'c026', 'c123', 'c011', 'c010', 'c151', 'c154', 'c009'],
#  ['c106', 'c107', 'c118'],
#  ['c097', 'c112', 'c063', 'c113', 'c061'],
#  ['c020', 'c061', 'c156', 'c137', 'c022', 'c009', 'c024', 'c137'],
#  ['c009',
#   'c151',
#   'c011',
#   'c059',
#   'c107',
#   'c108',
#   'c106',
#   'c119',
#   'c118',
#   'c110',
#   'c119'],
#  ['c091'],
#  ['c061', 'c064'],
#  ['c006', 'c097', 'c141', 'c008'],
#  ['c011',
#   'c014',
#   'c052',
#   'c061',
#   'c065',
#   'c067',
#   'c156',
#   'c015',
#   'c016',
#   'c019'],
#  ['c059', 'c061', 'c065', 'c156', 'c110'],
#  ['c134',
#   'c015',
#   'c146',
#   'c018',
#   'c016',
#   'c154',
#   'c017',
#   'c151',
#   'c027',
#   'c059',
#   'c011',
#   'c014',
#   'c032',
#   'c145'],
#  ['c106', 'c110', 'c147', 'c106', 'c109', 'c147'],
#  ['c059', 'c061', 'c118', 'c156', 'c149', 'c152', 'c062'],
#  ['c147', 'c118', 'c142', 'c143', 'c143', 'c156'],
#  ['c098', 'c100'],
#  ['c134', 'c132', 'c127', 'c137', 'c154'],
#  ['c082', 'c035', 'c002', 'c033', 'c003', 'c036', 'c152'],
#  ['c011',
#   'c059',
#   'c123',
#   'c107',
#   'c106',
#   'c108',
#   'c109',
#   'c120',
#   'c118',
#   'c119',
#   'c009',
#   'c012',
#   'c110',
#   'c154',
#   'c107'],
#  ['c008', 'c028', 'c116', 'c009', 'c127', 'c026', 'c115', 'c117', 'c030'],
#  ['c098', 'c123', 'c099', 'c141', 'c112', 'c097'],
#  ['c078', 'c123', 'c079', 'c076', 'c132'],
#  ['c015', 'c016', 'c107', 'c153', 'c017', 'c106'],
#  ['c102', 'c062', 'c063', 'c118', 'c097', 'c127', 'c099'],
#  ['c040', 'c050', 'c151', 'c125', 'c041'],
#  ['c147', 'c030', 'c026', 'c015'],
#  ['c096', 'c152', 'c084', 'c088'],
#  ['c026', 'c033', 'c097', 'c009', 'c034', 'c036', 'c003'],
#  ['c107', 'c153', 'c107', 'c129', 'c106', 'c109'],
#  ['c076'],
#  ['c000', 'c024', 'c070', 'c149'],
#  ['c155', 'c001', 'c000', 'c003', 'c072', 'c134'],
#  ['c152', 'c009', 'c108', 'c106', 'c110', 'c107'],
#  ['c008', 'c006', 'c118', 'c120'],
#  ['c110', 'c108', 'c107', 'c009'],
#  ['c125', 'c039', 'c042', 'c154'],
#  ['c059',
#   'c154',
#   'c113',
#   'c008',
#   'c141',
#   'c002',
#   'c001',
#   'c000',
#   'c003',
#   'c155'],
#  ['c023',
#   'c011',
#   'c110',
#   'c059',
#   'c107',
#   'c107',
#   'c108',
#   'c009',
#   'c109',
#   'c110',
#   'c106',
#   'c020',
#   'c022',
#   'c009',
#   'c151'],
#  ['c144', 'c030', 'c026', 'c114', 'c081', 'c028', 'c028', 'c127'],
#  ['c011', 'c014', 'c052', 'c059', 'c154'],
#  ['c072',
#   'c116',
#   'c023',
#   'c030',
#   'c026',
#   'c028',
#   'c027',
#   'c115',
#   'c117',
#   'c025'],
#  ['c143', 'c023', 'c020', 'c142'],
#  ['c011', 'c059', 'c062', 'c063', 'c156', 'c154', 'c097', 'c008', 'c006'],
#  ['c151', 'c120', 'c118', 'c106', 'c119', 'c139', 'c057', 'c058', 'c154'],
#  ['c015', 'c016', 'c135', 'c008', 'c154', 'c087'],
#  ['c002', 'c003', 'c126', 'c061', 'c156', 'c096', 'c113'],
#  ['c061', 'c063', 'c051', 'c108', 'c062'],
#  ['c097',
#   'c043',
#   'c042',
#   'c127',
#   'c081',
#   'c114',
#   'c040',
#   'c008',
#   'c141',
#   'c006',
#   'c112',
#   'c097',
#   'c042',
#   'c127',
#   'c141',
#   'c008',
#   'c113'],
#  ['c005', 'c015', 'c016', 'c054', 'c077'],
#  ['c006', 'c097', 'c141', 'c079', 'c076'],
#  ['c127', 'c137', 'c076', 'c079'],
#  ['c098', 'c110', 'c118', 'c147', 'c109', 'c119', 'c120', 'c009'],
#  ['c020', 'c154', 'c097', 'c127', 'c102'],
#  ['c059', 'c154', 'c113', 'c119', 'c081', 'c006', 'c119'],
#  ['c015', 'c016', 'c156', 'c056', 'c023', 'c020', 'c053', 'c044', 'c063'],
#  ['c147', 'c141', 'c008', 'c113', 'c120', 'c119', 'c110', 'c106'],
#  ['c128', 'c147', 'c152', 'c128', 'c149', 'c129'],
#  ['c147', 'c118', 'c111'],
#  ['c062', 'c147'],
#  ['c003', 'c153'],
#  ['c093', 'c154', 'c069', 'c067', 'c156', 'c065', 'c119', 'c068'],
#  ['c096', 'c155', 'c000', 'c026', 'c030', 'c155', 'c001', 'c038'],
#  ['c026', 'c032', 'c147', 'c113', 'c028', 'c081', 'c112', 'c025'],
#  ['c015', 'c033', 'c070', 'c019', 'c036', 'c097'],
#  ['c026', 'c032', 'c035', 'c001', 'c003', 'c073', 'c002'],
#  ['c097', 'c074', 'c070', 'c079', 'c071'],
#  ['c152', 'c147'],
#  ['c047', 'c051', 'c052', 'c059', 'c107', 'c106', 'c149', 'c152'],
#  ['c102', 'c127', 'c096', 'c144'],
#  ['c025', 'c106', 'c113', 'c112', 'c027'],
#  ['c001', 'c097', 'c155', 'c106', 'c152', 'c003', 'c134', 'c107'],
#  ['c150', 'c154', 'c008', 'c151', 'c059', 'c055', 'c097', 'c006'],
#  ['c008', 'c113', 'c006', 'c118', 'c112'],
#  ['c074', 'c009', 'c071', 'c081', 'c079', 'c070', 'c078', 'c076', 'c072'],
#  ['c011', 'c051', 'c052', 'c156'],
#  ['c030',
#   'c070',
#   'c072',
#   'c123',
#   'c029',
#   'c151',
#   'c025',
#   'c028',
#   'c107',
#   'c110',
#   'c109',
#   'c106',
#   'c026',
#   'c027',
#   'c032'],
#  ['c008',
#   'c113',
#   'c063',
#   'c023',
#   'c000',
#   'c003',
#   'c061',
#   'c112',
#   'c082',
#   'c114',
#   'c004'],
#  ['c051', 'c052', 'c156', 'c012', 'c137'],
#  ['c092', 'c090', 'c097'],
#  ['c011', 'c059', 'c118', 'c062', 'c045'],
#  ['c093', 'c106', 'c125'],
#  ['c118', 'c120', 'c147', 'c062'],
#  ['c061', 'c063', 'c006', 'c142', 'c097', 'c008', 'c062', 'c143'],
#  ['c020', 'c104', 'c061', 'c156'],
#  ['c092', 'c072', 'c070', 'c076', 'c078', 'c073'],
#  ['c008', 'c097', 'c006', 'c082', 'c038', 'c111', 'c121'],
#  ['c115', 'c145', 'c014', 'c051', 'c052'],
#  ['c096', 'c153'],
#  ['c107', 'c119', 'c109', 'c108', 'c111', 'c008', 'c121'],
#  ['c072',
#   'c122',
#   'c146',
#   'c070',
#   'c154',
#   'c073',
#   'c071',
#   'c075',
#   'c082',
#   'c123'],
#  ['c008', 'c061', 'c067', 'c107', 'c106', 'c006', 'c065'],
#  ['c002', 'c148', 'c020', 'c023', 'c132'],
#  ['c153', 'c137'],
#  ['c096', 'c154', 'c105'],
#  ['c014', 'c015', 'c019', 'c052', 'c152'],
#  ['c153', 'c153', 'c002', 'c127', 'c001', 'c009'],
#  ['c128', 'c152', 'c149', 'c143', 'c142', 'c129'],
#  ['c143',
#   'c142',
#   'c107',
#   'c110',
#   'c151',
#   'c059',
#   'c011',
#   'c106',
#   'c108',
#   'c062'],
#  ['c033', 'c073', 'c154', 'c151', 'c059', 'c072', 'c155'],
#  ['c134', 'c154', 'c053', 'c056', 'c054', 'c003', 'c001'],
#  ['c081', 'c082', 'c105', 'c150'],
#  ['c155',
#   'c002',
#   'c023',
#   'c020',
#   'c061',
#   'c151',
#   'c135',
#   'c021',
#   'c063',
#   'c132',
#   'c003',
#   'c156'],
#  ['c142', 'c147', 'c118'],
#  ['c051', 'c052', 'c125', 'c124'],
#  ['c000', 'c155', 'c106', 'c001', 'c022', 'c076', 'c096'],
#  ['c151', 'c135', 'c018', 'c016', 'c015', 'c076', 'c079', 'c077'],
#  ['c015', 'c017', 'c097', 'c151', 'c059', 'c055', 'c148', 'c152', 'c009'],
#  ['c008', 'c097', 'c107', 'c141', 'c006', 'c096'],
#  ['c011', 'c021', 'c059', 'c156', 'c032', 'c153', 'c154', 'c092'],
#  ['c098', 'c153', 'c125', 'c056', 'c057'],
#  ['c041',
#   'c151',
#   'c125',
#   'c042',
#   'c073',
#   'c000',
#   'c071',
#   'c154',
#   'c004',
#   'c002',
#   'c001'],
#  ['c006', 'c149', 'c152', 'c155', 'c001', 'c003'],
#  ['c047', 'c127', 'c137', 'c150'],
#  ['c061',
#   'c063',
#   'c065',
#   'c067',
#   'c152',
#   'c156',
#   'c027',
#   'c032',
#   'c025',
#   'c068',
#   'c062',
#   'c026',
#   'c030'],
#  ['c037', 'c033', 'c112', 'c113', 'c081', 'c034'],
#  ['c097', 'c002', 'c030', 'c070', 'c073', 'c028', 'c115', 'c117', 'c000'],
#  ['c015', 'c087', 'c149'],
#  ['c143', 'c156', 'c151', 'c059', 'c063', 'c142', 'c061', 'c118'],
#  ['c007', 'c113', 'c054', 'c127', 'c053', 'c056', 'c112'],
#  ['c004'],
#  ['c061', 'c135', 'c156', 'c040', 'c043', 'c039'],
#  ['c115', 'c123', 'c145', 'c152'],
#  ['c082', 'c114', 'c153', 'c110', 'c106'],
#  ['c127', 'c154', 'c102'],
#  ['c021', 'c153', 'c023', 'c020'],
#  ['c094',
#   'c096',
#   'c135',
#   'c153',
#   'c067',
#   'c065',
#   'c156',
#   'c000',
#   'c155',
#   'c003'],
#  ['c132', 'c134', 'c072', 'c074'],
#  ['c092', 'c100', 'c098', 'c099', 'c105', 'c097'],
#  ['c097', 'c001', 'c002', 'c004', 'c000'],
#  ['c065', 'c067', 'c092', 'c156'],
#  ['c107', 'c107', 'c110', 'c106', 'c106', 'c081', 'c109'],
#  ['c097', 'c044', 'c128', 'c149', 'c152', 'c113', 'c040', 'c041', 'c043'],
#  ['c097', 'c052', 'c047', 'c098', 'c099'],
#  ['c076',
#   'c135',
#   'c110',
#   'c118',
#   'c118',
#   'c107',
#   'c106',
#   'c154',
#   'c109',
#   'c152',
#   'c077',
#   'c146',
#   'c078',
#   'c133'],
#  ['c072', 'c076', 'c104', 'c105', 'c141', 'c006'],
#  ['c011', 'c015', 'c016', 'c153', 'c009', 'c011', 'c015', 'c016', 'c017'],
#  ['c137', 'c152'],
#  ['c050', 'c047', 'c097'],
#  ['c070', 'c015', 'c087', 'c074', 'c126', 'c071'],
#  ['c063',
#   'c112',
#   'c113',
#   'c043',
#   'c061',
#   'c041',
#   'c109',
#   'c062',
#   'c081',
#   'c039',
#   'c042',
#   'c110',
#   'c044',
#   'c108',
#   'c107'],
#  ['c059', 'c061', 'c156', 'c118', 'c082', 'c062', 'c119', 'c009', 'c154'],
#  ['c055', 'c059', 'c154', 'c150', 'c117', 'c115'],
#  ['c009',
#   'c011',
#   'c014',
#   'c063',
#   'c065',
#   'c069',
#   'c145',
#   'c061',
#   'c067',
#   'c062'],
#  ['c076', 'c124', 'c125', 'c155', 'c078', 'c057'],
#  ['c011',
#   'c012',
#   'c013',
#   'c014',
#   'c038',
#   'c038',
#   'c059',
#   'c106',
#   'c107',
#   'c118',
#   'c152'],
#  ['c020', 'c021', 'c024', 'c126'],
#  ['c015',
#   'c016',
#   'c135',
#   'c109',
#   'c110',
#   'c107',
#   'c106',
#   'c017',
#   'c151',
#   'c154',
#   'c126',
#   'c070',
#   'c071',
#   'c073',
#   'c074'],
#  ['c035', 'c038', 'c033', 'c034'],
#  ['c059', 'c145', 'c146', 'c011', 'c032', 'c027', 'c014'],
#  ['c020',
#   'c062',
#   'c063',
#   'c008',
#   'c113',
#   'c006',
#   'c112',
#   'c021',
#   'c130',
#   'c061',
#   'c081'],
#  ['c003',
#   'c004',
#   'c059',
#   'c151',
#   'c055',
#   'c059',
#   'c055',
#   'c002',
#   'c000',
#   'c148'],
#  ['c053', 'c110', 'c109', 'c054', 'c119', 'c120'],
#  ['c141', 'c008', 'c011', 'c048', 'c059', 'c052', 'c014', 'c051', 'c097'],
#  ['c151', 'c123', 'c100', 'c098', 'c125', 'c127', 'c102'],
#  ['c108',
#   'c106',
#   'c030',
#   'c026',
#   'c032',
#   'c027',
#   'c025',
#   'c028',
#   'c154',
#   'c151',
#   'c059',
#   'c115',
#   'c107',
#   'c110'],
#  ['c151',
#   'c059',
#   'c123',
#   'c154',
#   'c063',
#   'c011',
#   'c061',
#   'c062',
#   'c065',
#   'c156'],
#  ['c153', 'c069', 'c067', 'c065', 'c061', 'c156', 'c096'],
#  ['c016', 'c134', 'c015', 'c009', 'c154', 'c089', 'c004'],
#  ['c126', 'c003', 'c001', 'c002'],
#  ['c130', 'c081', 'c112', 'c006', 'c099', 'c081'],
#  ['c061', 'c156', 'c081', 'c073', 'c000', 'c002', 'c070', 'c137', 'c127'],
#  ['c004', 'c114', 'c137', 'c097', 'c098', 'c105'],
#  ['c072', 'c123', 'c143', 'c062', 'c130', 'c020', 'c097'],
#  ['c151',
#   'c123',
#   'c154',
#   'c061',
#   'c141',
#   'c008',
#   'c132',
#   'c000',
#   'c067',
#   'c070',
#   'c071',
#   'c074',
#   'c126',
#   'c006'],
#  ['c070', 'c072', 'c154', 'c073', 'c097', 'c008', 'c113'],
#  ['c011', 'c059', 'c146', 'c154', 'c096', 'c144'],
#  ['c063', 'c061', 'c120', 'c003', 'c000', 'c001'],
#  ['c026',
#   'c032',
#   'c059',
#   'c072',
#   'c115',
#   'c145',
#   'c025',
#   'c028',
#   'c154',
#   'c150'],
#  ['c019', 'c097', 'c015', 'c002'],
#  ['c047', 'c125', 'c049', 'c046', 'c081'],
#  ['c097', 'c150', 'c106', 'c109', 'c110'],
#  ['c070',
#   'c072',
#   'c134',
#   'c000',
#   'c154',
#   'c001',
#   'c004',
#   'c156',
#   'c065',
#   'c061',
#   'c063',
#   'c062',
#   'c155',
#   'c000',
#   'c074',
#   'c002'],
#  ['c026', 'c028', 'c081', 'c154', 'c117', 'c115', 'c151'],
#  ['c084',
#   'c087',
#   'c086',
#   'c083',
#   'c105',
#   'c104',
#   'c096',
#   'c018',
#   'c015',
#   'c123',
#   'c151',
#   'c088'],
#  ['c020', 'c004', 'c022', 'c024', 'c151', 'c059'],
#  ['c047', 'c051', 'c088', 'c065', 'c156', 'c063', 'c061', 'c153', 'c064'],
#  ['c063', 'c143', 'c147', 'c142', 'c062', 'c147'],
#  ['c053', 'c150', 'c097'],
#  ['c000', 'c033', 'c003', 'c070'],
#  ['c015', 'c153', 'c097', 'c016'],
#  ['c127', 'c137', 'c110', 'c107', 'c106', 'c009', 'c109'],
#  ['c026', 'c032', 'c059', 'c135', 'c029'],
#  ['c053', 'c056', 'c062', 'c041', 'c044'],
#  ['c150', 'c151', 'c125'],
#  ['c015', 'c019'],
#  ['c113', 'c128', 'c112'],
#  ['c006',
#   'c141',
#   'c110',
#   'c106',
#   'c153',
#   'c097',
#   'c018',
#   'c019',
#   'c015',
#   'c152',
#   'c107'],
#  ['c092', 'c155', 'c000', 'c001'],
#  ['c033'],
#  ['c065', 'c156', 'c065'],
#  ['c119', 'c115', 'c145', 'c116'],
#  ['c047',
#   'c097',
#   'c049',
#   'c009',
#   'c107',
#   'c063',
#   'c067',
#   'c069',
#   'c142',
#   'c143'],
#  ['c097', 'c015', 'c016', 'c063', 'c087'],
#  ['c111', 'c139', 'c109', 'c110', 'c106'],
#  ['c079', 'c076'],
#  ['c021', 'c153'],
#  ['c061', 'c118', 'c015', 'c087'],
#  ['c118', 'c154', 'c063', 'c119', 'c097', 'c106', 'c120', 'c123', 'c120'],
#  ['c092', 'c033', 'c004', 'c097', 'c153'],
#  ['c060',
#   'c062',
#   'c118',
#   'c120',
#   'c149',
#   'c152',
#   'c119',
#   'c081',
#   'c153',
#   'c082'],
#  ['c062', 'c051', 'c119', 'c066', 'c147', 'c063', 'c061', 'c120'],
#  ['c076', 'c150', 'c097'],
#  ['c053', 'c070', 'c001', 'c106', 'c075', 'c071', 'c054'],
#  ['c070',
#   'c113',
#   'c097',
#   'c075',
#   'c151',
#   'c059',
#   'c132',
#   'c081',
#   'c071',
#   'c112'],
#  ['c051', 'c052', 'c125', 'c047', 'c009', 'c154'],
#  ['c055', 'c135', 'c154', 'c097'],
#  ['c011',
#   'c059',
#   'c070',
#   'c075',
#   'c106',
#   'c009',
#   'c154',
#   'c034',
#   'c071',
#   'c110'],
#  ['c061', 'c156', 'c067', 'c064', 'c062'],
#  ['c088', 'c125', 'c132', 'c107', 'c120', 'c152', 'c110'],
#  ['c027', 'c154', 'c060', 'c030', 'c026'],
#  ['c106', 'c075'],
#  ['c000', 'c073', 'c002', 'c070', 'c001', 'c071', 'c008', 'c097'],
#  ['c154', 'c102', 'c127'],
#  ['c118', 'c147', 'c113', 'c120'],
#  ['c151', 'c075', 'c011', 'c070', 'c009', 'c059', 'c108', 'c097'],
#  ['c051', 'c059', 'c061', 'c062', 'c063', 'c147'],
#  ['c108', 'c129', 'c128', 'c107', 'c106', 'c129'],
#  ['c107', 'c081', 'c106'],
#  ['c015',
#   'c087',
#   'c125',
#   'c152',
#   'c027',
#   'c115',
#   'c030',
#   'c116',
#   'c154',
#   'c028',
#   'c017',
#   'c032',
#   'c025',
#   'c117',
#   'c026'],
#  ['c076', 'c078', 'c098', 'c125', 'c127', 'c102', 'c077', 'c079', 'c124'],
#  ['c134', 'c148', 'c000', 'c002', 'c096', 'c133', 'c146', 'c154'],
#  ['c098', 'c099', 'c128', 'c097'],
#  ['c102', 'c127', 'c151', 'c125'],
#  ['c097', 'c107', 'c141', 'c006', 'c110', 'c106', 'c119'],
#  ['c148', 'c097', 'c015', 'c016', 'c006', 'c112'],
#  ['c033', 'c154', 'c040', 'c034', 'c035', 'c009', 'c011', 'c151', 'c061'],
#  ['c040', 'c047', 'c051'],
#  ['c021', 'c020'],
#  ['c011', 'c059', 'c015', 'c016', 'c017'],
#  ['c074',
#   'c151',
#   'c135',
#   'c118',
#   'c061',
#   'c156',
#   'c065',
#   'c152',
#   'c149',
#   'c067'],
#  ['c063',
#   'c143',
#   'c011',
#   'c151',
#   'c061',
#   'c016',
#   'c059',
#   'c015',
#   'c142',
#   'c062'],
#  ['c030', 'c116', 'c031', 'c126', 'c116', 'c141', 'c008', 'c150', 'c097'],
#  ['c020',
#   'c021',
#   'c130',
#   'c063',
#   'c062',
#   'c022',
#   'c147',
#   'c063',
#   'c062',
#   'c063',
#   'c062'],
#  ['c052',
#   'c124',
#   'c151',
#   'c123',
#   'c009',
#   'c014',
#   'c011',
#   'c011',
#   'c156',
#   'c021',
#   'c063',
#   'c009',
#   'c062',
#   'c014',
#   'c154',
#   'c047',
#   'c050',
#   'c049'],
#  ['c000', 'c002', 'c092', 'c153'],
#  ['c127', 'c154', 'c028', 'c003'],
#  ['c020',
#   'c022',
#   'c023',
#   'c062',
#   'c063',
#   'c062',
#   'c021',
#   'c063',
#   'c009',
#   'c130'],
#  ['c045', 'c072', 'c070'],
#  ['c011', 'c015', 'c016', 'c059', 'c152', 'c143', 'c142'],
#  ['c098', 'c102', 'c127', 'c105', 'c097'],
#  ['c026', 'c115', 'c100', 'c098', 'c097', 'c153'],
#  ['c097', 'c113', 'c128', 'c148'],
#  ['c026', 'c032', 'c124', 'c025', 'c154', 'c008'],
#  ['c015', 'c016', 'c123', 'c124'],
#  ['c150',
#   'c081',
#   'c001',
#   'c001',
#   'c081',
#   'c023',
#   'c000',
#   'c021',
#   'c020',
#   'c152'],
#  ['c133', 'c134', 'c146', 'c104', 'c040', 'c041'],
#  ['c150', 'c008', 'c097', 'c020', 'c021', 'c006', 'c152'],
#  ['c008',
#   'c143',
#   'c107',
#   'c110',
#   'c109',
#   'c106',
#   'c142',
#   'c006',
#   'c153',
#   'c128',
#   'c128'],
#  ['c040', 'c061', 'c141', 'c008', 'c062', 'c156'],
#  ['c102', 'c127', 'c038'],
#  ['c020',
#   'c143',
#   'c008',
#   'c021',
#   'c130',
#   'c062',
#   'c024',
#   'c126',
#   'c006',
#   'c142',
#   'c081',
#   'c063',
#   'c061',
#   'c022'],
#  ['c145', 'c115'],
#  ['c011',
#   'c059',
#   'c061',
#   'c063',
#   'c064',
#   'c065',
#   'c067',
#   'c069',
#   'c156',
#   'c062',
#   'c068',
#   'c153'],
#  ['c061', 'c134', 'c155', 'c003', 'c065'],
#  ['c015', 'c153', 'c035', 'c033', 'c038', 'c034', 'c017', 'c006', 'c141'],
#  ['c125', 'c145', 'c059', 'c026', 'c115'],
#  ['c059', 'c065', 'c156', 'c106', 'c026', 'c032', 'c031', 'c028'],
#  ['c081', 'c113', 'c033', 'c020', 'c112'],
#  ['c002',
#   'c148',
#   'c001',
#   'c073',
#   'c070',
#   'c110',
#   'c107',
#   'c097',
#   'c008',
#   'c006'],
#  ['c061', 'c067', 'c097', 'c152', 'c048', 'c156', 'c065'],
#  ['c151', 'c001', 'c023', 'c154', 'c002', 'c000', 'c004'],
#  ['c113', 'c081', 'c151', 'c059', 'c130', 'c112', 'c020'],
#  ['c012', 'c051', 'c059', 'c116', 'c117'],
#  ['c044', 'c112', 'c113', 'c154', 'c153'],
#  ['c026', 'c076', 'c115', 'c027', 'c029', 'c152'],
#  ['c065', 'c156', 'c106', 'c106'],
#  ['c096', 'c082', 'c034', 'c035', 'c001', 'c081'],
#  ['c155', 'c000', 'c001', 'c151', 'c123', 'c059', 'c153', 'c053'],
#  ['c059', 'c076', 'c080'],
#  ['c070',
#   'c150',
#   'c090',
#   'c092',
#   'c033',
#   'c036',
#   'c071',
#   'c034',
#   'c074',
#   'c098',
#   'c101',
#   'c099'],
#  ['c098', 'c102', 'c034'],
#  ['c106', 'c109', 'c107', 'c154', 'c096'],
#  ['c008', 'c097', 'c009', 'c074', 'c003'],
#  ['c001', 'c081', 'c016', 'c018', 'c015', 'c155', 'c000'],
#  ['c118', 'c008', 'c143', 'c147'],
#  ['c011', 'c059', 'c132', 'c108'],
#  ['c033', 'c097', 'c098', 'c034', 'c102', 'c127'],
#  ['c093', 'c096', 'c073', 'c075', 'c070', 'c033', 'c154'],
#  ['c097', 'c098', 'c008', 'c102', 'c127', 'c141'],
#  ['c059', 'c135', 'c001', 'c002', 'c035', 'c004'],
#  ['c008',
#   'c097',
#   'c006',
#   'c104',
#   'c056',
#   'c057',
#   'c155',
#   'c054',
#   'c058',
#   'c126'],
#  ['c151', 'c123', 'c132', 'c142', 'c006'],
#  ['c108', 'c107'],
#  ['c152', 'c009', 'c039'],
#  ['c143', 'c142', 'c117', 'c115', 'c116', 'c153'],
#  ['c043', 'c081', 'c012', 'c153'],
#  ['c150', 'c137', 'c127', 'c119'],
#  ['c094', 'c096', 'c149', 'c152'],
#  ['c141', 'c097', 'c008', 'c015', 'c006'],
#  ['c151', 'c059', 'c055'],
#  ['c001', 'c002', 'c004', 'c081', 'c152'],
#  ['c072',
#   'c133',
#   'c134',
#   'c146',
#   'c151',
#   'c075',
#   'c135',
#   'c048',
#   'c154',
#   'c002',
#   'c148'],
#  ['c106', 'c110'],
#  ['c072', 'c153'],
#  ['c015', 'c016', 'c061', 'c067', 'c118', 'c062', 'c068', 'c119'],
#  ['c098', 'c127', 'c051', 'c102'],
#  ['c098', 'c100', 'c033', 'c035', 'c102', 'c038', 'c127'],
#  ['c020', 'c022', 'c008', 'c006', 'c021', 'c130'],
#  ['c008', 'c104', 'c114', 'c154'],
#  ['c113', 'c032'],
#  ['c097', 'c141', 'c151', 'c011', 'c048', 'c001', 'c144'],
#  ['c106', 'c109', 'c023', 'c000'],
#  ['c096', 'c144', 'c044', 'c079'],
#  ['c011', 'c113', 'c081', 'c112', 'c046', 'c047'],
#  ['c015', 'c016', 'c076', 'c080'],
#  ['c123', 'c152', 'c063', 'c061', 'c156', 'c057', 'c054', 'c053'],
#  ['c021', 'c023', 'c009'],
#  ['c052', 'c019', 'c020', 'c130', 'c113', 'c022', 'c018', 'c015'],
#  ['c072',
#   'c078',
#   'c122',
#   'c073',
#   'c057',
#   'c058',
#   'c126',
#   'c155',
#   'c154',
#   'c020',
#   'c023',
#   'c021',
#   'c151',
#   'c123',
#   'c146',
#   'c070',
#   'c074'],
#  ['c065', 'c106', 'c009', 'c132'],
#  ['c008',
#   'c070',
#   'c073',
#   'c072',
#   'c071',
#   'c132',
#   'c097',
#   'c006',
#   'c123',
#   'c151'],
#  ['c141', 'c008', 'c150', 'c097'],
#  ['c011', 'c048', 'c123', 'c061', 'c021', 'c156', 'c062', 'c051', 'c063'],
#  ['c052', 'c059', 'c065', 'c156', 'c061', 'c110', 'c106', 'c063'],
#  ['c107', 'c151', 'c059', 'c060', 'c082'],
#  ['c026', 'c061', 'c063', 'c156'],
#  ['c015', 'c016', 'c149', 'c152', 'c155', 'c017', 'c155'],
#  ['c010',
#   'c014',
#   'c051',
#   'c052',
#   'c070',
#   'c076',
#   'c078',
#   'c072',
#   'c110',
#   'c120',
#   'c107',
#   'c118',
#   'c106'],
#  ['c059', 'c143', 'c142', 'c121', 'c147', 'c120', 'c062', 'c063'],
#  ['c113',
#   'c047',
#   'c050',
#   'c123',
#   'c048',
#   'c151',
#   'c046',
#   'c049',
#   'c154',
#   'c153'],
#  ['c078', 'c124', 'c146', 'c154', 'c057'],
#  ['c054', 'c119', 'c120', 'c118', 'c062'],
#  ['c084',
#   'c088',
#   'c088',
#   'c115',
#   'c117',
#   'c151',
#   'c011',
#   'c038',
#   'c116',
#   'c036',
#   'c009',
#   'c033',
#   'c153'],
#  ['c115',
#   'c145',
#   'c116',
#   'c154',
#   'c062',
#   'c021',
#   'c023',
#   'c020',
#   'c063',
#   'c152',
#   'c029',
#   'c149'],
#  ['c003', 'c018', 'c036'],
#  ['c070', 'c128', 'c150', 'c141'],
#  ['c002', 'c001', 'c000', 'c055', 'c097'],
#  ['c020', 'c153', 'c149', 'c009', 'c130', 'c022', 'c152'],
#  ['c011',
#   'c026',
#   'c027',
#   'c032',
#   'c151',
#   'c025',
#   'c018',
#   'c015',
#   'c151',
#   'c154',
#   'c017',
#   'c001',
#   'c148',
#   'c002'],
#  ['c076', 'c079', 'c017', 'c081', 'c077'],
#  ['c008', 'c113'],
#  ['c055', 'c125', 'c148', 'c149', 'c152'],
#  ['c033',
#   'c070',
#   'c073',
#   'c156',
#   'c067',
#   'c065',
#   'c068',
#   'c009',
#   'c071',
#   'c061',
#   'c063',
#   'c069'],
#  ['c070', 'c072', 'c001', 'c003', 'c155'],
#  ['c008'],
#  ['c092', 'c067', 'c153'],
#  ['c151', 'c059', 'c015', 'c087'],
#  ['c054', 'c072', 'c075', 'c070'],
#  ['c002', 'c096', 'c155', 'c019', 'c015', 'c097', 'c113', 'c112'],
#  ['c020', 'c009'],
#  ['c076', 'c150', 'c080'],
#  ['c020', 'c026', 'c032', 'c115', 'c147', 'c149', 'c152'],
#  ['c096', 'c153', 'c097', 'c135', 'c132'],
#  ['c006',
#   'c104',
#   'c151',
#   'c059',
#   'c056',
#   'c057',
#   'c055',
#   'c054',
#   'c097',
#   'c153'],
#  ['c040', 'c009', 'c043', 'c041', 'c044', 'c039', 'c042'],
#  ['c000', 'c002', 'c004', 'c003', 'c148', 'c144', 'c001'],
#  ['c065', 'c061', 'c015', 'c016', 'c156'],
#  ['c113', 'c114', 'c152', 'c112', 'c038'],
#  ['c020', 'c006', 'c112', 'c024', 'c008', 'c113', 'c023'],
#  ['c137', 'c137', 'c008', 'c113', 'c114', 'c128', 'c097'],
#  ['c061', 'c156', 'c110', 'c106'],
#  ['c134', 'c154'],
#  ['c050', 'c151', 'c135', 'c047', 'c048', 'c052', 'c075'],
#  ['c008',
#   'c041',
#   'c044',
#   'c045',
#   'c126',
#   'c030',
#   'c026',
#   'c032',
#   'c027',
#   'c149',
#   'c040',
#   'c097',
#   'c025',
#   'c006'],
#  ['c008', 'c002', 'c076', 'c078', 'c152', 'c081', 'c077', 'c006'],
#  ['c135', 'c155', 'c001', 'c003', 'c076', 'c154', 'c113', 'c077', 'c112'],
#  ['c033', 'c038', 'c149', 'c152', 'c113', 'c112'],
#  ['c008',
#   'c001',
#   'c003',
#   'c057',
#   'c058',
#   'c126',
#   'c113',
#   'c105',
#   'c104',
#   'c000',
#   'c155'],
#  ['c042', 'c082', 'c110', 'c043', 'c112', 'c106'],
#  ['c113', 'c035', 'c033', 'c070', 'c097'],
#  ['c015', 'c016', 'c084', 'c088', 'c135', 'c152', 'c149'],
#  ['c033', 'c059', 'c036', 'c154', 'c105'],
#  ['c061',
#   'c063',
#   'c120',
#   'c118',
#   'c119',
#   'c009',
#   'c062',
#   'c061',
#   'c154',
#   'c151',
#   'c059',
#   'c123',
#   'c011'],
#  ['c070', 'c120', 'c118', 'c097'],
#  ['c011', 'c014', 'c052', 'c059', 'c012', 'c037', 'c154'],
#  ['c061', 'c065', 'c067', 'c097', 'c096', 'c156'],
#  ['c106'],
#  ['c125', 'c124', 'c151', 'c154'],
#  ['c059', 'c106', 'c107', 'c109', 'c015', 'c018', 'c016'],
#  ['c011', 'c020', 'c059', 'c061', 'c062', 'c063', 'c156'],
#  ['c015', 'c087', 'c144'],
#  ['c098', 'c020', 'c130', 'c099'],
#  ['c008', 'c061', 'c112', 'c113', 'c107'],
#  ['c001', 'c005', 'c015', 'c019'],
#  ['c096'],
#  ['c062', 'c107', 'c109', 'c118', 'c119', 'c106', 'c106'],
#  ['c051', 'c014', 'c152', 'c009', 'c048', 'c059', 'c011', 'c151'],
#  ['c059', 'c132', 'c152', 'c131', 'c141', 'c149', 'c154', 'c008'],
#  ['c148', 'c152', 'c033', 'c131', 'c132'],
#  ['c076', 'c009', 'c080', 'c077'],
#  ['c081', 'c113', 'c112', 'c123', 'c151', 'c108', 'c109'],
#  ['c011', 'c059', 'c009', 'c020', 'c041', 'c039'],
#  ['c006', 'c008', 'c097', 'c082', 'c063', 'c156'],
#  ['c108', 'c009', 'c107', 'c151', 'c106', 'c059', 'c011', 'c107', 'c118'],
#  ['c061', 'c072', 'c156'],
#  ['c098', 'c102', 'c127', 'c008', 'c097', 'c152'],
#  ['c082', 'c020', 'c020', 'c081', 'c021', 'c113', 'c008', 'c130'],
#  ['c098',
#   'c102',
#   'c127',
#   'c099',
#   'c073',
#   'c000',
#   'c071',
#   'c070',
#   'c075',
#   'c001'],
#  ['c081', 'c034', 'c112', 'c148', 'c037'],
#  ['c110', 'c153', 'c072', 'c070', 'c118', 'c107', 'c106'],
#  ['c006',
#   'c008',
#   'c097',
#   'c112',
#   'c141',
#   'c154',
#   'c113',
#   'c151',
#   'c125',
#   'c114'],
#  ['c118', 'c006', 'c142', 'c147'],
#  ['c123', 'c151', 'c154', 'c097', 'c033', 'c035', 'c059', 'c153'],
#  ['c008', 'c097', 'c119', 'c118', 'c121', 'c006', 'c081', 'c104', 'c120'],
#  ['c059', 'c061', 'c150', 'c065', 'c156'],
#  ['c015', 'c115', 'c016', 'c087'],
#  ['c026', 'c123', 'c027', 'c156', 'c032', 'c018', 'c019', 'c063'],
#  ['c026', 'c032', 'c059', 'c115', 'c145', 'c110', 'c118', 'c106', 'c009'],
#  ['c006', 'c152', 'c088', 'c082', 'c083', 'c023', 'c020'],
#  ['c086', 'c012'],
#  ['c118', 'c015', 'c016', 'c018', 'c102', 'c127', 'c099'],
#  ['c117', 'c026', 'c028'],
#  ['c089',
#   'c030',
#   'c117',
#   'c125',
#   'c009',
#   'c011',
#   'c026',
#   'c032',
#   'c027',
#   'c125'],
#  ['c134', 'c088', 'c084', 'c086', 'c135', 'c107', 'c106'],
#  ['c150',
#   'c028',
#   'c025',
#   'c082',
#   'c016',
#   'c015',
#   'c087',
#   'c030',
#   'c027',
#   'c026',
#   'c009'],
#  ['c076', 'c153', 'c079', 'c102', 'c127'],
#  ['c094', 'c152', 'c144', 'c096'],
#  ['c107',
#   'c135',
#   'c108',
#   'c062',
#   'c109',
#   'c119',
#   'c057',
#   'c134',
#   'c118',
#   'c061'],
#  ['c118', 'c119', 'c148'],
#  ['c151',
#   'c011',
#   'c095',
#   'c034',
#   'c036',
#   'c059',
#   'c009',
#   'c033',
#   'c035',
#   'c093',
#   'c014',
#   'c038'],
#  ['c008',
#   'c154',
#   'c025',
#   'c030',
#   'c082',
#   'c097',
#   'c026',
#   'c032',
#   'c081',
#   'c028',
#   'c096',
#   'c152',
#   'c151',
#   'c135'],
#  ['c018', 'c097', 'c152', 'c092', 'c017', 'c015'],
#  ['c016', 'c093'],
#  ['c143', 'c063', 'c061', 'c142', 'c062', 'c147'],
#  ['c019', 'c097', 'c129', 'c153'],
#  ['c021', 'c061', 'c061', 'c156', 'c113', 'c141', 'c020', 'c023', 'c112'],
#  ['c033', 'c113', 'c112', 'c143', 'c063', 'c063', 'c142', 'c061'],
#  ['c026', 'c027', 'c032', 'c151', 'c123'],
#  ['c033', 'c141'],
#  ['c142', 'c094', 'c147', 'c119'],
#  ['c096', 'c141', 'c008', 'c097', 'c155', 'c155', 'c000', 'c153'],
#  ['c009', 'c097'],
#  ['c026', 'c106', 'c032', 'c025'],
#  ['c076', 'c097', 'c113', 'c077', 'c112'],
#  ['c054', 'c126', 'c106', 'c110', 'c118', 'c119', 'c107'],
#  ['c120', 'c119', 'c150'],
#  ['c137', 'c118', 'c061', 'c097', 'c006'],
#  ['c093', 'c096', 'c128'],
#  ['c098', 'c149', 'c152', 'c084', 'c088', 'c016'],
#  ['c080', 'c001', 'c113', 'c112', 'c123', 'c004', 'c002', 'c000'],
#  ['c079', 'c080', 'c152', 'c108'],
#  ['c009', 'c011', 'c051', 'c059', 'c076', 'c153'],
#  ['c084', 'c088', 'c141', 'c008', 'c088', 'c081', 'c086'],
#  ['c135', 'c129', 'c106', 'c154', 'c151', 'c097'],
#  ['c046', 'c052'],
#  ['c021', 'c135', 'c149'],
#  ['c011', 'c051', 'c153'],
#  ['c087', 'c015'],
#  ['c152', 'c132', 'c106', 'c123', 'c107'],
#  ['c051', 'c052', 'c155', 'c096', 'c154'],
#  ['c106', 'c107', 'c142', 'c147', 'c143', 'c156', 'c063'],
#  ['c093'],
#  ['c015', 'c019', 'c059', 'c061', 'c156', 'c063', 'c016', 'c087'],
#  ['c118',
#   'c147',
#   'c142',
#   'c062',
#   'c130',
#   'c118',
#   'c008',
#   'c143',
#   'c063',
#   'c006'],
#  ['c026', 'c030', 'c097', 'c008', 'c113', 'c009', 'c028'],
#  ['c015', 'c016', 'c070', 'c072'],
#  ['c053', 'c125', 'c061', 'c118', 'c065', 'c156', 'c006', 'c054', 'c154'],
#  ['c097', 'c040', 'c141', 'c008'],
#  ['c143', 'c142', 'c147', 'c064'],
#  ['c075', 'c071', 'c020', 'c021', 'c156'],
#  ['c053', 'c098', 'c126', 'c054', 'c127', 'c102'],
#  ['c097', 'c152'],
#  ['c084', 'c115', 'c125', 'c154', 'c153', 'c086', 'c110'],
#  ['c059', 'c107', 'c154', 'c108', 'c106'],
#  ['c015', 'c016', 'c009', 'c017', 'c144', 'c106'],
#  ['c149'],
#  ['c062', 'c015', 'c018', 'c016'],
#  ['c143', 'c142', 'c132'],
#  ['c015', 'c155', 'c003', 'c001'],
#  ['c070', 'c055', 'c097', 'c154'],
#  ['c106', 'c040', 'c044'],
#  ['c006', 'c097', 'c150'],
#  ['c000', 'c148', 'c096', 'c149'],
#  ['c128', 'c129', 'c097', 'c006'],
#  ['c096', 'c116', 'c117', 'c115', 'c097', 'c097'],
#  ['c009', 'c106', 'c152'],
#  ['c107', 'c123', 'c153', 'c106'],
#  ['c061', 'c065', 'c097', 'c156', 'c110', 'c105', 'c039', 'c108'],
#  ['c107', 'c104', 'c038', 'c140', 'c106', 'c033', 'c097', 'c150'],
#  ['c015', 'c016', 'c052', 'c104'],
#  ['c020',
#   'c005',
#   'c023',
#   'c002',
#   'c004',
#   'c021',
#   'c000',
#   'c001',
#   'c000',
#   'c000',
#   'c106'],
#  ['c098', 'c127', 'c155', 'c000'],
#  ['c134',
#   'c146',
#   'c133',
#   'c017',
#   'c128',
#   'c129',
#   'c096',
#   'c009',
#   'c015',
#   'c016'],
#  ['c061', 'c062', 'c063', 'c123', 'c156', 'c030', 'c026'],
#  ['c006', 'c141', 'c008', 'c097', 'c073', 'c070'],
#  ['c026', 'c124', 'c154', 'c028', 'c031', 'c097', 'c146', 'c032'],
#  ['c076', 'c080', 'c149', 'c125', 'c156', 'c151'],
#  ['c118', 'c121', 'c139', 'c002', 'c121', 'c000'],
#  ['c139', 'c150', 'c097', 'c128', 'c038', 'c095'],
#  ['c051', 'c052', 'c125', 'c135', 'c061', 'c128', 'c129', 'c156', 'c046'],
#  ['c059', 'c115', 'c126', 'c149', 'c152'],
#  ['c015', 'c019', 'c092'],
#  ['c000', 'c148', 'c000', 'c155', 'c141', 'c003', 'c001', 'c153'],
#  ['c011',
#   'c063',
#   'c021',
#   'c149',
#   'c152',
#   'c149',
#   'c152',
#   'c106',
#   'c061',
#   'c156'],
#  ['c118', 'c120', 'c119'],
#  ['c020', 'c024', 'c022', 'c130'],
#  ['c059', 'c061', 'c065', 'c115', 'c145', 'c156', 'c132'],
#  ['c153', 'c097', 'c151', 'c125', 'c061'],
#  ['c048', 'c052', 'c033', 'c151', 'c150', 'c047', 'c070', 'c050', 'c125'],
#  ['c034',
#   'c004',
#   'c026',
#   'c030',
#   'c027',
#   'c032',
#   'c096',
#   'c035',
#   'c095',
#   'c033',
#   'c038',
#   'c038'],
#  ['c070',
#   'c072',
#   'c076',
#   'c078',
#   'c122',
#   'c132',
#   'c071',
#   'c068',
#   'c154',
#   'c069',
#   'c067',
#   'c156',
#   'c065',
#   'c077'],
#  ['c130', 'c008', 'c113', 'c112', 'c081', 'c082', 'c114'],
#  ['c009', 'c049', 'c023', 'c150', 'c041'],
#  ['c015', 'c016', 'c017', 'c104'],
#  ['c082'],
#  ['c026', 'c032', 'c153', 'c029', 'c152', 'c029'],
#  ['c104',
#   'c096',
#   'c030',
#   'c026',
#   'c027',
#   'c032',
#   'c097',
#   'c144',
#   'c152',
#   'c094'],
#  ['c004', 'c021', 'c001', 'c003'],
#  ['c150', 'c053', 'c097', 'c153'],
#  ['c009',
#   'c010',
#   'c011',
#   'c014',
#   'c026',
#   'c028',
#   'c032',
#   'c061',
#   'c063',
#   'c069',
#   'c106',
#   'c110',
#   'c115',
#   'c117',
#   'c145',
#   'c116',
#   'c107',
#   'c067'],
#  ['c006', 'c015', 'c112'],
#  ['c143', 'c142', 'c121'],
#  ['c026', 'c115', 'c145', 'c008', 'c141', 'c006', 'c147'],
#  ['c020', 'c155', 'c009', 'c130', 'c022', 'c002'],
#  ['c151', 'c135', 'c065', 'c092', 'c154'],
#  ['c011', 'c059', 'c152', 'c088'],
#  ['c102', 'c137', 'c127'],
#  ['c081', 'c130', 'c062', 'c066', 'c147'],
#  ['c012',
#   'c119',
#   'c130',
#   'c042',
#   'c113',
#   'c114',
#   'c081',
#   'c113',
#   'c112',
#   'c021',
#   'c009'],
#  ['c149', 'c108'],
#  ['c020',
#   'c033',
#   'c034',
#   'c036',
#   'c070',
#   'c075',
#   'c107',
#   'c009',
#   'c151',
#   'c011',
#   'c106',
#   'c071',
#   'c024'],
#  ['c003', 'c080'],
#  ['c000', 'c001', 'c148', 'c110', 'c118', 'c106', 'c075', 'c071'],
#  ['c150', 'c097', 'c104', 'c090', 'c113'],
#  ['c033', 'c034', 'c038', 'c152', 'c153'],
#  ['c008', 'c141', 'c143', 'c006', 'c142', 'c002', 'c000'],
#  ['c020', 'c034', 'c071', 'c075'],
#  ['c098', 'c102', 'c127', 'c149', 'c061', 'c063', 'c062', 'c130', 'c081'],
#  ['c000', 'c070', 'c067', 'c072', 'c156'],
#  ['c096', 'c148', 'c008'],
#  ['c061', 'c118', 'c008', 'c097', 'c106'],
#  ['c008', 'c097', 'c056', 'c057', 'c053'],
#  ['c070', 'c097', 'c040', 'c043', 'c081', 'c042', 'c071', 'c034'],
#  ['c070',
#   'c071',
#   'c106',
#   'c106',
#   'c074',
#   'c120',
#   'c118',
#   'c119',
#   'c075',
#   'c110'],
#  ['c150', 'c015', 'c016'],
#  ['c040', 'c059', 'c011', 'c042', 'c097', 'c154', 'c149'],
#  ['c008', 'c152', 'c004', 'c006', 'c154', 'c001', 'c054'],
#  ['c123', 'c154', 'c073', 'c070', 'c030', 'c026'],
#  ['c020',
#   'c062',
#   'c063',
#   'c081',
#   'c130',
#   'c152',
#   'c081',
#   'c081',
#   'c110',
#   'c109',
#   'c063',
#   'c063'],
#  ['c026',
#   'c027',
#   'c027',
#   'c028',
#   'c032',
#   'c117',
#   'c025',
#   'c028',
#   'c031',
#   'c117',
#   'c083',
#   'c084',
#   'c088'],
#  ['c147', 'c128'],
#  ['c106', 'c143', 'c106', 'c061'],
#  ['c006',
#   'c008',
#   'c112',
#   'c125',
#   'c081',
#   'c114',
#   'c082',
#   'c127',
#   'c027',
#   'c028',
#   'c032',
#   'c025'],
#  ['c104', 'c016', 'c154', 'c059', 'c151', 'c015', 'c017', 'c018', 'c097'],
#  ['c033', 'c061', 'c070'],
#  ['c134',
#   'c146',
#   'c000',
#   'c154',
#   'c077',
#   'c074',
#   'c004',
#   'c002',
#   'c127',
#   'c135',
#   'c126',
#   'c003'],
#  ['c127', 'c137', 'c110', 'c107', 'c118', 'c106', 'c009'],
#  ['c051', 'c046', 'c052'],
#  ['c125', 'c154', 'c079', 'c126', 'c077', 'c151'],
#  ['c001', 'c076', 'c077', 'c081', 'c074', 'c126'],
#  ['c003', 'c087', 'c015', 'c155'],
#  ['c107',
#   'c110',
#   'c118',
#   'c119',
#   'c120',
#   'c148',
#   'c001',
#   'c000',
#   'c148',
#   'c105'],
#  ['c097',
#   'c079',
#   'c035',
#   'c151',
#   'c006',
#   'c078',
#   'c076',
#   'c150',
#   'c034',
#   'c135',
#   'c077',
#   'c154',
#   'c033'],
#  ['c060', 'c103', 'c151'],
#  ['c097', 'c008', 'c118', 'c061', 'c152', 'c149', 'c006'],
#  ['c059', 'c081', 'c107', 'c109', 'c110', 'c106', 'c154', 'c082'],
#  ['c004', 'c016', 'c015', 'c018', 'c001', 'c002'],
#  ['c033', 'c097', 'c153', 'c008'],
#  ['c153', 'c144'],
#  ['c016', 'c009', 'c017', 'c014', 'c052'],
#  ['c149', 'c152', 'c097', 'c152'],
#  ['c093', 'c096', 'c041', 'c044', 'c042', 'c039', 'c040', 'c043'],
#  ['c015', 'c122', 'c146', 'c154', 'c107', 'c110', 'c106'],
#  ['c005',
#   'c040',
#   'c041',
#   'c041',
#   'c044',
#   'c009',
#   'c039',
#   'c097',
#   'c039',
#   'c042'],
#  ['c002',
#   'c153',
#   'c155',
#   'c120',
#   'c119',
#   'c118',
#   'c121',
#   'c069',
#   'c156',
#   'c067',
#   'c065'],
#  ['c149', 'c020', 'c024', 'c142', 'c143'],
#  ['c072', 'c132', 'c134', 'c070'],
#  ['c061', 'c128', 'c153'],
#  ['c141', 'c008', 'c097', 'c006', 'c150', 'c086'],
#  ['c107', 'c154', 'c110', 'c108', 'c123', 'c106', 'c109', 'c009'],
#  ['c094', 'c096', 'c152', 'c154', 'c113', 'c114'],
#  ['c026', 'c032', 'c135', 'c025', 'c109', 'c106', 'c154'],
#  ['c078',
#   'c080',
#   'c134',
#   'c146',
#   'c133',
#   'c077',
#   'c126',
#   'c135',
#   'c076',
#   'c152',
#   'c079'],
#  ['c139', 'c035', 'c038', 'c153', 'c034', 'c137', 'c127', 'c153'],
#  ['c143', 'c142', 'c153', 'c063', 'c130', 'c020'],
#  ['c076', 'c107', 'c150', 'c123', 'c080', 'c151'],
#  ['c059', 'c114', 'c063', 'c097', 'c154'],
#  ['c143', 'c130', 'c063', 'c120', 'c147', 'c062', 'c061'],
#  ['c038', 'c059', 'c070', 'c154', 'c100', 'c152', 'c149', 'c034'],
#  ['c002',
#   'c004',
#   'c081',
#   'c082',
#   'c114',
#   'c154',
#   'c023',
#   'c127',
#   'c000',
#   'c020',
#   'c021',
#   'c001',
#   'c035',
#   'c033',
#   'c034'],
#  ['c137', 'c141'],
#  ['c147', 'c143'],
#  ['c128', 'c152', 'c149', 'c107', 'c000', 'c153', 'c155'],
#  ['c011', 'c052', 'c059', 'c152', 'c153'],
#  ['c033', 'c096'],
#  ['c154', 'c114', 'c060', 'c063', 'c113', 'c082', 'c063'],
#  ['c008', 'c097', 'c123', 'c151', 'c107', 'c006', 'c132', 'c120', 'c118'],
#  ['c065', 'c067', 'c118', 'c156', 'c097'],
#  ['c107', 'c125', 'c092', 'c109', 'c153'],
#  ['c150', 'c141', 'c008'],
#  ['c015', 'c016', 'c087', 'c123', 'c152', 'c087'],
#  ['c131', 'c132', 'c149', 'c148'],
#  ['c019', 'c008', 'c055', 'c152', 'c148', 'c097', 'c151', 'c152', 'c059'],
#  ['c011', 'c015', 'c016', 'c059', 'c009', 'c017', 'c153', 'c154', 'c150'],
#  ['c006', 'c008', 'c020', 'c097', 'c141', 'c021', 'c006', 'c153'],
#  ['c020', 'c020', 'c143', 'c142', 'c021', 'c062', 'c130', 'c061'],
#  ['c015', 'c016', 'c017', 'c081', 'c061', 'c063'],
#  ['c041'],
#  ['c016', 'c147', 'c015'],
#  ['c059', 'c076', 'c078'],
#  ['c133',
#   'c134',
#   'c146',
#   'c072',
#   'c063',
#   'c156',
#   'c107',
#   'c129',
#   'c106',
#   'c009',
#   'c118'],
#  ['c016', 'c151', 'c015', 'c087', 'c135'],
#  ['c082', 'c114'],
#  ['c128', 'c126', 'c154', 'c096', 'c094'],
#  ['c106', 'c107', 'c009', 'c109'],
#  ['c000', 'c004', 'c020', 'c076', 'c149', 'c003', 'c022', 'c126', 'c077'],
#  ['c098'],
#  ['c107',
#   'c106',
#   'c009',
#   'c109',
#   'c050',
#   'c008',
#   'c047',
#   'c097',
#   'c141',
#   'c006'],
#  ['c145', 'c092', 'c152'],
#  ['c011', 'c059', 'c108', 'c109', 'c118', 'c106'],
#  ['c150', 'c152', 'c097', 'c149'],
#  ['c101', 'c126', 'c113', 'c006', 'c112'],
#  ['c106', 'c152'],
#  ['c047', 'c049', 'c009', 'c046', 'c097'],
#  ['c139'],
#  ['c031', 'c009', 'c109'],
#  ['c107', 'c110', 'c128', 'c106'],
#  ['c020', 'c021', 'c127', 'c054', 'c040', 'c152', 'c043'],
#  ['c006',
#   'c008',
#   'c020',
#   'c023',
#   'c097',
#   'c141',
#   'c021',
#   'c002',
#   'c148',
#   'c022',
#   'c000'],
#  ['c096', 'c148', 'c055'],
#  ['c118', 'c119', 'c151', 'c132', 'c097'],
#  ['c011', 'c059', 'c137', 'c153', 'c152', 'c127'],
#  ['c011', 'c059', 'c149', 'c145', 'c064'],
#  ['c020',
#   'c023',
#   'c001',
#   'c097',
#   'c141',
#   'c006',
#   'c022',
#   'c021',
#   'c002',
#   'c000',
#   'c004'],
#  ['c073', 'c071', 'c009', 'c070', 'c075'],
#  ['c132', 'c151', 'c135', 'c022'],
#  ['c106', 'c107', 'c152', 'c149', 'c127', 'c058', 'c056', 'c057'],
#  ['c081', 'c106'],
#  ['c060', 'c103', 'c151', 'c011', 'c059', 'c107', 'c106'],
#  ['c009', 'c040', 'c042', 'c112', 'c113'],
#  ['c098', 'c102', 'c126', 'c080', 'c127'],
#  ['c154', 'c148', 'c002', 'c000', 'c123', 'c151'],
#  ['c114', 'c141', 'c018', 'c015', 'c017', 'c113'],
#  ['c110', 'c106', 'c151', 'c123', 'c009', 'c109', 'c057'],
#  ['c015', 'c016', 'c147'],
#  ['c077', 'c080', 'c106', 'c009', 'c107'],
#  ['c015', 'c134', 'c146', 'c152', 'c106', 'c129', 'c009', 'c154', 'c107'],
#  ['c127', 'c137', 'c018', 'c015', 'c019'],
#  ['c012', 'c098', 'c009'],
#  ['c070', 'c122', 'c146', 'c071'],
#  ['c124', 'c146', 'c154', 'c150', 'c002', 'c035', 'c097', 'c125'],
#  ['c086', 'c088', 'c154', 'c110', 'c106', 'c107'],
#  ['c026', 'c032', 'c027', 'c025', 'c108', 'c106'],
#  ['c020', 'c097', 'c006', 'c022', 'c024', 'c008', 'c141'],
#  ['c098', 'c102', 'c154', 'c127', 'c152'],
#  ['c015', 'c016', 'c018', 'c087', 'c000', 'c002', 'c148'],
#  ['c070',
#   'c072',
#   'c122',
#   'c130',
#   'c023',
#   'c063',
#   'c020',
#   'c021',
#   'c009',
#   'c062',
#   'c022',
#   'c146',
#   'c071',
#   'c154'],
#  ['c113', 'c130', 'c082', 'c042', 'c081', 'c114'],
#  ['c070', 'c075', 'c076'],
#  ['c047', 'c051', 'c107', 'c153', 'c126'],
#  ['c120', 'c106', 'c118'],
#  ['c123', 'c132', 'c065', 'c067', 'c156'],
#  ['c028', 'c081', 'c015', 'c016'],
#  ['c026', 'c027', 'c032', 'c115', 'c124', 'c125', 'c152', 'c025'],
#  ['c020',
#   'c061',
#   'c063',
#   'c063',
#   'c156',
#   'c057',
#   'c126',
#   'c062',
#   'c100',
#   'c098'],
#  ['c061',
#   'c008',
#   'c141',
#   'c006',
#   'c092',
#   'c097',
#   'c062',
#   'c081',
#   'c118',
#   'c156',
#   'c065'],
#  ['c125', 'c136', 'c065', 'c156'],
#  ['c043', 'c040', 'c097', 'c042', 'c081'],
#  ['c011', 'c027', 'c030', 'c026', 'c032', 'c029', 'c152'],
#  ['c011', 'c019', 'c137', 'c152'],
#  ['c012', 'c081', 'c042', 'c022'],
#  ['c061', 'c065', 'c156', 'c067', 'c151', 'c123'],
#  ['c147', 'c155', 'c000', 'c002', 'c097', 'c141'],
#  ['c011', 'c123', 'c062', 'c087', 'c154', 'c015', 'c016'],
#  ['c015', 'c016', 'c053'],
#  ['c051', 'c076', 'c078', 'c125'],
#  ['c020', 'c047', 'c048', 'c021'],
#  ['c026', 'c032', 'c125', 'c027'],
#  ['c015', 'c097', 'c153', 'c062', 'c063', 'c061', 'c065', 'c156'],
#  ['c142', 'c061', 'c128', 'c143', 'c129', 'c156', 'c063'],
#  ['c009', 'c028', 'c031', 'c114', 'c115', 'c116'],
#  ['c123', 'c004', 'c127', 'c002', 'c000', 'c145', 'c106'],
#  ['c011', 'c106', 'c154', 'c150', 'c097', 'c009', 'c151', 'c059'],
#  ['c134', 'c016', 'c152', 'c149'],
#  ['c096', 'c018', 'c015', 'c016', 'c087', 'c148'],
#  ['c118', 'c119', 'c121', 'c010', 'c011', 'c132'],
#  ['c001', 'c072', 'c134', 'c135', 'c154', 'c151', 'c146', 'c133', 'c055'],
#  ['c137', 'c039', 'c147', 'c006'],
#  ['c061', 'c147', 'c081', 'c062', 'c112', 'c113', 'c128', 'c106', 'c129'],
#  ['c033', 'c035', 'c038', 'c140', 'c036'],
#  ['c015', 'c016', 'c051', 'c017'],
#  ['c008', 'c053', 'c097', 'c054'],
#  ['c147', 'c035', 'c114', 'c038', 'c061', 'c062', 'c063'],
#  ['c015', 'c016', 'c033', 'c038', 'c095', 'c114'],
#  ['c033', 'c088', 'c085'],
#  ['c093', 'c081', 'c082'],
#  ['c019', 'c082', 'c096'],
#  ['c107'],
#  ['c015', 'c018', 'c016', 'c152', 'c087'],
#  ['c033', 'c156', 'c119', 'c112', 'c113', 'c118', 'c120', 'c081'],
#  ['c082', 'c004', 'c009', 'c026', 'c030', 'c028', 'c116', 'c002', 'c009'],
#  ['c015', 'c016', 'c149'],
#  ['c096', 'c152', 'c144'],
#  ['c093', 'c096', 'c113', 'c007', 'c112', 'c152'],
#  ['c151', 'c071', 'c073', 'c070', 'c059', 'c009', 'c072'],
#  ['c070', 'c097', 'c118', 'c150'],
#  ['c084'],
#  ['c065', 'c067', 'c087', 'c018', 'c015', 'c016', 'c156', 'c061'],
#  ['c011', 'c059', 'c097', 'c082', 'c014', 'c145'],
#  ['c038', 'c121', 'c092', 'c118', 'c119', 'c120'],
#  ['c092', 'c125', 'c132'],
#  ['c008', 'c097', 'c141', 'c006'],
#  ['c040', 'c150', 'c041', 'c053'],
#  ['c040', 'c042', 'c110', 'c107', 'c106', 'c109', 'c008', 'c125', 'c006'],
#  ['c000', 'c004', 'c001', 'c153'],
#  ['c011',
#   'c026',
#   'c032',
#   'c059',
#   'c123',
#   'c151',
#   'c118',
#   'c097',
#   'c065',
#   'c009',
#   'c068',
#   'c119'],
#  ['c144', 'c141', 'c112', 'c006', 'c113', 'c008'],
#  ['c147', 'c041', 'c062', 'c147'],
#  ['c125', 'c140', 'c141'],
#  ['c061', 'c065', 'c124', 'c145', 'c156'],
#  ['c113', 'c130', 'c062', 'c112', 'c081', 'c082', 'c114'],
#  ['c047',
#   'c052',
#   'c046',
#   'c049',
#   'c069',
#   'c156',
#   'c063',
#   'c065',
#   'c061',
#   'c067'],
#  ['c059',
#   'c132',
#   'c107',
#   'c110',
#   'c106',
#   'c079',
#   'c154',
#   'c077',
#   'c109',
#   'c119'],
#  ['c020', 'c023', 'c008', 'c104', 'c022'],
#  ['c092', 'c082', 'c114', 'c043', 'c040', 'c150'],
#  ['c015',
#   'c016',
#   'c059',
#   'c123',
#   'c077',
#   'c017',
#   'c008',
#   'c141',
#   'c097',
#   'c006',
#   'c076',
#   'c154'],
#  ['c132', 'c156', 'c131', 'c061', 'c152'],
#  ['c018', 'c021', 'c059', 'c015', 'c016'],
#  ['c147'],
#  ['c015', 'c016', 'c033', 'c037'],
#  ['c144', 'c097', 'c148', 'c001', 'c153'],
#  ['c150',
#   'c154',
#   'c151',
#   'c156',
#   'c120',
#   'c118',
#   'c011',
#   'c059',
#   'c119',
#   'c009',
#   'c012',
#   'c145'],
#  ['c011', 'c014', 'c009', 'c107', 'c106', 'c152'],
#  ['c015', 'c135', 'c016', 'c017', 'c117', 'c154', 'c087'],
#  ['c022', 'c036', 'c020', 'c149', 'c097', 'c024', 'c114', 'c127'],
#  ['c026', 'c032', 'c085', 'c149', 'c097', 'c033', 'c029', 'c009', 'c017'],
#  ['c155', 'c107', 'c106', 'c002', 'c026', 'c032', 'c027', 'c030'],
#  ['c020', 'c061', 'c022', 'c062'],
#  ['c059', 'c076', 'c092'],
#  ['c033', 'c070', 'c152'],
#  ['c057', 'c144', 'c053', 'c054', 'c058', 'c126'],
#  ['c092', 'c020', 'c021', 'c002', 'c056'],
#  ['c124', 'c000', 'c002', 'c148', 'c080', 'c154', 'c097', 'c008', 'c146'],
#  ['c015', 'c016', 'c135', 'c154', 'c008', 'c097'],
#  ['c008', 'c141', 'c054', 'c059', 'c055', 'c151'],
#  ['c061', 'c065', 'c156', 'c015', 'c016'],
#  ['c149', 'c152', 'c075', 'c073', 'c070', 'c009', 'c012'],
#  ['c059', 'c051', 'c052', 'c014', 'c088'],
#  ['c008', 'c113', 'c006', 'c141'],
#  ['c118', 'c119', 'c081'],
#  ['c008', 'c082', 'c114', 'c062', 'c038', 'c112'],
#  ['c124', 'c125', 'c146', 'c115', 'c117', 'c154', 'c081', 'c116'],
#  ['c072', 'c122', 'c146', 'c069', 'c067', 'c061'],
#  ['c081', 'c155', 'c002', 'c000'],
#  ['c011', 'c014', 'c032', 'c059', 'c025', 'c149', 'c152', 'c154'],
#  ['c153', 'c008', 'c079', 'c076'],
#  ['c117',
#   'c031',
#   'c024',
#   'c026',
#   'c115',
#   'c021',
#   'c144',
#   'c097',
#   'c020',
#   'c030'],
#  ['c059', 'c155', 'c000', 'c001', 'c003', 'c054', 'c058', 'c053'],
#  ['c040', 'c112', 'c114', 'c113', 'c042', 'c081'],
#  ['c040', 'c042', 'c009', 'c041', 'c044', 'c117', 'c097'],
#  ['c129', 'c000', 'c095', 'c106'],
#  ['c033', 'c125', 'c149', 'c152'],
#  ['c015', 'c016', 'c087', 'c009', 'c017', 'c151', 'c134', 'c122'],
#  ['c015', 'c019', 'c021', 'c061', 'c063', 'c062', 'c147', 'c018'],
#  ['c152', 'c155', 'c113', 'c155'],
#  ['c123', 'c156', 'c015', 'c016', 'c018'],
#  ['c026',
#   'c072',
#   'c115',
#   'c122',
#   'c146',
#   'c116',
#   'c028',
#   'c153',
#   'c070',
#   'c071',
#   'c154'],
#  ['c133', 'c134', 'c146', 'c075', 'c135', 'c154'],
#  ['c023', 'c153', 'c057', 'c112', 'c113'],
#  ['c033', 'c072', 'c037', 'c034', 'c073', 'c070'],
#  ['c072',
#   'c076',
#   'c077',
#   'c078',
#   'c133',
#   'c134',
#   'c070',
#   'c001',
#   'c003',
#   'c036',
#   'c154',
#   'c097',
#   'c071',
#   'c002',
#   'c000'],
#  ['c014', 'c085', 'c149', 'c154', 'c151', 'c052', 'c059', 'c011'],
#  ['c033', 'c090', 'c113', 'c153'],
#  ['c124', 'c070', 'c071', 'c074', 'c146', 'c154', 'c073'],
#  ['c011',
#   'c061',
#   'c065',
#   'c067',
#   'c069',
#   'c156',
#   'c062',
#   'c068',
#   'c035',
#   'c033',
#   'c038'],
#  ['c096', 'c144', 'c153', 'c015', 'c019', 'c152', 'c094'],
#  ['c107', 'c118'],
#  ['c154', 'c106', 'c109'],
#  ['c137', 'c098', 'c000', 'c076', 'c001', 'c148'],
#  ['c017', 'c154', 'c012', 'c054', 'c058', 'c053', 'c016'],
#  ['c015', 'c113', 'c002', 'c019', 'c149', 'c148'],
#  ['c061', 'c062', 'c063', 'c064', 'c147', 'c017', 'c018', 'c087', 'c015'],
#  ['c063', 'c069', 'c061', 'c051', 'c062', 'c064', 'c068'],
#  ['c011', 'c014', 'c059', 'c115', 'c145', 'c156', 'c062', 'c063'],
#  ...]

# %%
result[0:30] # 0, 1, 2, 3, 6, 7, 8, 9
# 1st 困難：8	c089	Closing a window\n	c090	Opening a window\n	
# 2nd 困難：how about 3 and 7? c084有兩種結果...

# 0, 1, 3, 5, 21, 23
# door, chair, cup/dishes, picture, laptop, window
# Out:
#    1st class                         1st class name 2nd class  \
# 0       c007                        Fixing a door\n      c140
# 1       c060                  Standing on a chair\n      c103
# 2       c099            Putting a broom somewhere\n      c101
# 3       c111           Washing a cup/glass/bottle\n      c121
# 4       c137                     Holding a vacuum\n      c138
# 5       c084                    Holding a picture\n      c088
# 6       c083  Reaching for and grabbing a picture\n      c084
# 7       c012                   Tidying up a table\n      c013
# 8       c038       Washing something with a towel\n      c095
# 9       c083  Reaching for and grabbing a picture\n      c086
# 10      c089                     Closing a window\n      c090
# 11      c084                    Holding a picture\n      c085
# 12      c133          Someone is awakening in bed\n      c146
# 13      c091                     Washing a window\n      c095
# 14      c098                      Holding a broom\n      c100
# 15      c047                     Holding a laptop\n      c050
# 16      c133          Someone is awakening in bed\n      c134
# 17      c013                      Washing a table\n      c038
# 18      c085                Laughing at a picture\n      c086
# 19      c038       Washing something with a towel\n      c091
# 20      c095                     Washing a mirror\n      c111
# 21      c046                     Closing a laptop\n      c049
# 22      c042              Putting a box somewhere\n      c045
# 23      c090                     Opening a window\n      c092
# 24      c091                     Washing a window\n      c111
# 25      c085                Laughing at a picture\n      c131
# 26      c007                        Fixing a door\n      c101
# 27      c084                    Holding a picture\n      c086
# 28      c083  Reaching for and grabbing a picture\n      c085
# 29      c085                Laughing at a picture\n      c088
#
#                             2nd class name pointwise mutual info
# 0                      Fixing a doorknob\n    10.889790389666496
# 1                         Fixing a light\n    10.753384151272465
# 2             Throwing a broom somewhere\n    10.689673445921121
# 3                     Wash a dish/dishes\n     9.854881341156664
# 4         Taking a vacuum from somewhere\n     9.796809314189238
# 5          Watching/looking at a picture\n     9.569586975248596
# 6                      Holding a picture\n     9.535772262256351
# 7                        Washing a table\n     9.474344715242509
# 8                       Washing a mirror\n      9.45743926001654
# 9            Putting a picture somewhere\n     9.435224526201015
# 10                      Opening a window\n     9.428010251804913
# 11                 Laughing at a picture\n     9.414308749770683
# 12        Someone is awakening somewhere\n     9.369454513986424
# 13                      Washing a mirror\n     9.367053023559436
# 14         Taking a broom from somewhere\n     9.319625591466647
# 15        Taking a laptop from somewhere\n       9.2949032378036
# 16                        Lying on a bed\n     9.148464810350065
# 17        Washing something with a towel\n     9.114110530673484
# 18           Putting a picture somewhere\n     9.100357375606155
# 19                      Washing a window\n     9.040453488948176
# 20            Washing a cup/glass/bottle\n     9.037745398306477
# 21            Putting a laptop somewhere\n     9.032185872964575
# 22              Throwing a box somewhere\n     8.997863193537507
# 23  Watching/Looking outside of a window\n      8.97365460180926
# 24            Washing a cup/glass/bottle\n     8.961796545073177
# 25                Laughing at television\n     8.946029229214862
# 26            Throwing a broom somewhere\n     8.878202415391284
# 27           Putting a picture somewhere\n      8.85242986216257
# 28                 Laughing at a picture\n      8.84510032036408
# 29         Watching/looking at a picture\n     8.840234565192265

# %%
picked = [0, 1, 3, 5, 21, 23]
a = result.get(picked)

# %%
result_class = []
for i in picked:
    result_class.append(mypmi[i][0])
    result_class.append(mypmi[i][2])

# %%
# result_class.remove('c084') # repeated

# %%
result_class # 13 classes in total
# ['c007',
#  'c140',
 
#  'c060',
#  'c103',
 
#  'c099',
#  'c101',
 
#  'c086', # also 'c084'
 
#  'c111',
#  'c121',
 
#  'c084',
#  'c085',
 
#  'c089',
#  'c090',
 
#  'c012',
#  'c013']
# Out:
# ['c007',
#  'c140',
#  'c060',
#  'c103',
#  'c111',
#  'c121',
#  'c084',
#  'c088',
#  'c046',
#  'c049',
#  'c090',
#  'c092']

# %%
for (idx, row) in df.iterrows():
    act = row['actions']
    if ('c007' in act and 'c140' in act) or \
    ('c060' in act and 'c103' in act) or \
    ('c111' in act and 'c121' in act) or \
    ('c084' in act and 'c088' in act) or \
    ('c046' in act and 'c049' in act) or \
    ('c090' in act and 'c092' in act):
        print(act)
    else:
        df = df.drop(idx)
# Out:
# c106 0.00 11.10;c107 0.00 12.00;c038 13.70 23.60;c111 8.00 18.30;c121 15.50 27.10;c109 0.00 12.20;c035 14.00 23.30;c110 7.40 12.40
# c151 16.80 24.60;c052 0.00 19.20;c111 23.60 37.00;c121 22.30 37.00;c059 0.00 21.70;c011 0.00 24.30;c014 0.00 22.10;c051 0.00 22.10
# c084 0.00 14.60;c088 0.00 15.50;c106 12.20 19.00;c118 11.70 19.40;c123 0.00 21.00
# c088 6.10 11.50;c083 6.10 10.70;c084 8.90 19.00
# c084 17.70 33.00;c096 0.00 18.20;c152 0.00 7.00;c088 17.90 33.00
# c092 16.90 25.00;c097 3.50 17.00;c090 18.00 25.00
# c097 0.00 5.90;c111 4.70 42.00;c008 0.00 6.30;c082 3.90 42.00;c121 5.90 42.00;c006 1.10 7.70;c038 4.70 42.00
# c108 2.00 16.00;c111 2.00 16.00;c107 0.00 20.00;c119 15.10 20.80;c008 21.30 26.10;c121 4.30 10.90;c109 15.70 21.00
# c046 14.00 18.90;c049 11.80 18.20;c081 23.30 29.40;c125 0.00 19.30;c047 0.00 18.80
# c084 0.00 26.00;c123 26.70 32.00;c151 26.70 32.00;c105 10.30 21.50;c086 0.50 24.20;c096 15.10 21.50;c087 0.00 6.00;c018 22.50 29.00;c104 13.50 19.40;c015 25.00 32.00;c083 0.60 5.60;c088 3.30 24.30
# c033 2.20 8.30;c034 4.30 9.10;c090 10.30 22.80;c092 18.40 34.00;c098 5.10 11.00;c099 6.60 11.80;c150 0.00 4.50;c070 0.00 8.30;c101 6.10 11.30;c074 4.30 8.60;c036 2.80 8.80;c071 3.50 9.50
# c048 23.10 33.80;c123 22.10 37.50;c151 23.50 30.40;c153 9.60 16.70;c154 33.50 40.00;c113 14.10 22.80;c050 18.80 27.50;c046 31.10 35.90;c049 31.50 37.30;c047 18.40 35.50
# c033 6.20 31.00;c038 12.00 17.10;c088 0.00 11.20;c151 0.00 2.90;c011 0.60 31.00;c036 26.10 31.00;c084 0.00 31.00;c153 7.50 24.10;c009 26.50 31.00;c088 0.00 29.90;c115 0.00 30.50;c116 25.80 31.00;c117 0.00 4.40
# c152 23.30 27.70;c149 25.90 31.00;c016 0.00 23.10;c135 19.50 32.00;c084 19.10 32.00;c088 19.10 32.00;c015 0.00 32.00
# c084 4.30 11.20;c083 2.10 7.50;c088 4.00 11.70
# c111 0.00 22.60;c127 27.70 39.00;c091 7.10 23.90;c020 26.90 39.00;c154 0.00 39.00;c090 0.00 9.60;c012 27.10 39.00;c082 27.10 39.00;c092 2.40 10.60
# c060 0.00 32.00;c088 0.00 32.00;c083 0.00 6.60;c086 1.70 32.00;c084 0.00 32.00
# c008 19.50 28.70;c078 12.10 21.00;c084 0.00 9.60;c141 18.60 26.00;c134 0.00 17.30;c076 12.00 31.00;c079 10.00 18.20;c154 13.90 21.90;c088 0.00 17.50;c086 7.90 14.10;c097 26.70 31.00
# c046 1.70 10.80;c092 8.40 19.00;c156 1.80 19.00;c020 0.00 19.00;c047 0.00 14.90;c063 0.00 19.00;c049 8.10 14.60;c051 0.00 8.50;c135 0.00 19.00;c061 0.00 18.40;c081 5.30 15.60
# c152 10.10 21.40;c088 12.60 18.00;c084 0.00 32.00
# c040 4.50 14.20;c044 7.30 12.70;c088 10.70 16.40;c038 12.50 21.20;c041 5.40 11.00;c084 8.50 28.90;c152 19.20 28.20;c045 9.10 15.00;c043 3.10 9.90;c083 6.00 15.90;c152 29.00 32.00;c043 28.80 32.00;c083 29.00 32.00
# c009 9.90 15.70;c151 1.80 7.90;c153 4.40 13.50;c154 26.50 31.80;c123 3.40 30.80;c117 14.30 19.00;c086 9.90 15.20;c088 3.40 13.40;c116 15.00 19.10;c011 3.40 31.80;c084 2.10 15.80;c145 14.80 30.20;c115 13.70 30.00
# c135 0.00 32.00;c152 0.00 3.70;c083 12.90 20.20;c085 5.50 12.30;c084 15.70 32.00;c088 6.50 32.00
# c151 19.60 26.10;c040 1.60 10.00;c043 0.50 8.80;c088 19.10 32.00;c042 1.10 10.80;c059 18.80 32.00;c011 21.00 32.00;c127 0.50 19.20;c115 17.80 32.00;c084 19.60 32.00;c083 18.00 23.30;c117 18.90 23.90
# c046 13.10 18.90;c052 0.00 17.20;c123 0.00 21.00;c047 15.40 20.60;c049 17.40 21.00;c014 0.00 16.60
# c098 14.20 37.00;c100 12.00 18.20;c088 2.10 12.10;c099 17.30 36.70;c084 0.00 11.90;c154 17.40 37.00;c152 1.10 9.60;c086 9.00 15.50;c125 0.00 21.27
# c090 1.70 7.40;c092 3.30 8.50;c156 0.00 3.20;c061 0.00 3.60

# %%
df.tail()
# Out:
#          id subject                                     scene  quality  \
# 7715  TIEA9    ZAWX                                   Bedroom      7.0
# 7721  LTC5Y    KFGP  Basement (A room below the ground floor)      5.0
# 7754  45P7D    UO0Z                               Living room      7.0
# 7764  9OP4S    T7C3                                    Stairs      5.0
# 7790  XAW3U    WG9D                               Living room      4.0
#
#       relevance verified                                             script  \
# 7715        6.0      Yes  A person in a bed room is sitting at a desk lo...
# 7721        6.0      Yes  A person is tidying up the room when they see ...
# 7754        6.0      Yes  A person is playing a game on their laptop. Th...
# 7764        7.0      Yes  A person is sitting, looking at a picture. The...
# 7790        4.0       No  A person is eating and grasping a clothes hang...
#
#                                                 objects  \
# 7715                                        bed;picture
# 7721  box;chair;desk;fan;floor;paper/notebook;pictur...
# 7754                     couch;laptop;pillow;sofa;table
# 7764                         broom;floor;picture;stairs
# 7790                                curtain;food;window
#
#                                            descriptions  \
# 7715  A woman is sitting on a bed smiling and dancin...
# 7721  A person walks and  tidy ups the room a bit, i...
# 7754  A person sits on a couch while working on a la...
# 7764  A person is sitting on stairs looking at a pic...
# 7790  A person is standing by a curtained window eat...
#
#                                                 actions  length  origin_index
# 7715  c135 0.00 32.00;c152 0.00 3.70;c083 12.90 20.2...   30.75          7888
# 7721  c151 19.60 26.10;c040 1.60 10.00;c043 0.50 8.8...   31.42          7894
# 7754  c046 13.10 18.90;c052 0.00 17.20;c123 0.00 21....   20.38          7927
# 7764  c098 14.20 37.00;c100 12.00 18.20;c088 2.10 12...   35.83          7937
# 7790  c090 1.70 7.40;c092 3.30 8.50;c156 0.00 3.20;c...    9.54          7963

# %%
print(df.shape)
df = df.reset_index(drop=True)
df
# Out:
# (216, 12)
#         id subject                                              scene  \
# 0    2WGSN    WQ8Z                                            Kitchen
# 1    MZOPX    4YWP                                        Dining room
# 2    X0CKA    H8N1                                        Living room
# 3    MLDGN    HR43                                       Laundry room
# 4    FN457    9PLL                                            Bedroom
# 5    YORQM    5LWB                                           Bathroom
# 6    MD6C0    L4ZP  Entryway (A hall that is generally located at ...
# 7    ZXHLY    D0RU                                           Bathroom
# 8    OVEXF    D0RU                                            Bedroom
# 9    X3LEM    KQI6                                            Hallway
# 10   0CX32    C7O9                                        Living room
# 11   UYJVE    PO5L  Home Office / Study (A room in a house used fo...
# 12   9T11N    Z68L  Home Office / Study (A room in a house used fo...
# 13   JCBDT    YMXV                                            Bedroom
# 14   XZPAS    BYF9                                            Bedroom
# 15   3QVSC    XXN8                                            Hallway
# 16   KTQEL    9PLL                                        Living room
# 17   7NBPG    OUKK                                            Kitchen
# 18   UIWY2    QOQ4           Basement (A room below the ground floor)
# 19   H9V9I    XXN8             Closet / Walk-in closet / Spear closet
# 20   4O9A6    KFGP                                              Other
# 21   0GR11    XXN8                                            Kitchen
# 22   I8WPI    EXQX                                             Pantry
# 23   GYRNY    PKND                                             Garage
# 24   14A2O    9Y7F                                            Kitchen
# 25   F56YP    HJJ4                                             Stairs
# 26   1J3I0    HR43                                        Living room
# 27   QO0FI    T7C3                                       Laundry room
# 28   0IAGO    70CN                                        Dining room
# 29   CLORP    2RTW                                        Living room
# ..     ...     ...                                                ...
# 186  MNGT1    KFGP                                             Stairs
# 187  N7243    BPRF                                            Kitchen
# 188  US6P9    L4ZP                                        Living room
# 189  57QKQ    EIO2                                             Pantry
# 190  NOSZ3    18IT                                        Living room
# 191  9VBJ5    V8LI                                            Kitchen
# 192  RGIZ7    9Y7F                                        Living room
# 193  AZO8U    2RTW                                            Kitchen
# 194  QJ389    5LWB                                        Dining room
# 195  47ZXN    UTMU                                            Bedroom
# 196  JQJSB    KFGP                                            Hallway
# 197  H4ZD8    3H6W                                        Dining room
# 198  FYJHS    2RTW                                            Kitchen
# 199  RSRZ0    QZQ4                                            Kitchen
# 200  55687    YA10  Home Office / Study (A room in a house used fo...
# 201  LXJ86    P6LJ                                        Living room
# 202  RTIP8    UTMU                                            Bedroom
# 203  RTGML    OUKK                                             Pantry
# 204  CAND1    D0RU  Entryway (A hall that is generally located at ...
# 205  6UZLM    C7O9                                             Stairs
# 206  V54TI    8IOD                                            Bedroom
# 207  7VP2U    BYF9                                            Bedroom
# 208  C0GSN    9PLL                                            Kitchen
# 209  ZS7X6    UTMU                                             Garage
# 210  R3ZN9    PO5L                         Recreation room / Man cave
# 211  TIEA9    ZAWX                                            Bedroom
# 212  LTC5Y    KFGP           Basement (A room below the ground floor)
# 213  45P7D    UO0Z                                        Living room
# 214  9OP4S    T7C3                                             Stairs
# 215  XAW3U    WG9D                                        Living room
#
#      quality  relevance verified  \
# 0        7.0        7.0      Yes
# 1        6.0        6.0      Yes
# 2        4.0        6.0      Yes
# 3        5.0        3.0      Yes
# 4        6.0        6.0      Yes
# 5        5.0        5.0      Yes
# 6        6.0        6.0      Yes
# 7        7.0        7.0      Yes
# 8        7.0        1.0       No
# 9        6.0        5.0      Yes
# 10       6.0        6.0      Yes
# 11       4.0        7.0      Yes
# 12       6.0        7.0      Yes
# 13       6.0        7.0       No
# 14       7.0        7.0      Yes
# 15       6.0        3.0      Yes
# 16       6.0        7.0      Yes
# 17       6.0        7.0      Yes
# 18       6.0        7.0      Yes
# 19       7.0        7.0      Yes
# 20       5.0        7.0      Yes
# 21       7.0        7.0      Yes
# 22       6.0        7.0      Yes
# 23       6.0        5.0      Yes
# 24       5.0        7.0      Yes
# 25       7.0        7.0      Yes
# 26       3.0        6.0      Yes
# 27       6.0        7.0      Yes
# 28       7.0        7.0      Yes
# 29       6.0        6.0      Yes
# ..       ...        ...      ...
# 186      5.0        7.0      Yes
# 187      6.0        7.0      Yes
# 188      6.0        6.0      Yes
# 189      6.0        6.0      Yes
# 190      6.0        4.0      Yes
# 191      6.0        5.0      Yes
# 192      6.0        6.0      Yes
# 193      6.0        6.0      Yes
# 194      2.0        5.0      Yes
# 195      5.0        6.0      Yes
# 196      5.0        7.0      Yes
# 197      5.0        7.0      Yes
# 198      6.0        6.0      Yes
# 199      5.0        5.0      Yes
# 200      6.0        6.0      Yes
# 201      6.0        6.0      Yes
# 202      6.0        6.0      Yes
# 203      3.0        6.0      Yes
# 204      5.0        1.0       No
# 205      6.0        6.0      Yes
# 206      6.0        7.0      Yes
# 207      6.0        7.0      Yes
# 208      6.0        7.0      Yes
# 209      5.0        7.0      Yes
# 210      4.0        7.0      Yes
# 211      7.0        6.0      Yes
# 212      5.0        6.0      Yes
# 213      7.0        6.0      Yes
# 214      5.0        7.0      Yes
# 215      4.0        4.0       No
#
#                                                 script  \
# 0    A person drinks from a cup then puts it in the...
# 1    A person is playing on their new laptop and th...
# 2    Person is standing looking at a picture on a s...
# 3    A person in the laundry room is dressing by pu...
# 4    A person is smiling into a mirror while graspi...
# 5    A person opens the bathroom door and walks thr...
# 6    In the hallway, a person sees a glass sitting ...
# 7    A person is smiling while washing the glass an...
# 8    One person is sitting in a towel closing a lap...
# 9    One person puts a picture next to a mirror as ...
# 10   A person runs into the living room, carrying a...
# 11   A laptop sits on the cabinet a person is walki...
# 12   A person is in a office holding a picture, the...
# 13   A person is taking a picture of a doorknob whi...
# 14   A person is awakening with a cup of coffee whi...
# 15   A person is playing with a broom while another...
# 16   A person is standing with their hand on the do...
# 17   A person is standing in front of the stove hol...
# 18   A person stands on a chair in the basement, ch...
# 19   A person puts their laptop onto a desk, and wa...
# 20   The person fixes a light but abandons it to si...
# 21   A person is playing a game on their laptop. Th...
# 22   One person washes a glass and grasps a broom, ...
# 23   A person sits on the floor of the garage, work...
# 24   A person is throwing a picture while another p...
# 25   A person is closing a box and sneezing, then k...
# 26   One person closes a laptop, then lies down and...
# 27   A person walks into a laundry room and sneezes...
# 28   A person takes off their shoes before they beg...
# 29   Person awakens from a nap on the couch.  Perso...
# ..                                                 ...
# 186  A person was sitting on the stairs playing wit...
# 187  A person is sitting in a chair looking at a pi...
# 188  A person is holding a picture when suddenly th...
# 189  One person opens a window and puts a blanket o...
# 190  A person is in the hallway fixing a light whil...
# 191  The person is eating food and throwing coffee ...
# 192  A person closes a laptop, then laughs while lo...
# 193  A person is washing dishes and then starts tid...
# 194  A person is opening a window and another perso...
# 195  A person is tidying a cabinet. The stop, and t...
# 196  A person was leaving a camera on the floor in ...
# 197  A person is undressing in a dining room while ...
# 198  A person carrying a bag of groceries walks to ...
# 199  In the dining room, a person is smiling and lo...
# 200  One person plays with a picture, then washes i...
# 201  After opening the curtain, a person is standin...
# 202  A smiling person is sitting nest to a mirror, ...
# 203  A person opens a box and finds a picture insid...
# 204  A person is washing a glass window.  Then a pe...
# 205  While one person watches, another person puts ...
# 206  A person is lying on a bed looking at a pictur...
# 207  One person is putting a laptop on a shelf by a...
# 208  A person stands by the stove in the kitchen ho...
# 209  Person gets picture out box then starts washin...
# 210  A person is sneezing on a picture, then workin...
# 211  A person in a bed room is sitting at a desk lo...
# 212  A person is tidying up the room when they see ...
# 213  A person is playing a game on their laptop. Th...
# 214  A person is sitting, looking at a picture. The...
# 215  A person is eating and grasping a clothes hang...
#
#                                                objects  \
# 0                                 cup;dish;glass;towel
# 1    book;chair;cup;dish;glass;homework;laptop;sink...
# 2                  dish;glass;picture;sofa/couch;water
# 3                               clothes;picture;sponge
# 4                                       mirror;picture
# 5                                          door;window
# 6            cup;dish;door;glass;rag;shelf;table;towel
# 7      bucket;counter;cup;dish;door;glass;toilet;water
# 8           clothes;floor;laptop;shelf;something;towel
# 9                chair;light;mirror;phone;picture;sofa
# 10                          blanket;broom;towel;window
# 11                          closet/cabinet;laptop;sofa
# 12       chair;desk;paper/notebook;picture;table;towel
# 13                                   bed;phone;picture
# 14                         bed;cup;floor;glass;picture
# 15                          broom;phone/camera;picture
# 16                             door;hand;picture;shelf
# 17                     book;counter;picture;sink;stove
# 18                                         chair;light
# 19                           desk;doorway;laptop;table
# 20                        chair;coffee;cup;light;table
# 21                           food;game;laptop;sandwich
# 22                  broom;cup;dish;doorway;glass;light
# 23                               car;door;floor;ground
# 24   floor;food;paper/notebook;picture;sandwich;som...
# 25                                         box;picture
# 26                              book;couch;laptop;sofa
# 27                                       picture;shelf
# 28                            chair;doorway;light;shoe
# 29   blanket;blinds;book;food;pizza;sofa;table;tele...
# ..                                                 ...
# 186                                bag;laptop;shoulder
# 187       cabinet;chair;coffee;cup;glass;picture;shelf
# 188                          light;phone;picture;shelf
# 189                             blanket;clothes;window
# 190                   bag;chair;cup/glass/bottle;light
# 191         coffee;cup;dish;food;glass;sing;sink;water
# 192               bed;chair;lap top;laptop;sofa;window
# 193                       dish;glass;paper towel;table
# 194                            book;chair;table;window
# 195              chair;closet/cabinet;light;shelf;wall
# 196                                  door;floor;object
# 197  book;chair;clothes;jacket;phone/camera;picture...
# 198                           bag;door;groceries;table
# 199  broom;cabinet;chair;closet;door;table;wardrobe...
# 200                           door;picture;table;towel
# 201                                 blinds;book;window
# 202                                floor;frame;picture
# 203                                        box;picture
# 204   bag;cup;floor;glass;groceries;shelf;table;window
# 205                                      chair;picture
# 206                            bed;door;picture;pillow
# 207         bag;bed;food;groceries;laptop;shelf;window
# 208                                      photo;picture
# 209                    box;clothes;floor;picture;towel
# 210     couch;paper/notebook;papers;picture;sofa;table
# 211                                        bed;picture
# 212  box;chair;desk;fan;floor;paper/notebook;pictur...
# 213                     couch;laptop;pillow;sofa;table
# 214                         broom;floor;picture;stairs
# 215                                curtain;food;window
#
#                                           descriptions  \
# 0                        A person drinks from a glass.
# 1    A person is working on a laptop, then they pic...
# 2    A person is looking at a picture then takes a ...
# 3    A person fixes the coat they are wearing and t...
# 4    A person is looking at themselves in the mirro...
# 5    A person walks takes a stool, walks into a bat...
# 6    A person walks through the door and grabs a cl...
# 7    A person carries a glass to a water bucket and...
# 8    A person is sitting on the floor on a towel wh...
# 9    A person is taking a picture from a chair then...
# 10   A person runs into the room carrying a broom a...
# 11   A person walks into a room and begins sneezing...
# 12   A person takes a seat behind the desk. While s...
# 13   A person is playing with their phone while sta...
# 14   A person is lying on the bed holding a glass. ...
# 15   A  person is playing with a broom while anothe...
# 16   A person grasping a doorknob and holding a pic...
# 17   Person walks into kitchen reading a book.  Per...
# 18   A person steps on a chair, changes a light bul...
# 19   A  person is standing holding an open laptop. ...
# 20   A person is standing on a chair and fixing som...
# 21   Person is working on a laptop computer. They c...
# 22   A person was washing their hands, and then cle...
# 23   A person is fixing a lock on car with a screwd...
# 24   Two people standing in a kitchen, one is cooki...
# 25   There is a person sitting on the stairs holdin...
# 26   A person is sitting on a sofa closes laptop pi...
# 27   A person walks into a laundry and takes a pict...
# 28   A person sits down in a chair and takes off th...
# 29   A person is sleeping on a sofa. The person wak...
# ..                                                 ...
# 186  A person sits on the stairs working on their l...
# 187  A person is holding a framed picture and looki...
# 188  Person standing holding a picture and looking ...
# 189  A person wearing a blanket walks in, throws th...
# 190  A MAN IS FIXING A LIGHT IN A LIVING ROOM WHILE...
# 191  A person is eating some food, they then drink ...
# 192  A person sitting on a sofa with a open laptop ...
# 193  the person stands facing away from the camera ...
# 194  A person is interacting with a window.  Anothe...
# 195  A woman adjusts something hanging on a wall, t...
# 196  Person in hallway, kneels down, grab object, t...
# 197  A person walks into the room and takes a pictu...
# 198  A person walking across a room carrying a bag ...
# 199  A person is sitting on a chair at a table, loo...
# 200  A person holding a picture.The person wipes th...
# 201              person picks up book and opens blinds
# 202  A person goes fom standing to sitting and star...
# 203  A person moves a box, and takes and snuggles a...
# 204  A person dusting a curtain and a person pickin...
# 205  A person is standing on a chair putting up a p...
# 206  A person lying in bed looks at a picture they ...
# 207  A person is sitting on a bed eating food from ...
# 208  A person is standing still in a kitchen, holdi...
# 209  A person walks into a room and picks up a box....
# 210  someone sitting on a couch sneezing messing wi...
# 211  A woman is sitting on a bed smiling and dancin...
# 212  A person walks and  tidy ups the room a bit, i...
# 213  A person sits on a couch while working on a la...
# 214  A person is sitting on stairs looking at a pic...
# 215  A person is standing by a curtained window eat...
#
#                                                actions  length  origin_index
# 0    c106 0.00 11.10;c107 0.00 12.00;c038 13.70 23....   28.00            82
# 1    c151 16.80 24.60;c052 0.00 19.20;c111 23.60 37...   36.46            95
# 2    c084 0.00 14.60;c088 0.00 15.50;c106 12.20 19....   19.75           127
# 3      c088 6.10 11.50;c083 6.10 10.70;c084 8.90 19.00   18.04           130
# 4    c084 17.70 33.00;c096 0.00 18.20;c152 0.00 7.0...   32.00           270
# 5    c092 16.90 25.00;c097 3.50 17.00;c090 18.00 25.00   24.00           324
# 6    c097 0.00 5.90;c111 4.70 42.00;c008 0.00 6.30;...   40.71           331
# 7    c108 2.00 16.00;c111 2.00 16.00;c107 0.00 20.0...   31.58           334
# 8    c046 14.00 18.90;c049 11.80 18.20;c081 23.30 2...   31.33           418
# 9    c084 0.00 26.00;c123 26.70 32.00;c151 26.70 32...   30.96           422
# 10   c033 2.20 8.30;c034 4.30 9.10;c090 10.30 22.80...   33.17           522
# 11   c048 23.10 33.80;c123 22.10 37.50;c151 23.50 3...   39.12           574
# 12   c033 6.20 31.00;c038 12.00 17.10;c088 0.00 11....   30.46           577
# 13   c152 23.30 27.70;c149 25.90 31.00;c016 0.00 23...   30.96           615
# 14   c084 3.30 9.10;c107 6.20 15.00;c134 0.00 8.80;...   14.38           659
# 15   c084 2.50 33.00;c098 0.00 33.00;c016 4.30 33.0...   31.92           684
# 16   c141 0.00 10.40;c084 0.00 22.70;c088 18.50 29....   32.83           688
# 17   c026 0.00 25.00;c031 20.20 25.10;c032 0.00 24....   29.71           786
# 18    c103 2.00 22.40;c060 0.60 24.20;c151 23.30 28.90   28.54           800
# 19   c009 3.90 10.30;c046 6.60 12.70;c049 0.70 12.7...   33.50           862
# 20   c106 25.60 32.00;c107 24.90 32.00;c103 0.00 21...   31.46           877
# 21   c046 17.80 24.70;c047 0.00 25.30;c052 0.00 25....   30.92           961
# 22   c111 0.00 10.70;c105 20.70 27.70;c097 21.00 29...   59.75          1035
# 23   c140 0.00 33.00;c125 0.00 33.00;c007 0.00 33.0...   31.62          1053
# 24   c065 0.00 6.80;c156 0.00 6.80;c061 0.00 3.40;c...   30.67          1076
# 25   c039 0.00 4.80;c040 0.00 9.00;c084 8.30 17.00;...   15.54          1142
# 26   c046 0.00 7.80;c026 3.50 25.00;c122 5.40 25.00...   23.75          1202
# 27   c084 6.80 16.50;c083 4.60 10.70;c088 6.80 16.5...   24.83          1203
# 28   c104 13.00 21.00;c151 1.00 6.00;c060 10.00 15....   28.38          1211
# 29   c011 0.50 10.10;c027 28.80 37.80;c132 28.90 40...   38.62          1306
# ..                                                 ...     ...           ...
# 186  c046 10.70 16.80;c052 1.70 14.30;c049 13.00 19...   33.67          6721
# 187  c081 9.10 17.40;c106 15.50 32.00;c107 13.80 24...   30.67          6823
# 188  c088 0.00 21.50;c019 20.30 25.00;c104 1.50 7.7...   24.12          6857
# 189  c092 1.00 12.50;c074 9.10 16.30;c090 3.30 10.9...   29.96          6868
# 190  c103 0.00 10.00;c020 0.00 10.00;c106 0.20 10.0...    8.83          6913
# 191  c061 0.00 18.20;c106 16.30 28.80;c156 0.00 18....   39.42          6964
# 192  c090 14.10 20.30;c092 15.40 25.00;c046 9.20 16...   30.67          7002
# 193  c121 0.00 27.90;c107 3.30 27.90;c012 33.10 40....   39.21          7012
# 194  c026 7.90 18.00;c030 4.30 14.00;c092 0.00 18.0...   17.04          7025
# 195  c103 19.50 30.10;c154 18.50 31.40;c060 18.50 3...   32.29          7043
# 196  c140 0.00 7.90;c141 22.60 28.00;c007 21.00 29....   28.83          7090
# 197  c026 14.40 21.80;c152 5.20 9.80;c030 14.20 19....   22.08          7162
# 198  c008 23.60 32.00;c130 3.70 15.10;c140 18.80 28...   30.79          7202
# 199  c098 0.00 9.90;c113 2.70 15.50;c059 0.00 33.00...   32.08          7260
# 200  c141 24.40 29.20;c097 27.50 32.00;c034 16.40 2...   30.67          7312
# 201  c090 15.60 40.00;c028 38.50 45.00;c092 26.20 4...   44.42          7363
# 202  c152 18.00 27.60;c151 1.90 7.80;c084 0.00 31.0...   30.29          7497
# 203     c084 4.30 11.20;c083 2.10 7.50;c088 4.00 11.70   17.38          7545
# 204  c111 0.00 22.60;c127 27.70 39.00;c091 7.10 23....   38.04          7573
# 205  c060 0.00 32.00;c088 0.00 32.00;c083 0.00 6.60...   30.75          7586
# 206  c008 19.50 28.70;c078 12.10 21.00;c084 0.00 9....   30.29          7617
# 207  c046 1.70 10.80;c092 8.40 19.00;c156 1.80 19.0...   17.75          7642
# 208  c152 10.10 21.40;c088 12.60 18.00;c084 0.00 32.00   31.04          7739
# 209  c040 4.50 14.20;c044 7.30 12.70;c088 10.70 16....   30.92          7745
# 210  c009 9.90 15.70;c151 1.80 7.90;c153 4.40 13.50...   32.88          7769
# 211  c135 0.00 32.00;c152 0.00 3.70;c083 12.90 20.2...   30.75          7888
# 212  c151 19.60 26.10;c040 1.60 10.00;c043 0.50 8.8...   31.42          7894
# 213  c046 13.10 18.90;c052 0.00 17.20;c123 0.00 21....   20.38          7927
# 214  c098 14.20 37.00;c100 12.00 18.20;c088 2.10 12...   35.83          7937
# 215  c090 1.70 7.40;c092 3.30 8.50;c156 0.00 3.20;c...    9.54          7963
#
# [216 rows x 12 columns]

# %%
df.to_csv('train.csv')
