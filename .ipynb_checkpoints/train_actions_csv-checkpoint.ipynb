# %%
import os
import pandas as pd
import numpy as np
import sklearn
import csv

# %%
df = pd.read_csv('Charades_vu17_train.csv')

# %%
df.head()
# Out:
#       id subject         scene  quality  relevance verified  \
# 0  46GP8    HR43       Kitchen      6.0        7.0      Yes
# 1  N11GT    0KZ7        Stairs      6.0        7.0      Yes
# 2  0IH69    6RE8       Bedroom      6.0        5.0      Yes
# 3  KRF68    YA10  Laundry room      6.0        7.0      Yes
# 4  MJO7C    6RE8       Kitchen      6.0        6.0      Yes
#
#                                               script                 objects  \
# 0  A person cooking on a stove while watching som...       food;stove;window
# 1  One person opens up a folded blanket, then sne...     blanket;broom;floor
# 2  A person is seen leaving a cabinet. They then ...  book;box;cabinet;shelf
# 3  A person runs into their laundry room. They gr...      clothes;door;phone
# 4  A person runs into their pantry holding a bott...               cup;phone
#
#                                         descriptions  \
# 0  A person cooks food on a stove before looking ...
# 1  Person at the bottom of the staircase shakes a...
# 2  A person is standing in a bedroom. They walk o...
# 3  A person runs in and shuts door. The person gr...
# 4  A person runs in place while holding a bottle ...
#
#                                              actions  length
# 0                   c092 11.90 21.20;c147 0.00 12.60   24.83
# 1  c098 8.60 14.20;c075 0.00 11.70;c127 0.00 15.2...   18.33
# 2                                                NaN   30.25
# 3  c018 22.60 27.80;c141 4.10 9.60;c148 10.30 25....   30.33
# 4                    c015 0.00 32.00;c107 0.00 32.00   31.38

# %%
df = df[pd.notnull(df['actions'])] # drop NA in column['actions']
# df = df[df.quality >=6 ]
# df = df[df.relevance == 7] #  和 script 的相關性，但我們不需要管 script ，所以用不到
df['origin_index'] = df.index.values
df.head()
# Out:
#       id subject                                              scene  quality  \
# 0  46GP8    HR43                                            Kitchen      6.0
# 1  N11GT    0KZ7                                             Stairs      6.0
# 3  KRF68    YA10                                       Laundry room      6.0
# 4  MJO7C    6RE8                                            Kitchen      6.0
# 5  S6MPZ    EA2K  Home Office / Study (A room in a house used fo...      6.0
#
#    relevance verified                                             script  \
# 0        7.0      Yes  A person cooking on a stove while watching som...
# 1        7.0      Yes  One person opens up a folded blanket, then sne...
# 3        7.0      Yes  A person runs into their laundry room. They gr...
# 4        6.0      Yes  A person runs into their pantry holding a bott...
# 5        6.0      Yes  A person is eating at the desk and lying the p...
#
#                                     objects  \
# 0                         food;stove;window
# 1                       blanket;broom;floor
# 3                        clothes;door;phone
# 4                                 cup;phone
# 5  chair;desk;food;phone;plate;snacks;table
#
#                                         descriptions  \
# 0  A person cooks food on a stove before looking ...
# 1  Person at the bottom of the staircase shakes a...
# 3  A person runs in and shuts door. The person gr...
# 4  A person runs in place while holding a bottle ...
# 5  A person in a blue shirt is eating snacks off ...
#
#                                              actions  length  origin_index
# 0                   c092 11.90 21.20;c147 0.00 12.60   24.83             0
# 1  c098 8.60 14.20;c075 0.00 11.70;c127 0.00 15.2...   18.33             1
# 3  c018 22.60 27.80;c141 4.10 9.60;c148 10.30 25....   30.33             3
# 4                    c015 0.00 32.00;c107 0.00 32.00   31.38             4
# 5  c009 0.00 4.30;c011 0.00 39.00;c015 0.00 39.00...   38.46             5

# %%
df = df.reset_index(drop=True)
df.head()
# Out:
#       id subject                                              scene  quality  \
# 0  46GP8    HR43                                            Kitchen      6.0
# 1  N11GT    0KZ7                                             Stairs      6.0
# 2  KRF68    YA10                                       Laundry room      6.0
# 3  MJO7C    6RE8                                            Kitchen      6.0
# 4  S6MPZ    EA2K  Home Office / Study (A room in a house used fo...      6.0
#
#    relevance verified                                             script  \
# 0        7.0      Yes  A person cooking on a stove while watching som...
# 1        7.0      Yes  One person opens up a folded blanket, then sne...
# 2        7.0      Yes  A person runs into their laundry room. They gr...
# 3        6.0      Yes  A person runs into their pantry holding a bott...
# 4        6.0      Yes  A person is eating at the desk and lying the p...
#
#                                     objects  \
# 0                         food;stove;window
# 1                       blanket;broom;floor
# 2                        clothes;door;phone
# 3                                 cup;phone
# 4  chair;desk;food;phone;plate;snacks;table
#
#                                         descriptions  \
# 0  A person cooks food on a stove before looking ...
# 1  Person at the bottom of the staircase shakes a...
# 2  A person runs in and shuts door. The person gr...
# 3  A person runs in place while holding a bottle ...
# 4  A person in a blue shirt is eating snacks off ...
#
#                                              actions  length  origin_index
# 0                   c092 11.90 21.20;c147 0.00 12.60   24.83             0
# 1  c098 8.60 14.20;c075 0.00 11.70;c127 0.00 15.2...   18.33             1
# 2  c018 22.60 27.80;c141 4.10 9.60;c148 10.30 25....   30.33             3
# 3                    c015 0.00 32.00;c107 0.00 32.00   31.38             4
# 4  c009 0.00 4.30;c011 0.00 39.00;c015 0.00 39.00...   38.46             5

# %%
dat_id = df['id']
dat_actions = df['actions']
dat_origin_index = df['origin_index']
dat = pd.concat([dat_id, dat_origin_index, dat_actions], axis=1)
split_arr = dat['actions'].str.split(';')

# %%
large_arr = []
for element in enumerate(split_arr):
    arr = []
    for i in element[1]:
        k = i.split(" ")
        d = k[0]
        arr.append(d)
    large_arr.append(arr)
dat['split'] = large_arr

# %%
dat = dat.drop('actions', 1)

# %%
dat.head()
# Out:
#       id  origin_index                                              split
# 0  46GP8             0                                       [c092, c147]
# 1  N11GT             1                           [c098, c075, c127, c153]
# 2  KRF68             3         [c018, c141, c148, c006, c002, c150, c000]
# 3  MJO7C             4                                       [c015, c107]
# 4  S6MPZ             5  [c009, c011, c015, c019, c156, c059, c061, c06...

# %%
str_actions = dat['split']
int_actions = []
for action in str_actions:
    arr = []
    for act in action:
        a = int(act[1:])
        arr.append(a)
    int_actions.append(arr)

# %%
# str_actions # 欲處理對象
# https://www.kaggle.com/jeffd23/visualizing-word-vectors-with-t-sne
import re
import nltk

from gensim.models import word2vec
from adjustText import adjust_text
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 1
# corpus = str_actions
# that's all!


# 2
classes = open('Charades_v1_classes.txt', 'r')
d = dict()
for line in classes.readlines():
    tmp = line.split(" ", 1)
    d[tmp[0]] = tmp[1]
# d["c000"]

origin_actions = []
for mylist in str_actions:
    arr = []
    for action in mylist:
        arr.append(d[action])
#     print(arr)
    origin_actions.append(arr)

corpus = origin_actions

# %%
# model = word2vec.Word2Vec(corpus, size=100, window=20, min_count=200, workers=4)
model = word2vec.Word2Vec(corpus, size=100, window=5, min_count=10, workers=4)
# model.wv['c000']

# %%
def tsne_plot(model):
    "Creates and TSNE model and plots it"
    labels = []
    tokens = []

    for word in model.wv.vocab:
        tokens.append(model[word])
        labels.append(word)
    
    tsne_model = TSNE(perplexity=10, n_components=2, init='pca', n_iter=2500, random_state=23)
    new_values = tsne_model.fit_transform(tokens)

    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
        
    texts = []
    plt.figure(figsize=(25, 25)) 
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        texts.append(plt.text(x[i], y[i], labels[i]))

        plt.annotate(labels[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
        
    adjust_text(texts, arrowprops=dict(arrowstyle='-', color='k', lw=0.5))

    plt.savefig("tsne.png")
    plt.show()

# %%
tsne_plot(model)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-d0f4ea6902bf> in <module>()
# ----> 1 tsne_plot(model)
#
# <ipython-input-14-b2b5750fa91e> in tsne_plot(model)
#      30                      va='bottom')
#      31
# ---> 32     adjust_text(texts, arrowprops=dict(arrowstyle='-', color='k', lw=0.5))
#      33
#      34     plt.savefig("tsne.png")
#
# ~/python3/lib/python3.6/site-packages/adjustText/adjustText.py in adjust_text(texts, x, y, add_objects, ax, expand_text, expand_points, expand_objects, expand_align, autoalign, va, ha, force_text, force_points, force_objects, lim, precision, only_move, text_from_text, text_from_points, save_steps, save_prefix, save_format, add_step_numbers, draggable, *args, **kwargs)
#     431                                          add_bboxes=add_bboxes,
#     432                                          direction=autoalign, renderer=r,
# --> 433                                          ax=ax)
#     434         else:
#     435             texts = optimally_align_text(orig_x, orig_y, texts,
#
# ~/python3/lib/python3.6/site-packages/adjustText/adjustText.py in optimally_align_text(x, y, texts, expand, add_bboxes, renderer, ax, direction)
#     123             if v:
#     124                 text.set_va(v)
# --> 125             bbox = text.get_window_extent(r).expanded(*expand).\
#     126                                        transformed(ax.transData.inverted())
#     127             c = len(get_points_inside_bbox(x, y, bbox))
#
# ~/python3/lib/python3.6/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     965             raise RuntimeError('Cannot get window extent w/o renderer')
#     966
# --> 967         bbox, info, descent = self._get_layout(self._renderer)
#     968         x, y = self.get_unitless_position()
#     969         x, y = self.get_transform().transform_point((x, y))
#
# ~/python3/lib/python3.6/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     386
#     387         # get the rotation matrix
# --> 388         M = Affine2D().rotate_deg(self.get_rotation())
#     389
#     390         offsetLayout = np.zeros((len(lines), 2))
#
# ~/python3/lib/python3.6/site-packages/matplotlib/transforms.py in rotate_deg(self, degrees)
#    1933         and :meth:`scale`.
#    1934         """
# -> 1935         return self.rotate(degrees * np.pi / 180.)
#    1936
#    1937     def rotate_around(self, x, y, theta):
#
# ~/python3/lib/python3.6/site-packages/matplotlib/transforms.py in rotate(self, theta)
#    1922             np.float_)
#    1923         self._mtx = np.dot(rotate_mtx, self._mtx)
# -> 1924         self.invalidate()
#    1925         return self
#    1926
#
# ~/python3/lib/python3.6/site-packages/matplotlib/transforms.py in invalidate(self)
#     132         time the transform changes.
#     133         """
# --> 134         value = self.INVALID
#     135         if self.is_affine:
#     136             value = self.INVALID_AFFINE
#
# KeyboardInterrupt:

# %%
# model.most_similar('c042')
model.most_similar('Closing a box\n')

# %%
model.most_similar('Sitting in a chair\n')
